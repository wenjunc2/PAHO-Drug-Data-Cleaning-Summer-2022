# %% [markdown]
# <a href="https://colab.research.google.com/github/wenjunc2/Summer-2022/blob/main/RawData_Chile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Chile drug names 1

# %%
import pandas as pd
#CHLDiab1 = pd.read_csv('CHLDiab1.csv')

# %%
import chardet
with open('CHLDiab1.csv', 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
result
# Out:
# {'confidence': 0.73, 'encoding': 'Windows-1252', 'language': ''}

# %%
CHLDiab1 = pd.read_csv('CHLDiab1.csv',encoding='Windows-1252')
#CHLDiab1.head(1)

# %%
CHLDiab1DirtyName = CHLDiab1['Descripcion linea Adquisicion']

# %%
len(CHLDiab1DirtyName)
# Out:
# 20606

# %%
CHLDiab1DirtyName = list(set(CHLDiab1DirtyName))
len(CHLDiab1DirtyName)
# Out:
# 3663

# %%
# uppercase everything
CHLDiab1DirtyNameU = []
for i in CHLDiab1DirtyName:
  CHLDiab1DirtyNameU.append(i.upper())

# %%
CHLDiab1DirtyNameU
# Out:
# ['INSULINA HUMANA MONOCOMPONENTE ISOFANICA NPH ADN RECOMBINANTE 100 U.I./ML SUSPENSION INYECTABLE  FRASCO AMPOLLA 10ML',
#  'METFORMINA CLORHIDRATO RECUBIERTO 850 MG\t\t\t\r\r\n',
#  'LO QUE SE REQUIERE ES METFORMINA 1000 VILDAGLIPTINA 50  X 56  COMP',
#  '1629829 INSULINA GLARGINA  ACCION PROLONGADA 100 U/ML 3ML LAPIZ SOLUCIÓN INYECTABLE SC',
#  'SITAGLIPTINA 50/ METFORMINA 500 X 56 COMP. REC SIMILAR A JANUMET 50/850',
#  'INSULINA CRISTALINA HUMANA MONOCOMPETENTE ADN RECOMBINENTE 100 U.I/ML F.A 10 ML',
#  'XIG-DUO 10/1000 X 28 COMP.',
#  'METFORMINA 750 MG X 30 COMPRIMIDOS LIBERACION PROLONGADA',
#  'INSULINA HUMANA CRISTALINA – SOLUCIÓN INYECTABLE 100 UI/10 ML – VÍA SUBCUTÁNEA – FRASCO AMPOLLA MULTIDOSIS 1.000 UI (DEBE INCLUIR INSUMOS PARA ADMINISTRACIÓN COMO: AGUJAS, BOLSA PARA TRANSPORTE Y MANTENCIÓN DE CADENA DE FRIO (262-050-00)',
#  'LO QUE SE REQUIERE ES DAPAGLIFOZINA 5 MG METFORMINA 1000 X 56 COMP',
#  'VILDAGLIPTINA + METFOMIRNA 50/1000 MG (SIMILAR GALVUS MET 50/1000) CAJA DE 28 COMPRIMIDOS',
#  'METFORMINA 850MG. CON FECHA VENCIMIENTO ENERO 2023',
#  'INSULINA GLARGINA 300 UI/ML \r\r\nLÁPIZ PRELLENADO / CON 10 AGUJAS 32 G X 4 MM POR DISPOSITIVO DE INYECCIÓN TIPO LAPICERA\r\r\n',
#  'SUMINISTRO DE METFORMINA CLORHIDRATO 1000 MG, CAJA 30 O 60 COMPRIMIDOS',
#  'METFORMINA 1000MG COMPRIMIDO LP.',
#  'SITAGLIPTINA 50 MG METFORMINA CLORHIDRATO 1000 MG, COMPRIMIDOS DE LIBERACION PROLONGADA, ENVASADOS EN BLISTER DE PVC O SIMILAR Y ALUMINIO IMPRESO, ENVASE 56 COMPRIMIDOS. TIPO JANUMET 50/1000MG XR\r\r\n',
#  'METFORMINA 850 MG. CM. VENCIMIENTO SUPERIOR A 12 MESES',
#  'METFORMINA 850 MG (INDICAR VALOR COMPRIMIDO NETO).\r\r\n',
#  'CAJAS DE LINAGLIPTINA 2,5MG/METFORMINA 850MG; PRESENTACIÓN CAJA DE 30 TABLETAS; SIMILAR TRAYECTA DUO.',
#  '(2032022022) AGUJA 31 G X 8 MM. LAPIZ INSULINA 3ML (LAPIZ NOVOPEN)',
#  'METFORMINA XR 750 MG\t\r\r\nENVASE DE 30 COMPRIMIDOS',
#  'METFORMINA / SITAGLIPTINA 100/1000 MG POR 28 COMPRIMIDOS. JANUMET O SIMILAR\r\r\n',
#  'METFORMINA 1000 MG COMP. DE LINERACIÓN PROLONGADA',
#  '50-214-700-052-00 METFORMINA XR 750 MG\r\r\n',
#  'FAAA10005 INSULINA RETARDADA HUMANA 100 UI/ML INY',
#  '1093087-3 CADA COMPRIMIDO DE LIBERACIÓN PROLONGRADA CONTIENE\r\r\n METFORMINA CLORHIDRATO 750 MG O EQUIVALENTE A GLAUPAX XR 750MG X 30 COMP.',
#  'METFORMINA 850 MG COMPRIMIDOS BIOEQUIVALENTE / COMPRIMIDOS CAJAS X 1000 Ó 1.200',
#  'EMPAGLIFOCINA 12,5 MG; METFORMINA 850 MG ENVASE DE 60 COMPRIMIDOS (EQ A JARDIANCE DUO). MAXIMO A PAGAR $31.106',
#  'METFORMINA 850 MG COMPRIMIDO RECUBIERTO',
#  'JERINGA DESECHABLE ESTÉRIL P/INSULINA 1CC',
#  'METFORMINA 1000 MG CM LIB PROLONGADA/CM REC LIB PROLONGADA (ITEM N° 77 DE LAS ESPECIFICACIONES TÉCNICAS).',
#  'JARDIANCE DUO 12,5/850',
#  'INSULINA GLARGINA 100 UI/ML, LÁPIZ PEN PRELLENADO DE 3 ML TIPO LANTUS SOLOSTAR. ENVASE CON 1 O 3 LÁPICES. FECHA DE VENCIMIENTO NO MENOR A 10 MESES DESDE LA ENTREGA.',
#  'METFORMINA 500MG COMPRIMIDOS RECUBIERTOS SIMILAR GLAFORNIL',
#  'METFORMINA COMP 850MG',
#  'METFORMINA/GLIBENCLAMIDA COMPRIMIDO  500 MG/5 MG VENC. SUPERIOR 24 MESES COMPRIMIDOS  OBLONGOS RANURABLES DOCUMENTACION TECNICA SOLICITADA : CERTIFICADO DE FARMAVIGILANCIA,  CERTIFICADO DE ANALISIS DE  LOTE , BIOEQUIVALENCIA, ESTADO DEL REGISTRO SANITARIO',
#  'INSULINA ASPARTA RECOMBINANTE, 100 U/ML.',
#  'EMPAGLIFLOZINA 12.5MG / METFORMINA 850MG COMPRIMIDOS, SEGÚN LO EXIGIDO EN BASES ADMINISTRATIVAS Y TÉCNICAS.',
#  'METFORMINA + GLIBENCLAMIDA 500/2.5MG **CARDIOVASCULAR**',
#  'METFORMINA LIB. PROLONGADA CM 1000 MG',
#  'LINAGLIPTINA/METFORMINA 2.5/850 MG. CAJA DE 60 COMPRIMIDOS.',
#  'METFORMINA / SITAGLIPTINA 50/850 MG POR 56 COMPRIMIDOS. JANUMET O SIMILAR\r\r\n',
#  'METFORMINA CLORHIDRATO 1000 MG + SITAGLIPTINA 50 MG. ENVASE COMERCIAL CON 56 COMPRIMIDOS DE LIBERACIÓN CONVENCIONAL. FECHA DE VENCIMIENTO NO MENOR A 8 MESES DESDE LA ENTREGA.',
#  'METFORMINA CLORHIDRATO COMPRIMIDOS LIBERACIÓN PROLONGADA 1000 MG X 20-30-500-1000 CM VENC. SUPERIOR 2 AÑOS DOCUMENTACION TECNICA SOLICITADA : CERTIFICADO DE FARMAVIGILANCIA, POLITICA DE CANJE Y DEVOLUCION , CERTIFICADO DE ANALISIS DE LOTE',
#  'INSULINA HUMANA ISOFANA (NPH) SUSPENSION INYECTABLE 100 U.I./ML FRASCO 10 ML EQUIVALENTE A INSULATARD\r\r\n',
#  'INSULINA NPH 10 UI/ML FA ( CONSUMO PROM. MENS: 1.500 )\r\r\n\r\r\n',
#  'INSULINA TRESIBA',
#  '•\tSITAGLIPTINA/METFORMINA CLORHIDRATO 50/500 X 56 COMPRIMIDOS RECUBIERTOS',
#  'CÓD.: 2200046\r\r\nINSULINA ULTRA RAPIDA (GLULISINA) 100UI/ML SOLUCION INYECTABLE LAPIZ PRELLENADO 3ML',
#  '214-5138\tMETFORMINA 850 MG EN BLISTER, BIOEQUIVALENTE/ REFERENTE/ INNOVADOR',
#  'GLIBENCLAMIDA/ METFORMINA  COMPRIMIDO 5MG/500MG\r\r\n',
#  'INSULINA GLARGINA 100UI/ML. SOLUCIÓN INYECTABLE X 1 CARTUCHO 3ML. SIMILAR A LANTUS SOLOSTAR\t.....(INDICAR FECHA DE VENCIMIENTO Y REGISTRO ISP).. \t\t\t\r\r\n',
#  'VILDAGLIPTINA/METFORMINA 50/850 X 56 COMPRIMIDOSVILDAGLIPTINA/METFORMINA 50/850 X X 28 COMPRIMIDOS\r\n',
#  'METFORMINA XR 1000MG X COMPRIMIDO, CAPSULA',
#  'METFORMINA 500 MG  LINAGLIPTINA 2,5 MG, ENVASE CON 60 COMPRIMIDOS. FECHA DE VENCIMIENTO NO MENOR A 8 MESES.',
#  'LEVOTIROXINA 100 MCG - PRESENTACIÓN: COMPRIMIDO\r\r\n',
#  'EMPAGLIFLOZINA 12,5 MG/ METFORMINA 850 MG, CAJA X 60 COMPRIMIDOS RECUBIERTOS (EQUIVALENTE A JARDIANCE DUO)',
#  'DAPAGLIFLOZINA (COMO PROPANODIOL) 5 MG Y METFORMINA CLORHIDRATO 1000 MG X 56 COMP\r\r\n',
#  'JANUMET 50/850 MG\tENVASE DE 56 COMPRIMIDOS',
#  'LINAGLIPTINA  2.5 MG + METFORMINA  CLORHIDRATO 850 MG SIMILAR A  TRAYENTA 2,5/850MG COMPRIMIDOS RECUBIERTOS',
#  'SITAGLIPTINA/METFORMINA 50/850MG X 56 COMP. (SIMILAR A JANUMET)',
#  'IGF1 (INSULINE LIKE GROWTH FACTOR)',
#  'CAJA DE 60 COMPRIMIDO CONTIENE: METFORMINA CLORHIDRATO 850 MG, COMPRIMIDOS RECUBIERTOS. SIMILAR A GLIDANIL',
#  'VILDAGLIPTINA 50/METFORMINA 1000MG X56 **GALVUS MET**',
#  'SITAGLIPTINA/ METFORMINA 50/1000 SIMILAR A JANUMET 50/1000',
#  'METFORMINA 750 MG\r\r\n',
#  'METFORMINA 750 MG X 30 O 60 COMPRIMIDOS DE LIBERACIÓN PROLONGADA',
#  'INSULINA LISPRO 100 U/ML 5 X 3ML SIMILAR A HUMALOG KWIKPEN',
#  'FA03-0005 INSULINA ASPARTATO 100 UI/ML LAPIZ 3 ML (ULTRA RAPIDA) (UI)',
#  'SITAGLIPTINA 50 MG; METFORMINA CLORHIDRATO 850 MG CAJA 56 COMPRIMIDOS RECUBIERTOS',
#  'METFORMINA 1000 MG/GLIBENCLAMIDA 5 MG X CAJA CON 30 A 60 COMPRIMIDOS',
#  'INSULINA ASPARTA 300 UI/3 ML LAPIZ INYECTABLE\r\r\n',
#  'INSULINA NOVORAPID 100 UI/ML X 300 UI O EQUIVALENTE TERAPEUTICO\r\r\n\r\r\n',
#  'INSULINA GLARGINA HUMANA 100 UI/ ML, JERINGA PRELLENADA. ESPECIFICAR MARCA, CARACTERÍSTICAS Y PRESENTACIÓN. CONSUMO PROMEDIO MENSUAL 600 UNIDADES APROX',
#  'DAPAGLIFOZINA  5 MG  + METFORMINA  CLORHIDRATO 1000 MG. SIMILAR A XIG DUO 5/1000 MG POR R 60 COMPRIMIDOS RECUBIERTOS DE LIBERACIÓN PROLONGADA',
#  'METFORM/SAXAGLIPTIN 1000/5 MG CM LIB EXT(100004977)',
#  '1093059-2 CADA COMPRIMIDO CONTIENE LOS PRINCIPIOS ACTIVOS SITAGLIPTINA 50MG Y METFORMINA 1000MG PARA ADMINISTRACION POR VIA ORAL EN LA FORMA FARMACEUTICA DE COMPRIMIDOS CON \r\r\nRECUBRIMIENTO O EQUIVALENTE A JANUMET 50/1000 X 56 COMP.',
#  'JANUMET XR 100 MG / 1000 MG X 28 COMPRIMIDOS O EQUIVALENTE TERAPEUTICO\r\r\n\r\r\n',
#  'LINAGLIPTINA 2,5 MG Y 1000 MG CLORHIDRATO DE METFORMINA COMPRIMIDOS RECUBIERTOS; EQUIVALENTE A TRAYENTA DUO 2.5/1000 MG 60 COMP',
#  'METFORMINA 1000 MG X 60 COMPRIMIDOS LP\r\n',
#  'ELECSYS INSULINA CALSET',
#  'METFORMINA 1000 MG / DAPAGLIFLOZINA 5 MG',
#  'VILDAGLIPTINA-METFORMINA 50-1000 MG COMP RECUBIERTO - VENCIMIENTO MAYOR A 1 AÑO, NO SE ACEPTAN CARTAS DE CANJE',
#  'GLAUPAX XR 750 MG CAJA X 30 COM. (O EQUIVALENTE)',
#  'METFORMINA 850MG COMPRIMIDO',
#  'METFORMINA 850 MG CM\r\r\n',
#  '1093080-8 CADA COMPRIMIDO CONTIENE 850MG DE METFORMINA O EQUIVALENTE A GLAFORNIL 850MG X 30 COMP.RECUB',
#  'LO QUE SE REQUIERE ES  INSULINA GLARGINA 300 UNIDADES EQUIVALENTES A 10.91 MG. QUE CADA LAPICERA CONTENGA 1.5 ML DE SOLUCIÓN INYECTABLE, EQUIVALENTES A 450 UNIDADES. TIPO TOUJEO',
#  '262-0068 INSULINA ASPARTO SOLUCION INYECTABLE 100UI/MLX3 ML. (LAPIZ).',
#  'SITAGLIPTINA + METFORMINA, COMPRIMIDOS RECUBIERTOS, 50 MG + 850 MG,1) PRESENTACIÓN VENTA PÚBLICO MÁS CONVENIENTE DESDE PUNTO DE VISTA PRECIO\r\r\n2) AL MENOS 24 MESES DE EFICACIA\r\r\n3) FABRICADO EN EL EXTRANJERO\r\r\n4) CERTIFICADO CUMPLIMIENTO BUENAS PRACTICAS DE',
#  'METFORMINA 500 MG/GLIBENCLAMIDA 2,5 MG X 30 COMP REC',
#  'INSULINA GLARGINA 300 UI/ML LAPIZ 1.5 ML.',
#  'TRAYENTA DUO, 30 COMP',
#  'METFORMINA 850 MG X COMP. (ENVASE CLINICO)',
#  'DAPAGLIFLOZINA 5 MG CM +METFORMINA 1000 MG  COMPRIMIDOS',
#  'INSULINA ULTRALENTA GLARGINA 100 UI/ML LÁPIZ DESECHABLE 3ML. JERINGA PRELLENADA (2620928)',
#  'SITAGLIPINA 64.25 MG COMO FOSFATO MONOHIDRATADO Y METFORMINA CLORHIDRATO, EQUIVALENTE A 50 MG DE SITAGLIPINA COMO BASE LIBRE Y 850 MG DE METFORMINA CLORHIDRATO, COMPRIMIDOS RECUBIERTOS; EQUIVALENTE A JANUMET 50/850 MG 28 COMP\r\r\n',
#  'METFORMINA 500 MG MAS GLIBENCLAMIDA 5 MG.',
#  '1092025 - 4   INSULINA HUMANA RAPIDA',
#  'SITAGLIPTINA 50 MG + METFORMINA 1000 MG X 56 COMPRIMIDOS, SIMILAR A JANUMET 50/1000 MG X 56 COMPRIMIDOS RECUBIERTOS',
#  'DAPAGLIFOZINA METFORMINA 5/1000 X 56 TABLETAS SIMILAR A XIGDUO',
#  'INSULINA NPH FA 100UI FA',
#  'SITAGLIPTINA 50 MG /METFORMINA MG 850 X 56 COMPRIMIDOS.',
#  'GLAFORNIL XR 500 MG X 30 CM. LIBERACION PROLONGADA (O EQUIVALENTE)',
#  'INSULINA LISPRO 100 U/ML 5 X 3 ML SIMILAR A HUMALOG KWIKPEN',
#  'METFORMINA COMPRIMIDO 850 MG BLISTER DE PVC/ALUMINIO IMPRESO, ENVASE RESISTENTE CON SELLO QUE ASEGURE LA INVIOLABILIDAD DEL CONTENIDO FECHA VENCIMIENTO SUPERIOR A 2 AÑOS.',
#  'METFORMINA 500MG XR',
#  'METFORMINA 500 MG CM/CM REC LIB. PROLONG 100003871',
#  'METFORMINA XR 500 MG X 30 COMP.',
#  'METFORMINA 1000 MG COMPRIMIDO RECUBIERTO LIBERACIÓN PROLONGADA',
#  'LANTUS SOLOSTAR LAPIZ (100 UI/ML * CATRIDGE DE 3 ML)',
#  'GALVUS 50/850 MG X 56 COMP.',
#  'METFORMINA 850MG **CARDIOVASCULAR**',
#  'LO QUE SE REQUIERE ES METFORMINA 1000 DE LIBERACIÓN PROLONGADA X 30',
#  'METFORMINA DE 850 MG.',
#  'METFORMINA 1000 MG; VILDAGLIPTINA 50 MG. COMPRIMIDOS RECUBIERTOS. ENVASE SELLADO, RESISTENTE E INADULTERADO. SIMILAR A GALVUS MET',
#  '007-0015 INSULINA CRISTALINA HUMANA SOLUCION INYECTABLE 100 UI / ML FRASCO AMPOLLA 10 ML',
#  'SE REQUIERE ADQUIRIR GLIBENCLAMIDA /METFORMINA 5/500 MG/CM',
#  'INSULINA ULTRA RAPIDA 100UI/ML FAM/CGE',
#  'METFORMINA 500 MG + GLIBENCLAMIDA 5 MG COMPRIMIDO O CÁPSULA',
#  'INSULINA CRISTALINA FA 100 UI/ML 10ML SOLUCION INYECTABLE',
#  'JERINGA DESECHABLE DE 1 CC. 27GX1 ½.',
#  'METFORMINA / GLIBENCLAMIDA COMPRIMIDO 500 MG/ 5 MG',
#  'METFORMINA CLORHIDRATO 750 MG, COMPRIMIDOS DE LIBERACION PROLONGADA, ENVASADOS EN BLISTER DE PVC O SIMILAR Y ALUMINIO IMPRESO, ENVASE 60 COMPRIMIDOS DE LIBERACIÓN PROLONGADA. GMP DE LA PLANTA PRODUCTORA (DESPACHO PARCIALIZADO)',
#  'SITAGLIPTINA/METFORMINA 50/1000 MG. PRESENTACIÓN 56 COMPRIMIDOS.',
#  'METFORMINA 1000 MG COMPRIMIDO DE LIBERACION PROLONGADA ENVASADO EN BLISTER',
#  'INSULINA HUMANA NPH 1000 UI/10 ML (100 UI/ML) INYECTABLE',
#  'METFORMINA 850 MG COMPRIMIDO, VENCIMIENTO MÍNIMO DE 12 MESES (INDICAR FECHA DE VENCIMIENTO).-',
#  'METFORMINA CLORHIDRATO 500 MG (EQUIVALENTE A METFORMINA BASE 390 MG). CAJA X 30 COMPRIMIDOS DE LIBERACIÓN PROLONGADA. SIMILAR GLIFORTEX XR 500 X 30 COMP.',
#  'JERINGA INSULINA',
#  'LÍNEA 14: METFORMINA 1000MG LIBERACIÓN PROLONGADA (COMPRIMIDO)',
#  'INSULINA RETARDADA NPH 100 UI/ML FC 10 ML',
#  'GLUCOVANCE 1000/5 MG METFORMINA + GLIBENCAMIDA, 30 TABLETAS',
#  'CAJA DE 56 COMPRIMIDO CONTIENE: VILDAGLIPTINA 50 MG; METFORMINA CLORHIDRATO 850 MG. SIMILAR A GALVUS MET 50/850',
#  'METFORMINA 850 MG, PRESENTACION X 1000',
#  'METFORMINA CLORHIDRATO XR 1000MG\tCOMPRIMIDO LIBERACIÓN PROLONGADA',
#  'METFORMINA CLORHIDRATO 850MG; CAJA X 60 COMPRIMIDOS; BIOEQUIVALENTE. EXCIPIENTES:  POVIDONA. CROSPOVIDONA, CELULOSA MICROCRISTALINA, ACIDO ESTEÁRICO; PRODUCTO ELABORADO EN CHILE.',
#  'METFORMINA 1000 MG L.P',
#  'METFORMINA 850 MG X 30 COMPRIMIDOS RECUBIERTOS\r\r\n',
#  'INSULINA DEGLUDEC 100 UI/ML LAPIZ PRELLENADO DE 3 ML (SIMILAR TRESIBA)',
#  '100 CAJAS X 1000 COMPRIMIDOS METFORMINA 850MG',
#  'METFORMINA CLORHIDRATO 1000 MG  X 56 COMP LIB. PROLONGADA\r\r\n(GLAUPAX XR, GLIFORTX XR, GLIMEFOR XR,  HIPOGLUCIN LP, TAVIST XR)\r\r\n',
#  'JANUMET 1000/50 MG\tENVASE DE 56 COMPRIMIDOS',
#  'INSULINA NPH HUMANA 100 UI/ML FAM 10 ML\r\r\n',
#  'EMPAGLIFLOZINA / METFORMINA 12.5 MG. ; 850 MG., CAJA 60 COMPRIMIDOS',
#  'METFORMINA 850MG COMPRIMIDOS RECUBIERTOS',
#  'METFORMINA CLORHIDRATO 850 MG, COMPRIMIDO RECUBIERTO',
#  'METFORMINA 500 MG, COMPRIMIDO  LIBERACIÓN  CONVENCIONAL',
#  'INSULINEMIA',
#  'METFORMINA 850MG. COTIZAR POR COMPRIMIDO. VENCIMIENTO IGUAL O SUPERIOR A 12 MESES. INDICAR VENCIMIENTO Y MONTO MÍNIMO DE FACTURACIÓN Y DESPACHO POR LINEA. EL DESPACHO SERÁ UNO SOLO.',
#  'GLIBENCLAMIDA/METFORMINA 5/500 MG CM / CM REC',
#  'SITAGLIPINA 50 MG + METFORMINA CLORHIDRATO 850 MG X 56 COMP\r\r\n(JANUMET 50/850)',
#  'METFORMINA CLORHIDRATO 750 MG, COMPRIMIDOS DE LIBERACION PROLONGADA, ENVASADOS EN BLISTER DE PVC O SIMILAR Y ALUMINIO IMPRESO, ENVASE 30 COMPRIMIDOS DE LIBERACIÓN PROLONGADA. CERTIFICACIÓN FDA O EMA, GMP DE LA PLANTA PRODUCTORA \r\r\n\r\r\n\r\r\n\r\r\n',
#  'EMPAGLIFLOZINA 12,5MG/1000MG CLORHIDRATO DE METFORMINA X 60 COMPRIMIDOS RECUBIERTOS\r\r\n',
#  'SITAGLIPTINA/METFORMINA LIBERACIÓN PROLONGADA 50/1000 MG. CAJA DE 56 COMPRIMIDOS.',
#  'LINAGLIPTINA 2,5 MG MTFORMINA 850 MG COMPRIMIDO ENVASADOS EN BLISTER PVC O SIMILAR Y ALUMINIO IMPRESO, ENVASE CONTENIDO 60 COMPRIMIDOS, CERTIFICACION GMP DE LA PLANTA PRODUCTORA. \r\r\n\r\r\n \r\r\n',
#  'METFORMINA /GLIBENCLAMIDA CM 500/5 MG ENVASADO EN BLISTER ENVASE INDIVIDUAL RESISTENTE CON SELLO QUE ASEGURE INVIOLABILIDAD DEL CONTENIDO.',
#  'KIT EDUCATIVO DE INSULINOTERAPIA (ABDOMEN DE INYECCIÓN PORTÁTIL)',
#  'METFORMINA/SITAGLIPTINA 50/1000 MG.COMPRIMIDO O CAPSULA',
#  '\xa0INSULINA RETARDADA 10 ML (INSULATARD) NOVO NORDISK\r\r\n',
#  'CAJA DE SITAGLIPTINA 50 MG /\r\nMETFORMINA 850 MG X 28\r\nCOMPRIMIDOS\r\nNOTA: SE SUGIERE FECHA DE\r\nVENCIMIENTO SUPERIOR A 1 AÑO O EN\r\nCASO CONTRARIO CONTAR CON\r\nPOLITICAS DE CANJE\r\n',
#  'METFORMINA CLORHIDRATO 850 MG COMP (EQUIVALENTE TERAPÉUTICO/ PRESENTACIÓN POR ENVASE 30 O 1000 COMP/ REGIST. SANITARIO VIGENTE/PROVEEDOR CON AUTOR. SANITARIA VIGENTE)',
#  '1092028-8 INSULINA LENTA NPH 100UI/ML EN LAPIZ DE 3ML    \r\r\nCON VIGENCIA SUPERIOR A UN AÑO O EQUIVALENTE A   INSULINA INSULATARD PENFILL',
#  'LO QUE SE REQUIERE ES INSULINA DEGLUDEC EN 3 ML  LAPIZ',
#  'SUMINISTRO DE METFORMINA CLORHIDRATO 500 MG/GLIBENCLAMIDA 5 MG, CAJA 30 O 60 COMPRIMIDOS',
#  '2200067\tINSULINA GLULISINA 3 ML CATRIDGE  (SEGÚN BASES TÉCNICAS Y SUS FORMULARIOS)',
#  'VILDAGLIPTINA 50 MG  + METFORMINA 850 MG X 56 COMP. SIMILAR A GALVUS MET',
#  '262-0710 INSULINA ANALOGA ULTRA RAPIDA CON EVIDENCIA PARA USO EN EMBARAZO O MUJERES EN EDAD FERTIL  Y PARA POBLACION CON ALTO RIESGO DE HIPOGLICEMIAS EN DM1 O POBLACION ADULTO MAYOR.',
#  'SITAGLIPTINA 50/ METFORMINA 500 X 56 COMP. REC SIMILAR A JANUMET 50/500',
#  'LINAGLIPTINA 2,5 MG + METFORMINA 850 MG SIMILAR TRAYENTA DUO 2,5/850 MG',
#  '[9350001] PUERTO DE INYECCION DE INSULINA (I-PORT ADVANCE MMT-100)',
#  'METFORMINA XR 1000MG COMPRIMIDOS',
#  'JERINGAS DE 1CC',
#  'METFORMINA 850MG COMPRIMIDOS SIMILAR GLAFORNIL',
#  'METFORMINA /GLIBENCLAMIDA',
#  '6605410\tMETFORMINA 850MG COMP.\r\r\n',
#  'LO QUE SE REQUIERE ES SAXAGLIPTINA 5  METFORMINA 1000 XR X 60 C',
#  'INSULATARD X 10 ML O SIMILAR',
#  'VIDAGLIPTINA 50 MG/ METFORMINA CLORHIDRATO 850 MG X 56 COMP REC SIMILAR A GALVUS MET\r\r\n',
#  'METFORMINA 850 MG //SALUD MENTAL//',
#  'INSULINA HUMANA ISOFANA NPH NOVO LENTA 100 UI/ML',
#  'INSULINA HUMANA CRISTALINA 100 UI/ML (F.A. 10 ML) (AIU206) HOSDIP AI5206',
#  'ENVASE DE 30 COMPRIMIDOS QUE CONTIENE: METFORMINA CLORHIDRATO 500 MG; SIMILAR O IGUAL A GLAFORNIL XR 500 MG.',
#  '262-0098\tINSULINA GLULISINA 100 UI/ML',
#  'METFORMINA 850 MG ENVASE CLINICO',
#  'TRAYENTA DUO 2,5/1000 MG X 60 COMP.',
#  'METFORMINA XR 1000 MG X 30 COMP REC',
#  'VILDAGLIPTINA 50 + METFORMINA 500 MG, CAJA DE 28 O 56 COMPRIMIDOS.',
#  'EMPAGLIFOZINA12.5MG / METFORMINA 850MG X 60 COMP',
#  'EMPAGLIFOZINA 12,5 METFORMINA 850 X 60 COM REC JARDIAN DUO O SIMILAR \r\r\n',
#  'LINAGLIPTINA 2.5 MG/METFORMINA 850 MG X 60 COMP REC. SIMILAR TRAYENTA DUO\r\r\n',
#  'METFORMINA 750 MG LIBERACIÓN PROLONGADA X 30 COMP',
#  'METFORMINA CLORHIDRATO 1000 MG. ENVASADO EN BLISTER DE PVC O SIMILAR Y ALUMINIO IMPRESO DE 60 COMP LIBERACIÓN PROLONGADA',
#  'METFORMINA 500 MG. COMPRIMIDOS RECUBIERTOS. ENVASE SELLADO, RESISTENTE E INADULTERADO',
#  'SITAGLIPTINA 50 MG/ METFORMINA 850 MG, CAJA 56 COMPRIMIDOS RECUBIERTO (JANUMET)',
#  'METFORMINA \tCOMP. REC. LIB. PROL.\t1000 MG \r\r\n',
#  'SITAGLIPTINA  50 MG / METFORMINA 500 MG X 28 COMPRIMIDOS \r\nNOTA: SE SUGIERE FECHA DE VENCIMIENTO SUPERIOR A 1 AÑO O EN CASO CONTRARIO CONTAR CON POLITICAS DE CANJE',
#  'INSULINA ULTRA RÁPIDA 100 UI/ML, JERINGA PRELLENADA,QUE INCLUYA POR CADA JERINGA 10 AGUJAS DE 6 MM PARA LA ADMINISTRACION DEL FARMACO. ESPECIFICAR MARCA CARACTERÍSTICAS Y PRESENTACIÓN. CONSUMO PROMEDIO MENSUAL 300 JERINGAS PRELLENADAS APROXIMADAS.',
#  'METFORMINA COMPRIMIDOS 850MG.',
#  'METFORMINA 1.000 MG COMPRIMIDOS DE LIBERACION PROLONGADA (XR)',
#  'KOMBIGLYZE XR 2,5/1000 CAJA X 56 COM. (O EQUIVALENTE)',
#  'EMPAGLIFLOZINA 12.5 MG + CLORHIDRATO DE METFORMINA 850 MG X 60 COMPRIMIDOS RECUBIERTOS, SIMILAR A JARDIANCE DUO 12,5/850 MG X 60 COMPRIMIDOS RECUBIERTOS',
#  'EMPAGLIFOZINA 12.5/850MG X 60 COMP. (SIMILAR JARDIANCE DUO)',
#  'INSULINA 30/70 UI/ 10 ML FC. COTIZAR X FRASCO INDICAR VENCIMIENTO',
#  'DAPAGLIFOZINA 10 MG + METFORMINA 1000 MG X 56 COMP. SIMILAR A XIGDUO 10/1000\r\r\n',
#  '"DAPAGLIFOZINA 5MG+ METFORMINA 1000 MG X 56 COMP. PROL. SIMILAR A XIGDUO XR. . .. . . . . . . . . . . . ..(SE ADJUNTAN BASES ADMINISTRATIVAS Y TÉCNICAS ""LEERLAS P/OFERTAR)"',
#  'LO QUE SE REQUIERE ES METFORMINA 1000 VILDAGLIPTINA 50 MG X 56 COMP',
#  'METFORMINA COMPRIMIDOS RECUBIERTOS LIBERACIÓN PROLONGADA, 1000MG, 1) PRESENTACIÓN VENTA PÚBLICO MÁS CONVENIENTE DESDE PUNTO DE VISTA PRECIO\r\r\n2) AL MENOS 24 MESES DE EFICACIA\r\r\n3) FABRICADO EN CHILE\r\r\n4) CERTIFICADO CUMPLIMIENTO BUENAS PRACTICAS DE FABRICACI',
#  'GLAFORNIL XR 1000 MG X 30',
#  'LINAGLIPTINA 2.5MG/ METFORMINA 1000 MG X 60 COMP\r\r\n',
#  'LINAGLIPTINA 2.5 MG Y CLORHIDRATO DE METFORMINA 850 MG. ENVASADO EN BLISTER DE PVC O SIMILAR Y ALUMINIO IMPRESO DE 60 COMP RECUBIERTOS',
#  'LINAGLIPTINA/METFORMINA 2.5MG/1000MG COMPRIMIDO RECUBIERTO. FECHA DE VENCIMIENTO SUPERIOR A 1 AÑO DESDE LA FECHA DE ENTREGA. NO SE ACEPTAN CARTAS DE CANJE',
#  'METFORMINA 1000MG COMP DE L.P .',
#  'LINAGLIPTINA/METFORMINA 2.5/1000 MG. CAJA DE 60 COMPRIMIDOS.',
#  'INS ASPARTIC SOL/INY100UI/ML FLEXPEN+AGU (100005592)',
#  'GLICENEX SR 1000 MG X 30',
#  'SITAGLIPTINA/METFORMINA 50/850 LIBERACION PROLONGADA X 56 COMPRIMIDOS\r\r\n',
#  'INSULINA GLANGINA 300 UI / ML LÁPIZ 1.5 ML',
#  'INSULINA ULTRARAPIDA ASPARTATA 100 U/ML PENFILL COD INT.40400170053',
#  'TRESIBA FLEXTOUCH 100 U/ML DISPOSITIVO PRELLENADO (O EQUIVALENTE)',
#  'METFORMINA 750 MG, LIBERACION PROLONGADA, CAJA 30 COMPRIMIDOS',
#  'EMPAGLIFLOZINA 12,5/METFORMINA 850MG X 60 COMPRIMIDOS RECUBIERTOS, CAJA 60 COMPRIMIDOS RECUBIERTOS',
#  'METFORMINA 850 MG CM\r\r\n\r\r\n\r\r\n\r\r\n\r\r\n\r\r\n\r\r\n\r\r\n\r\r\n\r\r\n\r\r\n\r\r\n\r\r\n',
#  'METFORMINA 1000MG COMPRIMIDOS DE LIBERACIÓN PROLONGADA SIMILAR HIPOGLUCIN LP',
#  'VILDAGLIPTINA/METFORMINA 50/1000 MG., CAJA 56 COMPRIMIDOS',
#  'METFORMINA CLORHIDRATO 850 MG; CAJA X 60 COMPRIMIDOS BIOEQUIVALENTE, CON EXCIPIENTES: POLIVIDONA, CROSPOVIDONA, CELULOSA MICROCRISTALINA, ACIDO ESTEÁRICO, ALCOHOL POLIVINILICO, DIÓXIDO DE TITANIO, MACROGOL 3000, TALCO.',
#  'METFORMINA 850 MG COMPRIMIDO\r\r\n',
#  'HIPOGLUCIN 750LP (30 COMP)',
#  'ÍTEM N°20.- JERINGA ESTÉRIL DESECHABLE PARA INSULINA CON AGUJA FIJA 0,5 ML. (50 UI), AGUJA FIJA 29 A 31 G X 6 MM. LARGO, CON TOPE DE GOMA.',
#  'METFORMINA COMPRIMIDOS RECUBIERTOS LIBERACIÓN PROLONGADA,750MG,1) PRESENTACIÓN VENTA PÚBLICO MÁS CONVENIENTE DESDE PUNTO DE VISTA PRECIO\r\r\n2) AL MENOS 24 MESES DE EFICACIA\r\r\n3) FABRICADO EN CHILE\r\r\n4) CERTIFICADO CUMPLIMIENTO BUENAS PRACTICAS DE FABRICACIÓN',
#  '"SAXAGLIPTINA 5 MG + METFORMINA CLORHIDRATO 1000 MG X 28 COMPRIMIDOS RECUBIERTOS, CON LA MARCA ""2,5/1000"" IMPRESA EN UN LADO."',
#  'VILDAGLIPTINA 50MG/METFORMINA 1000MG CAJA X 56 COMP',
#  '224-4523000  JERINGA INSULINA CON AGUJA INTERCAMBIABLE 1 ML',
#  'SAXAGLIPTINA/METFORMINA SIN ESPECIFICAR CM 5/1000 MG\r\r\n',
#  'INSULINA ASPARTATO 100 UI/ML LAPIZ DESECHABLE (2620231)\r\r\n',
#  'METFORMINA 1000 MGS XR',
#  'METFORMINA DE 1000MG DE LIBERACIÓN PROLONGADA',
#  'GLAFORNIL 850 MG - METFORMINA 850 MG (REFERENTE TERAPÉUTICO)',
#  '216-5166 INSULINA ASPARTO RECOMBINANTE 100 U/ML 3 ML CARTRIDGE',
#  'GLAUPAX XR 1000 MG CAJA X 30 COM.(O EQUIVALENTE)',
#  '303031\tCURVA DE INSULINA (X5)\r\r\n',
#  'METFORMINA CLORHIDRATO 500 MG/GLIBENCLAMIDA 5 MG EN COMPRIMIDOS',
#  'METFORMINA 1000 LP; COMPRIMIDOS DE LIBERACIÓN PROLONGADA\r\r\nBLÍSTER IMPRESO DE ALUMINIO + PVC Y LÁMINA PVC+PVDC INCOLORO\r\r\nEXCIPIENTES: HIPROMELOSA, LACTOSA MONOHIDRATO, CELULOSA\r\r\nMICROCRISTALINA, MAGNESIO ESTEARATO. DESEABLE EN ENVASE CLÍNICO; SIMILAR HIPOG',
#  'METFORMINA 1000 MG X 30 COMP. LP',
#  'METFORMINA COMP 100 MG XR',
#  'METFORMINA 850 COMPRIMIDO RECUBIERTO X 60 \r\r\n\r\r\n',
#  'METFORMINA LIBERACIÓN PROLONGADA 100MG, COMPRIMIDOS. SEGÚN TÉRMINOS DE REFERENCIA.',
#  'METFORMINA CLORH. 1000 MG\xa0EN COMPRIMIDOS DE LIBERACION PROLONGADA.  ENVASE CON 60 COMPRIMIDOS',
#  'SUMINISTRO DE GLIBENCLAMIDA/METFORMINA 5/500 MG CM/CM REC',
#  'ENVASE DE 56 COMPRIMIDOS QUE CONTIENE: SITAGLIPTINA 50 MG; METFORMINA CLORHIDRATO 850 MG. SIMILAR O IGUAL A JANUMET 50/850 MG.',
#  'ENVASE DE 56 COMPRIMIDOS QUE CONTIENE: SITAGLIPTINA 50 MG; METFORMINA CLORHIDRATO 500 MG. SIMILAR O IGUAL A JANUMET 50/500 MG.',
#  'GLAFORNIL 1000 MG CAJA X 30 COM. (O EQUIVALENTE)',
#  'LINAGLIPTINA/ METFORMINA, SIMILAR TRAYENTA DUO 2,5/1000 MG X 60 COMP.',
#  'EMPAGLIFLOZINA 12,5 MG/METFORMINA 850 MG X60 **JARDIANCE DUO**',
#  'METFORMINA 1000 MG/LINAGLIPTINA 2,5 MG, ENVASE CON 60 COMPRIMIDOS. FECHA DE VENCIMIENTO NO MENOR A 12 MESES.',
#  'INSULINA CRIS. HUMAN 100 UI/ML FAM 10 ML',
#  'SUMINISTRO DE METFORMINA CLORHIDRATO 500 MG/GLIBENCLAMIDA 5 MG EQUIVALENTE A GLUKAUT 500/5, CAJA 60 COMPRIMIDOS RECUBIERTOS',
#  'METFORMINA 850 MG CM/CM REC LIB. PROLONG',
#  'INSULINA HUMANA ISOFANA (NPH) SOL. INYECTABLE 100 IU/ML',
#  'METFORMINA CLORHIDRATO CM 850MG',
#  'METFORMINA CLORHIDRATO 1000 MG. ENVASE X 30 COMP. LIBERACIÓN PROLONGADA. SIMILAR GLAUPAX 1000 XR',
#  'METFORMINA 750 MG  X 60 COMP LIBERACION PROLONGADA\r\r\n(GLAFORNIL XR, GLICENEX SR, GLIFORTEX XR, GLUCOPAGE XR, HIPOGLUCIN LP, METFORMINA HCL)',
#  'JALRA M 50/850 MG',
#  'INSULINA HUMANA ISÓFANA BIOSINTÉTICA 100UI/ML FRASCO 10ML SIMILAR INSULINA INSULATARD HM',
#  'FA01-0090\t METFORMINA 850 MG COMP (COMP)',
#  'METFORMINA 850 MG CMBIOEQUIVALENTE',
#  'INSULINA DEGLUDEC 100 UI/ML EN LAPIZ DESECHABLE, ESPECIFICAR MARCA, CARACTERISTICAS Y PRESENTACION. CONSUMO PROMEDIO MENSUAL 40 UNIDADES APROXIMADAS.',
#  'METFORMINA 500MG COMPRIMIDO DE LIBERACIÓN PROLONGADA. DESPACHO DIFERIDO MENSUAL DE 6.600 COMPRIMIDOS MENSUALES. FECHA VENCIMIENTO MAYOR A 1 AÑO DESDE LA RECEPCIÓN. NO SE ACEPTAN CARTAS DE CANJE',
#  'METFORMINA 1.000 MG LIBERACION PROLONGADA',
#  'LINAGLIPTINA 2.5 MG/ METFORMINA 500 MG. X 60 COMPRIMIDOS\r\r\n',
#  'METFORMINA 850MG COMPRIMIDOS/ COMPRIMIDO RECUBIERTO',
#  'EMPAGLIFLOZINA 12.5 MG Y CLORHIDRATO DE METFORMINA 850 MG, SIMILAR A JARDIANCE DUO 12,5/850',
#  'CAJAS DE 56 COMPRIMIDOS DE METFORMINA DE 1000 MG. + VILDAGLIPTINA. - SE SUGIERE GALVUS O SIMILAR COMPOSICIÓN',
#  'SUMINISTRO DE SAXAGLIPTINA/METFORMINA CLORHIDRATO 5 MG/1000 MG EQUIVALENTE A KOMBIGLYZE XR 5/1000MG, CAJA 28 COMPRIMIDOS RECUBIERTOS DE LIBERACION PROLONGADA',
#  'GLIFORTEX XR 1000 MG, METFORMINA, CAJA DE 30 COMPR',
#  'SITAGLIPTINA/METFORMINA 50/1000 MG',
#  '262-0065\tINSULINA GLARGINA (DNA RECOMBINANTE) 100 UI/ML',
#  'JANUMET 50/1000 X 56 COMP',
#  'SITAGLIPINA 50 MG + METFORMINA 850 MG X 56 COMPRIMIDOS, SIMILAR A JANUMET 50/850 MG X 56 COMPRIMIDOS',
#  '1093058-4 CADA COMP. RECUB. CONTIENE 50 MG DE SITAGLIPTINA Y 850 MG DE METFORMINA ENVASE CONTENIENDO 56 COMPRIMIDOS O EQUIVALENTE A JANUMET 50/850 X 56 COMP.',
#  'JANUMET 50/1000 X56',
#  'GLIFORTEX XR 500 MG',
#  'SITAGLIPTINA 50 MG /METFORMINA MG 1000 X 56 COMPRIMIDOS.',
#  'SITAGLIPTINA 50 MG + METFORMINA 1000 MG X 56 COMPRIMIDOS DE LIBERACIÓN PROLONGADA, SIMILAR A JANUMET 50/1000 MG XR X 56 COMP.',
#  'METFORMINA CLORHIDRATO 850 MG CAJA 60 COMPRIMIDOS RECUBIERTOS BE',
#  'METFORMINA XR 1000 MG CM LIBERACION PROLONGADA',
#  'METFORMINA 850 MG COMPRIMIDOS RECUBIERTOS',
#  'GLUKAUT 2.5/500 MG',
#  'INSULINA GLULISINA 300 UI/3 ML (100 UI/ML) INYECTABLE LÁPIZ PRELLENADO',
#  'METFORMINA COMPRIMIDO 500 MG\r\r\n',
#  '2620056 INSULINA DEGLUDEC 100UI/ML 3ML LAPIZ SOL INY 300UI TOTAL MULTIDOSIS',
#  'METFORMINA 850 MG',
#  'METFORMINA 850 MG\r\r\n',
#  'EMPAGLIFLOZINA 12,5MG/METFORMINA 850MG X60',
#  'VIDAGLIPTINA + METFORMINA 50/1000 MG X 56 COMP',
#  'INSULINA CRISTALINA 100 UI/ML FC 10 ML',
#  'JERINGA DESECHABLE PARA INSULINA CON AGUJA FIJA 1 ML (100UI)AGUJA 29 A 30G X 6MM',
#  'METFORMINA 850 MG COMPRIMIDOS. \r\r\n(DE PREFERENCIA EN ENVASES CLÍNICOS DE 1.000 COMPRIMIDOS, NO EXCLUYENTE)',
#  '3.- ELECSYS INSULINA 100 TEST, CÓDIGO HOSPITAL LAB09442, SEGÚN BASES TÉCNICAS, ARTÍCULO N°2.-',
#  'VILDAGLIPTINA + METFORMINA, COMPRIMIDOS RECUBIERTOS,50 MG + 1000 MG, 1) PRESENTACIÓN VENTA PÚBLICO MÁS CONVENIENTE DESDE PUNTO DE VISTA PRECIO\r\r\n2) AL MENOS 24 MESES DE EFICACIA\r\r\n3) FABRICADO EN CHILE\r\r\n4) CERTIFICADO CUMPLIMIENTO BUENAS PRACTICAS DE FABRIC',
#  'METFORMINA 750 MG. COMPRIMIDO DE LIBERACIÓN PERLONGADA, ENVASE RESISTENTE CON SELLO QUE ASEGURE INVIOLABILIDAD DEL CONTENIDO.',
#  'AGUJAS INSULINA ULTRAFINE 4MM',
#  '216-5171 INSULINA DEGLUDEC 100UI/ML 3 ML LAPIZ PRELLENADO',
#  'METFORMINA (CLORHIDRATO  ) 500 MG  COMPRIMIDO DE  LIBERACIÓN PROLONGADA /XR-LP/  DOCUMENTACION TECNICA SOLICITADA : CERTIFICADO DE FARMAVIGILANCIA,  CERTIFICADO DE ANALISIS DE  LOTE , BIOEQUIVALENCIA, ESTADO DEL REGISTRO SANITARIO, ENVASE COMERCIAL O ENVA',
#  'INSULINA ANÁLOGA DE ACCIÓN BIFÁSICA. 30% ASPÁRTICA SOLUBLE Y 70% ASPÁRTICA RETARDADA CON PROTAMINA 100 UI/ML EN PRESENTACIÓN DE LÁPIZ PRELLENADO DESECHABLE; EQUIVALENTE A NOVO MIX 30 100 UI/ML 5 FLEXPEN 3 ML',
#  'LO QUE SE REQUIERE ES METFORMINA 850 MG',
#  'METFORMINA / SITAGLIPTINA 50/1000 MG POR 56 COMPRIMIDOS. JANUMET O SIMILAR.',
#  'LANTUS SOLOSTAR 100 U.I/ML X LAPICERA PRELLENADA 3 ML\r\r\n',
#  'METFORMINA 850 MG COMPRIMIDOS RECUBIERTOS ENVASE 30 COMPRIMIDOS RECUBIERTOS',
#  'METFORMINA 850 MG X 30 COMPRIMIDOS\r\r\n',
#  'ÍTEM N°19.- JERINGA ESTÉRIL DESECHABLE PARA INSULINA CON AGUJA FIJA 1ML. (100 UI), AGUJA 29 A 30 G X 8 MM. LARGO CON TOPE DE GOMA.',
#  'LINAGLIPTINA 2,5 MG / METFORMINA 500 MG X 60 COMP. RECUBIERTOS, CAJA 60 COMPRIMIDOS',
#  'COMPRIMIDOS RECUBIERTOS DE VILDAGLIPTINA 50 MG.; METFORMINA CLORHIDRATO 850 MG. CAJAS DE 56 COMPRIMIDOS RECUBIERTOS C/U. SIMILAR A GALVUSMET 50/850. VENCIMIENTO MÍNIMO 2022.',
#  'METFORMINA CLORHIDRATO 500.0 MG, GLIBENCLAMIDA 2,5 MG',
#  '1400019\tINSULINA RAPIDA HUMANA ADN RECOMBINANTE 100 U/ML X 10 ML SC, SIMILAR ACTRAPID\tUSO OCASIONAL\tSOL. INY. (FC)\r\r\n',
#  'METFORMINA 500 MG CAJA POR 30 COMPRIMIDOS\r\r\n',
#  'METFORMINA 1000 MG , ENVASE COMERCIAL \r\r\n',
#  'METFORMINA 500 MG CM RECUBIERTO',
#  'METFORMINA 750 MG LIBERACION PROLONGADA\r\r\n',
#  'VILDAGLIPTINA 50 MG + METFORMINA CLORH. 1000 MG ENVASE CONTENIENDO 56 COMPRIMIDOS',
#  'INSULINA NPH 100 UI/ML FC 10 ML',
#  'LINAGLIPTINA 2,5 MG / METFORMINA 1000 MG X 60 COMP RECUBIERTOS\r\r\n',
#  'ITEM N° 34 ,INSULINA LENTA HUMANA 100UI. SEGÚN ESPECIFICACIONES TÉCNICAS.',
#  'INSULINA CRISTALINA HUMANA MONOCOMPONENTE ADN RECOMBINANTE SUSP INYECTABLE 100 UI FA 10 ML',
#  'GALVUS MET 50/850 MG CAJA X 56 COM. (O EQUIVALENTE)',
#  '4000 COMPRIMIDO METFORMINA 1000 MG XR',
#  'SOBRE TERMICO PARA INSULINA 20 X 25 CM',
#  'INSULINA DEGLUDEC, AMPOLLA, 100 UI/ML,1) PRESENTACIÓN VENTA PÚBLICO, MÁS CONVENIENTE DESDE PUNTO DE VISTA PRECIO \r\r\n2) AL MENOS 24 MESES DE EFICACIA\r\r\n3) CERTIFICADO QUE ACREDITE QUE ES FABRICADO EN PAÍSES CON AGENCIAS DE ALTA VIGILANCIA SANITARIA (EE.UU O',
#  'METFORMINA 1000 MG; SITAGLIPTINA 50 MG. COMPRIMIDOS RECUBIERTOS. ENVASE SELLADO, RESISTENTE E INADULTERADO. SIMILAR A JANUMET',
#  'METFORMINA 500 MG LP. COMPRIMIDO O CAPSULA',
#  'INSULINA GLULISINA FA 100 UI/ML ULTRA RAPIDA APLICADOR INYECTABLE\r\r\n',
#  'EMPAGLIFLOZINA 12,5/METFORMINA 850 MG X 60 COMPRIMIDOS',
#  'GALVUS MET 50/850 X 56 COMPRIMIDOS',
#  'JANUMET 1000/50 MG\t\r\r\nENVASE DE 56 COMPRIMIDOS',
#  'INSULINA GLULISINA 100 UI/ML LAPIZ, APIDRA O SIMILAR DEBE INCLUIR AGUJAS, (PARA DESPACHO PARCIALIZADO DE 300 UNID MENSUALES)',
#  'METFORMINA 500 MG, ENVASE CON 30 COMPRIMIDOS DE LIBERACIÓN PROLONGADA. FECHA DE VENCIMIENTO NO MENOR A 8 MESES.',
#  'METFORMINA 850 MG. PRESENTAR FECHA DE VENCIMIENTO. REVISAR BASES ADJUNTAS',
#  '- JANUMET XR 50/1000 => SITAGLIPTINA 50 MG  /METFORMINA 1000 MG  X 56 TABLETAS DE LIBERACION PROLONGADA SIMILAR A JANUMET XR',
#  'METFORMINA 500 MG/GLIBENCLAMIDA 5 MG X CAJA CON 30 A 60 COMPRIMIDOS',
#  'INSULINA GLARGINA SOLUCIÓN INYECTABLE CONTENIENDO 3.6378 MG EQUIVALENTES A 100 UI DE INSULINA RECOMBINANTE HUMANA. ENVASE CONTENIENDO 1 LAPIZ APLICADOS DESECHABLE DE 3 ML. EQUIVALENTE A LANTUS',
#  'FA03-0005\tINSULINA ASPARTATO 100 UI/ML LAPIZ 3 ML (ULTRA RAIDA) (UI)',
#  'INSULINA BASAL',
#  'INSULINA HUMANA MONOCOMPONENTE ISOFANICA NPH ADN RECOMBINANTE 100 U.I./ML SUSP INY 10 ML',
#  'METFORMINA CLORHIDRATO CM 850 MG \xa0\r\r\n',
#  'METFORMINA 1000 MG LIBERACION PROLONGADA\r\r\n',
#  'VILDAGLIPTINA 50 MG + METFORMINA 500 MG X 56 COMPRIMIDOS SIMILAR A GALVUS 50/500 MG X 56 COMPRIMIDOS',
#  'EMPAGLIFLOZINA /METFORMINA 12.5 MG; 1000 MG., CAJA 60 COMPRIMIDOS RECUBIERTOS',
#  'INSULINA HUMANA RECOMBINANTE 100UI/ML, SOLUCION INYECTABLE EN VIAL DE 10 ML, INSULINA HUMANAN DE ACCIÓN RÁPIDA',
#  '"JERINGA DESECHABLE INSULINA 1 CC-100 UI TOPE DE GOMA AGUJA FIJA 29-30G*0.5"". CON VENCIMIENTO SUPERIOR A 12 MESES."',
#  'XIGDUO XR 10/1000 MG X 28COMP O SIMILAR',
#  'METFORMINA 750 MG LP. COMPRIMIDO O CAPSULA',
#  'HIPOGLUCIN LP 500MG X 60 COMP O SIMILAR',
#  '50-262-100-354-00\tARC INSULINA ASSAY (KIT X 100 DET)\r\r\n',
#  'METFORMINA CLORHIDRATO 1000 MG, COMPRIMIDOS DE LIBERACION PROLONGADA, ENVASADOS EN BLISTER DE PVC O SIMILAR Y ALUMINIO IMPRESO, ENVASE 30 COMPRIMIDOS DE LIBERACIÓN PROLONGADA. CERTIFICACIÓN FDA O EMA, GMP DE LA PLANTA PRODUCTORA (DESPACHO PARCIALIZADO)\r\r\n\r',
#  'HIPOGLUCIN 850MG',
#  'INSULINA   CRISTALINA FRASCOS AMPOLLA 10 ML 100 UI/ML SOLUCION INYECTABLE',
#  'METFORMINA 850 MG, CAJA X 60 COMPRIMIDOS RECUBIERTOS',
#  'XIGDUO 10/1000MG X 28 COMPRIMIDO',
#  'INSULINA LENTA , SUSPENSIÓN INYECTABLE 100 UI/ML, PENFIL ( CARTRIDGE) DE 3 ML.CARTRIDGE',
#  'GLAFORNIL XR 1.000 COMP.',
#  'INSULINA ULTRALENTA DETEMIR 100UI/ML X 3ML (TIPO LEVEMIR O EQUIVALENTE) DISPOSITIVO INYECTOR DESECHABLE',
#  'INSULINA HUMANA CRISTALINA 100UI/ML SOLUCIÓN INYECTABLE 10ML',
#  'EMPAGLIFOZINA / METFORMINA 12.5/850 MG., CAJA 60 COMPRIMIDOS',
#  'SITAGLIPTINA + METFORMINA 50/1000 MG X 56 COMP',
#  'INSULINA CRISTALINA AMPOLLA 10 ML 100 UI/ML',
#  '262-0003\tINSULINA RÁPIDA 100 UI/ML',
#  'INS ASPARTIC SOL/INY100UI/ML PENFILL+AGU (100005593)',
#  'METFORMINA/SAXAGLIPTINA, 1000/5MG COMPRIMIDO RECUBIERTO DE LIBERACION EXTENDIDA.',
#  'INSULINA DEGLUDEC (TRESIBA) 100 UI/ML SOL. INYECTABLE',
#  'ELECSYS INSULIN, 100 DET.',
#  'VILDAGLIPTINA + METFORMINA 50/850 MG',
#  'CAJA DE 1 LAPICERA INYECTABLE CONTIENE: 300 UNIDADES DE INSULINA GLARGINA (EQUIVALENTES A 10.91 MG). CADA LAPICERA CONTIENE 1.5 ML DE SOLUCIÓN INYECTABLE, EQUIVALENTES A 450 UNIDADES. SIMILAR A TOUJEO',
#  'JERINGA INSULINA C/AGUJA INTERCAMBIABLE',
#  'METFORMINA 1000/SITAFLIPTINA 50MG *30 **A.SOCIAL**',
#  'METFORMINA CLORHIDRATO 750 MG COMPRIMIDOS DE LIBERACIÓN PROLONGADA. EQUIVALENTE A GLICENEX SR 750 MG 30 COMP\r\r\n',
#  'METFORMINA SITAGLIPTINA + METFORMINA, COMPRIMIDOS RECUBIERTOS, 50 MG + 1000 MG,1) PRESENTACIÓN VENTA PÚBLICO MÁS CONVENIENTE DESDE PUNTO DE VISTA PRECIO\r\r\n2) AL MENOS 24 MESES DE EFICACIA\r\r\n3) FABRICADO EN CHILE\r\r\n4) CERTIFICADO CUMPLIMIENTO BUENAS PRACTICAS',
#  'CAJAS DE VILDAGLIPTINA 50MG/METFORMINA 1000MG X 56 COMP.',
#  'METFORMINA CLORHIDRATO 500 MG. COMPRIMIDOS DE LIBERACIÓN PROLONGADA.; EQUIVALENTE A HIPOGLUCIN LP 500 60 COMP BEQ\r\r\n',
#  'METFORMINA 850MG. COMPRIMIDOS RECUBIERTOS, CON FECHA VENCIMIENTO ENERO 2023.',
#  'METFORMINA 750XR (30COMP)',
#  'VILDAGLIPTINA 50 MG + METFORMINA 1000 MG X 56 COMPRIMIDOS SIMILAR A GALVUS MET 50/1000 MG X 56 COMPRIMIDOS',
#  'METFORMINA XR 750 MG X 30 COMP.',
#  'XIGDUO XR 10/1000 MG 28 COM. (O EQUIVALENTE)',
#  'METFORM/DAPAGLIFLO 1000/10 MG CM LIB PRO(100004978)',
#  'EMPAGLIFOZINA 12.5MG / 850MG',
#  'METFORMINA, 850MG COMPRIMIDOS',
#  'METFORMINA 850MG, COMPRIMIDO RECUBIERTO (F)',
#  'INSULINA HUMANA CRISTALINA FRASCO AMPOLLA 100 UI/ML SOLUCIÓN INYECTABLE.VENCIMIENTO MAYOR A 18 MESES DESDE EL ENVÍO DE OC.',
#  '1092019-7 CADA ML DE SOLUCIÓN INYECTABLE CONTIENE INSULINA  \r\r\nGLARGINA 3,64MG EQUIVALENTE A 100 UI DE INSULINA HUMANA HIPOGLICEMIANTE ANTI-DIABETICO O EQUIVALENTE A     INS.LANTUS-SOL.3 ML LAPIZ',
#  'LINAGLIPTINA + METFORMINA 2,5/1000 MG X 60 COMP.',
#  'BOLSA TÉRMICA DE TRANSPORTE PARA INSULINA 19X25CMS. APROX. COTIZAR POR UNIDAD. INDICAR VENCIMIENTO Y MONTO MÍNIMO DE FACTURACIÓN Y DESPACHO POR LINEA.',
#  'METFORMINA COMPRIMIDOS RECUBIERTOS LIBERACIÓN PROLONGADA, 500MG,1) PRESENTACIÓN VENTA PÚBLICO MÁS CONVENIENTE DESDE PUNTO DE VISTA PRECIO\r\r\n2) AL MENOS 24 MESES DE EFICACIA\r\r\n3) FABRICADO EN EL EXTRANJERO\r\r\n4) CERTIFICADO CUMPLIMIENTO BUENAS PRACTICAS DE FAB',
#  'INSULINA NPH 100 UI/ML, LÁPIZ 3 ML',
#  'JERINGA INSULINA 1CC UI C/AG.INT 29G X 8 MM ESTÉRIL',
#  'INSULINA CRISTALINA\tSOLUCION INYECTABLE\t\t100 UI/ML FC 10 ML',
#  'GLUKAUT 500/5MG',
#  'GLAUPAX XR 1000 MG X 30',
#  'METFORMINA LIBERACION PROLONGADA XR 1000 MG',
#  'SITAGLIPTINA/METFORMINA 50/850 MG X 28 COMPRIMIDOS',
#  'GLIFORTEX XR 1000 MG X 30 COMP',
#  'METFORMINA/VILDAGLIPTINA 1000/50 MG. COMPRIMIDOS. ENVASE SELLADO, RESISTENTE E INADULTERADO. SIMILAR A GALVUS MET',
#  'CAJAS DE LINAGLIPTINA 2,5MG + METFORMINA 1000 MG X 60 COMP.',
#  'METFORMINA 500 MG  X 60 COMP\r\r\n(GLAFORNIL, GLICENEX, GLIDANIL, GLIFORTEX, GLUCOPAGE, HIPOGLUCIN, METFORMINA HCL)',
#  'METFORMINA 750 MG',
#  'METFORMINA 750 MG MG COMPRIMIDOS TETRARANURADOS, ENVASADOS EN BLISTER PVC O SIMILAR IMPRESO, ENVASE CONTENIDO 50 COMPRIMIDOS,  CERTIFICADO DEAPROBACIÓN FDA Y EMEA, CERTIFICACIÓN GMP PLANTA PRODUCTORA. DESPACHO PARCIALIZADO\r\r\n',
#  'SITAGLIPTINA + METFORMINA, COMPRIMIDOS RECUBIERTOS, 50 MG + 1000 MG, 1) PRESENTACIÓN VENTA PÚBLICO, MÁS CONVENIENTE DESDE PUNTO DE VISTA PRECIO \r\r\n2) AL MENOS 24 MESES DE EFICACIA\r\r\n3) CERTIFICADO QUE ACREDITE QUE ES FABRICADO EN PAÍSES CON AGENCIAS DE ALTA',
#  'INSULINA HUMANA RECOMBINANTE 100UI/ML, SOLUCIÓN INYECTABLE EN VIAL DE 10 ML, INSULINA HUMANA DE ACCIÓN RÁPIDA.',
#  '1300105\tMETFORMINA HCL 850 ACCIÓN SOSTENIDA\tUSO OCASIONAL \tCM REC.\r\r\n',
#  'METFORMINA + GLIBENCLAMIDA COMPRIMIDO 500/5 MG',
#  'METFORMINA 850 MG. COMPRIMIDOS. VENCIMIENTO MÍNIMO 2023.',
#  'VILDAGLIPTINA 50 MG / METFORMINA  1000 MG X 56 COMPRIMIDOS RECUBIERTOS',
#  'METFORMINA XR 1000 MG X 30 COMP REC\r\r\n',
#  'TRAYENTA DUO 2,5/850 X 60 COMP O SIMILAR',
#  '262-0012 INSULINA PROLONGADA (GLARGINA 300UI) LAPICERA PRELLENADA DESCARTABLE',
#  'METFORMINA XR 1000 MG\tENVASE DE 30 COMPRIMIDOS',
#  'LAB-0622\tINSULINA\tCAJA\t9',
#  'METFORMINA 850 MG.',
#  '1\tINSULINA GLARGINA 450 UI/1,5 ML (300 UI/ML) INYECTABLE EN LAPIZ PRELLENADO\tINYECTABLE\t12000',
#  'INSULINA INSULATARD (NPH) 100 U/ML X 10 ML',
#  'GLICACIDA 60 MG X 30 COMPRIMIDOS',
#  'INSULINA RETARDADA HUMANA 100 UI/ML 10 ML. FA. CON VENCIMIENTO SUPERIOR A 12 MESES.',
#  'METFORMINA 500 MG + GLIBENCLAMIDA 2.5 MG X 60 COMP O CAPS\r\r\n',
#  'CAJA DE 60 COMPRIMIDO CONTIENE: METFORMINA CLORHIDRATO 850 MG, COMPRIMIDOS RECUBIERTOS. SIMILAR A GLAUPAX',
#  'VILDAGLIPTINA/METFORMINA 50/850 X 56 SIMILAR A GALVUS MET',
#  'M01F0043 INSULINA LENTA NPH 100UI/ML FCO. 10',
#  'DAPAGLIFOZIN +  METFORMINA, COMPRIMIDOS LIBERACION PROLONGADA, 5 MG + 1000 MG, 1) PRESENTACIÓN VENTA PÚBLICO MÁS CONVENIENTE DESDE PUNTO DE VISTA PRECIO\r\r\n2) AL MENOS 24 MESES DE EFICACIA\r\r\n3) FABRICADO EN CHILE\r\r\n4) CERTIFICADO CUMPLIMIENTO BUENAS PRACTICAS',
#  'METFORMINA CLORHIDRATO 850 MG CM\r\r\n',
#  'METFORMINA 850 MG ENVASE X 30 O 60 COM O COM REC \r\n',
#  'CLONAZEPAM 0,5 MG POR 30 COMPRIMIDOS',
#  'METFORMINA 850 MG ENVASE 30 COMPRIMIDOS. MAXIMO A PAGAR $450.-',
#  'METFORMINA 1000MG LIBERACION PROLONGADA X 30',
#  'INSULINA DEGLUDEC 100 U/ML 1 X 3 ML SIMILAR A TRESIBA FLEXTOUCH',
#  'KOMBIGLYZE XR 2,5/1000 MG X 56 CM. RECUBIERTO (O EQUIVALENTE)',
#  'JANUMET COMPRIMIDO 50MG',
#  '01-001-262-013\r\r\nINSULINA ULTRALENTA (GLARGINA) 100 UI/ML APLICADOR INY PRELL 3 ML',
#  'METFORMINA 750 MG, ENVASE CON 30 COMPRIMIDOS DE LIBERACIÓN PROLONGADA, MEDICAMENTO ORIGINAL O INNOVADOR. FECHA DE VENCIMIENTO NO MENOR A 8 MESES.',
#  'JANUMET XR  50/1000 X 56',
#  '1093058-4 CADA COMP RECUB CONTIENE 50MG DE SITAGLIPTINA Y 850MG DE METFORMINA ENVASE CONTENIENDO 56 COMP. O EQUIVALENTE A  JANUMET 50/850 X 56 COMP.',
#  'INSULINA DEGLUDEC LAPIZ SIMILAR A TRESIBA',
#  'METFORMINA 850 MG CAJA POR 1000 COMPRIMIDOS\r\r\n',
#  'METFORMINA/ VILDAGLIPTINA 850/50MG POR 56 COMPRIMIDOS. GALVUS O SIMILAR.',
#  'LO QUE SE REQUIERE ES METFORMINA 100 MG XR',
#  'EMPAGLIFOZINA METFORMINA 12.5/850 MG, CAJA DE 60 COMPRIMIDOS',
#  'SUMINISTRO DE INSULINA CRIS. HUMANA 100 UI/ML FRASCO 10ML',
#  'INSULINA GLARGINA 300 U/ML (INSULINA GLARGINA HUMANA RECOMBINANTE) DISPOSITIVO TIPO LAPIZ. PRE CARGADO *OFERTA DEBE INCLUIR BONIFICACIÓN DE 10 AGUJAS 31 GX 4 MM POR LÁPIZ*',
#  'DAPAGLIFLOZINA10 MG/ METFORMINA 1000 MG, CAJA X 28 COMPRIMIDOS DE LIBERACIÓN PROLONGADA (EQUIVALENTE A XIGDUO XR)',
#  'METFORMINA 850 MG ENVASES CLINICOS X 1000 COMPRIMDOS\r\r\n',
#  'METFORMINA 850 MG + SITAGLIPTINA 50 MG, ENVASE CON 56 COMPRIMIDOS. FECHA DE VENCIMIENTO NO MENOR A 12 MESES.',
#  'INSULINA HUMANA 30% SOLUBLE/70% ISOFANICA 100 UI/ML 10 ML COD. INT.40400170030\r\r\n',
#  'INSULINA HUMANA RECOMBINANTE GLARGINA LENTA LAPIZ AUTOINYECTABLE',
#  'GLAUPAX XR 500 MG CAJA X 30 COM. (O EQUIVALENTE)',
#  'INSUÑLINA DEGLUDEC 100 UI /ML X 3 ML SIMILAR A TRESIBA FLEX TOUCH',
#  'METFORMINA XR 500 MG\tENVASE DE 30 COMPRIMIDOS',
#  'METFORMINA 100 MG CAJA X 30 COM. (O EQUIVALENTE)',
#  'METFORMINA 500 MG MG COMPRIMIDOS DE LIBERACION PROLONGADA, ENVASADOS EN BLISTER PVC O SIMILAR IMPRESO, ENVASE CONTENIDO 30 COMPRIMIDOS,  CERTIFICADO DEAPROBACIÓN FDA Y EMEA, CERTIFICACIÓN GMP PLANTA PRODUCTORA. DESPACHO PARCIALIZADO',
#  'FA03-0005\tINSULINA ASPARTATO 100 UI/ML LAPIZ 3 ML (ULTRA RAPÍDA) INCLUYE 15 AGUJAS POR CADA LAPIZ',
#  'SAXAGLIPTINA 2,5MG/METFORMINA 1000 MG X 56 COMPRIMIDOS RECUBIERTOS DE LIBERACIÓN EXTENDIDA\r\r\n',
#  'METFORMINA 1000 MG  X 60 COMP LIBERACION PROLONGADA\r\r\n(GLAFORNIL XR, GLICENEX SR, GLIFORTEX XR, GLUCOPAGE XR, HIPOGLUCIN LP, METFORMINA HCL)',
#  'METFORMINA CLORHIDRATO 750 MG, COMPRIMIDOS DE LIBERACION PROLONGADA, ENVASADOS EN BLISTER DE PVC O SIMILAR Y ALUMINIO IMPRESO, ENVASE 30 COMPRIMIDOS DE LIBERACIÓN PROLONGADA. CERTIFICACIÓN FDA O EMA, GMP DE LA PLANTA PRODUCTORA (DESPACHO PARCIALIZADO)\r\r\n',
#  'METFORMINA 750MG X30COMP',
#  'INSULINA',
#  'EMPAGLIFLOZINA 2,5 MG/ METFORMINA 850 MG. ENVASE CONTENIENDO 60 COMPRIMIDOS RECUBIERTOS. JARDIANCE DUO O SIMILAR.',
#  'METFORMINA 850 MG. PACIENTES INTOLERANTES METFORMINA GENÉRICA EXCIPIENTES: POLIVIDONA K30, ESTEARATO DE MAGNESIO, METILHIDROXIPROPILCELULOSA COMPRIMIDOS PARA PACIENTES INTOLERANTES METFORMINA GENÉRICA)ENVASE CLINICO EQUIVALENTE GLAFORNIL.',
#  'INSULINA GLARGINA HUMANA RECOMBINANTE 300 UI/ML SOLUCIÓN INYECTABLE PARA ADMINISTRACIÓN SUBCUTÁNEA. DISPOSITIVO PRELLENADO DE VIDRIO DESCARTABLE DE 1,5 ML.',
#  'GLIBENCLAMIDA 5 MG + METFORMINA 500 MG COMPRIMIDO',
#  'METFORMINA XR 1.000 MG',
#  'GALVUS MET 50/500MG',
#  'INSULINA ASPARTATO CARTRIDGE 3 ML',
#  'METFORMINA 500/GLIBENCLAMIDA  MG.',
#  'CAJAS LINAGLIPTINA 2,5 MG/METFORMINA 850 MG, SIMILAR A TRAYENTA DUO 2,5/850 MG X 60 COMPRIMIDOS',
#  'EMPAGLIFLOZINA 12.5 MG Y CLORHIDRATO DE METFORMINA 850 MG X 60 COMP REC SIMILAR JARDIANCE DUO',
#  '"AGUJA 31G 1/2"" X 4MM CAJA 100 UNIDADES"',
#  'JARDIANCE DUO 12,5/1000(60 COMPRIMIDOS)',
#  'LINAGLIPTINA 2.5 MG / METFORMINA 500 MG\r\r\n',
#  'EMPAGLIFLOZINA12.5 MG+METFORMINA 850 MG. CAJA X 60 COMP.REC. SIMILAR A JARDIANCE DUO . ... .. .. . . . . ..(SE ADJUNTAN BASES ADMINISTRATIVAS Y TÉCNICAS)\r\r\n',
#  'LINAGLIPTINA 2,5 MG; METFORMINA 1000 MG ENVASE DE 60 COMPRIMIDOS (EQ A TRAYENTA DUO). MAXIMO A PAGAR $27.000',
#  'INSULINA NPH LÁPIZ 300 UI /ML (EJ: PENFILL INSULATARD O HUMULIN U OTRAS',
#  'EMPAGLIFOZINA  12,5 MG / METFORMINA 850 MG, ENVASE CON 60 COMPRIMIDOS. FECHA DE VENCIMIENTO NO MENOR A 12 MESES.',
#  'METFORMINA 1000MG\r\r\nLIBERACIÓN PROLONGADA',
#  '2628453 INSULINA NPH HM 100 U/ML 10 ML FRASCO AMPOLLA SOL INY',
#  'INSULINA GLARGINA 100 UI/ML FA ACCIÓN ULTRA LENTA APLICADOR INYECTABLE TIPO LÁPIZ 3 ML',
#  'METFORMINA 850 MG.,  CAJA DE 1000 COMPRIMIDOS',
#  'JANUMET COM. 50/850 MG CAJA X 56 COM. (O EQUIVALENTE)',
#  'METFORMINA COMPRIMIDOS 500MG, 1) PRESENTACIÓN VENTA PÚBLICO MÁS CONVENIENTE DESDE PUNTO DE VISTA PRECIO\r\r\n2) AL MENOS 24 MESES DE EFICACIA\r\r\n3) FABRICADO EN CHILE\r\r\n4) CERTIFICADO CUMPLIMIENTO BUENAS PRACTICAS DE FABRICACIÓN - EMITIDO POR ISP',
#  'SAXAGLIPTINA 2.5MG / METFORMINA 1000MG COMPRIMIDOS RECUBIERTOS DE LIBERACIÓN EXTENDIDA\r\r\n',
#  'INSULINA DEGLUDEC, SIMILAR TRESIBA 100 UI/ML, CAJA DE 1 DISPOSITIVO PRELLENADO DE 3 ML, USO SUBCUTANEO',
#  'CADA ML DE SOLUCIÓN INYECTABLE CONTIENE: 300 UNIDADES DE INSULINA GLARGINA (EQUIVALENTES A 10.91 MG).',
#  'JERINGA DE INSULINA 1 ML. FECHA DE VENCIMIENTO POSTERIOR A 18 MESES A CONTAR DE FEBRERO DE 2020.',
#  'JANUMET 50/1000 MG COMPRIMIDOS',
#  'METFORMINA  500 MG COMPRIMIDO DE LIBERACION PROLONGADA ENVASADO EN BLISTER',
#  'METFORMINA 1000 MG CAJA POR 30 COMPRIMIDOS DE LIBERACIÓN PROLONGADA\r\r\n',
#  'METFORMINA 850 MG BIOEQUIVALENTE (VENCIMIENTO SUPERIOR A 1 AÑO)',
#  'METFORMINA 1000MG ASOCIADO A SITAGLIPTINA 50MG, SEGÚN LO EXIGIDO EN BASES ADMINISTRATIVAS, TÉCNICAS Y ANEXOS ADJUNTOS.',
#  'METFORMINA 750 MG., LIBERACION PROLONGADA, CAJA 30 COMPRIMIDOS',
#  'DAPAGLIFOZINA/METFORMINA XR 5/1000  X 56 COMP SIMILAR A XIGDUO',
#  'CAJAS DE VILDAGLIPTINA 50MG/METFORMINA 850MG X 56 COMP..',
#  'GLIBENCLAMIDA 5 MG / METFORMINA 500 MG, CM',
#  'INSULINA GLARGINA REC 100 UI/ML FAM10 ML (100002079)',
#  'INSULINA GLARGINA LÁPIZ, SEGÚN LO INDICADO EN BASES ADMINISTRATIVAS, TÉCNICAS Y ANEXOS ADJUNTOS.',
#  'SUMINISTRO DE SITAGLIPINA 50 MG/METFORMINA CLORHIDRATO 1000 MG EQUIVALENTE A JANUMET 50/1000, CAJA 28 O 56 COMPRIMIDOS RECUBIERTOS',
#  'INSULINA CRISTALINA HUMANA 100 UI/ML FA 10 ML\xa0\r\r\n',
#  'SITAGLIPTINA/METFOMINA 50MG/1000 MG (SIMILAR JANUMET 50/1000 XR), CAJA DE 28 COMPRIMIDOS',
#  'JANUMET 850/50 MG\t\r\r\nENVASE DE 28 COMPRIMIDOS',
#  'METFORMINA 1000 MG COMPRIMIDO',
#  'METFORMINA 1000 MG XR COMPRIMIDOS',
#  'CAJA SITAGLIPTINA 50  MG / METFORMINA 1000  MG X 28  COMPRIMIDOS \r\nNOTA: SE SUGIERE FECHA DE VENCIMIENTO SUPERIOR A 1 AÑO O EN CASO CONTRARIO CONTAR CON POLITICAS DE CANJE',
#  'METFORMINA / SITAGLIPTINA 100/1000 MG POR 28 COMPRIMIDOS. JANUMET O SIMILAR.',
#  'LINAGLIPTINA 2,5 MG / METFORMINA 1000 MG X 60 COM P REC SIMILAR A TRAYENTA',
#  'METFORMINA 1.000 MG CONVENIO FOFAR, CAJA X 30 COMPRIMIDOS. (LIBERACIÓN PROLONGADA)\r\r\nSEGÚN BASES ADMINISTRATIVAS, ADJUNTAS.',
#  'METFORMINA 750 MG X 30 O 60 COMPRIMIDOS DE LIBERACIÓN SOSTENIDA',
#  'METFORMINA 850 MG COMPRIMIDOS ENVASE CLINICO',
#  'METFORMINA 1000 MG COMPRIMIDOS LIBERACION PROLONGADA',
#  'METFORMINA  850 MG',
#  'GLAFORNIL XR 500 MG. X 30 COMPRIMIDOS',
#  'METFORMINA 850 MG/ SITAGLIPTINA 50 MG',
#  'METFORMINA 850MG COMPRIMIDOS',
#  'METFORMINA 750 MG.',
#  'INSULINA GLARGINA 100/UI TIPO LÁPIZ 3 ML',
#  'METFORMINA 750MG LIBERACION PROLONGADA X30',
#  'INSULINA LENTA, SEGÚN LO REQUERIDO EN BASES ADMINISTRATIVAS, TÉCNICAS Y ANEXOS ADJUNTOS.',
#  'INSULINA HUMANA MONOCOMPONENTE ISOFANICA NPH ADN RECOMBINANTE  100U.I./ML SUSPENSION INYECTABLE FRASCO AMPOLLA 10 ML',
#  'LO QUE SE REQUIERE ES LINAGLIPTINA 2.5 MG METFORMINA 850 X 56 C',
#  'VIDAGLIPTINA 50 MG / METFORMINA 1000 MG ( EN PRESSENTACION DE 28 O 56 COMPRIMIDOS)\r\nNOTA: SE SUGIERE FECHA DE VENCIMIENTO SUPERIOR A 1 AÑO O EN CASO CONTRARIO CONTAR CON POLITICAS DE CANJE',
#  'INSULINA DEGLUDEC 100 UI (3,66 MG). ADN RECOMBINANTE EN DISPOSITIVO DESECHABLE.; EQUIVALENTE A TRESIBA FLEX TOUCH 100 UI/ML LÁPIZ 3 ML',
#  'METFORMINA 850 MG. FECHA DE VENCIMIENTO OBLIGATORIO',
#  'METFORMINA 850 MG. COMPRIMIDOS',
#  'METFORMINA 500 MG. COMPRIMIDOS RECUBIERTOS. ENVASE SELLADO, RESISTENTE E INADULTERADO. DESEABLE ENVASE NO SUPERIOR A 30 COMPRIMIDOS.',
#  'INSULINA HUMANA ADN RECOMBINANTE 100UI/ML X 1 VIAL 10 ML',
#  'METFORMINA 1.000 MG COMP LIB PROLONGADA, VENCIMIENTO MAYOR A 1 AÑO DESDE LA RECEPCIÓN. COMPRA DIFERIDA 4.000 COMP MENSUALES. NO SE ACEPTAN CARTAS DE CANJE.',
#  'INSULINA CRISTALINA 100UI/ML FRASCO AMPOLLA 10 ML\r\n',
#  'VILDAGLIPTINA/METFORMINA 50/1.000 MG COMP RECUBIERTO, VENCIMIENTO MAYOR A 1 AÑO DESDE LA RECEPCIÓN. NO SE ACEPTAN CARTAS DE CANJE.',
#  'INSULINA CRISTALINA 100UI/ML (INDICAR VALOR UNITARIO NETO). \r\r\n\r\r\n',
#  'JANUMET XR 100/1000 X 28',
#  'METFORMINA 500MG COMPRIMIDOS DE LIBERACIÓN PROLONGADA SIMILAR GLAFORNIL XR 500MG',
#  'METFORMINA CLORHIDRATO COMPRIMIDO 850 MG, VIA ORAL (10-100-214-565-00)',
#  'TRESIBA FLEX TOUCH 100 BU/ML',
#  'METFORMINA 850 MG COMP. (LINEA 86)',
#  'INSULINA NPH HUMANA 100UI/ML. (ESPECIFICAR CAJAS X AMPOLLA)',
#  'METFORMINA 750 MG  X 60 COMP LIBERACION PROLONGADA\r\r\n(GLAFORNIL XR, GLICENEX SR, GLIFORTEX XR, GLUCOPAGE XR, HIPOGLUCIN LP, METFORMINA HCL)\r\r\n',
#  'INSULINA GLULISINA 100 UI/ML LAPIZ 3 ML+15 AGUJAS POR LAPIZ + ESTUCHE TERMICO CON GEL',
#  'GLAUPAX XR 750 MG X 30 COMP.',
#  'INSULINA  CRISTALINA 100UI/ML 10 ML',
#  'METFORMINA 750 MG , ENVASE COMERCIAL \r\r\n',
#  'METFORMINA 850 MG, COMPRIMIDO RECUBIERTO',
#  'GLIBENCLAMIDA / METFORMINA 5/500 MG COMPRIMIDO O COMPRIMIDO RECUBIERTO ENVASADO EN BLISTER.',
#  'FA03-0006\tINSULINA CRISTALINA FCO AMP (RÁPIDA)',
#  'EXA-0987 - INSULIN LIKE GROWTH FACTOR (IGF-1)',
#  'INSULINA CRISTALINA, SOLUCIÓN INYECTABLE 100 UI/ML, FRASCO AMPOLLA 10 ML.',
#  'METFORMINA 850 MG.-',
#  'INSULINA GLARGINA FA 300 U.I./ML LAPIZ 1.5 ML SOLUCION INYECTABLE',
#  'INMUNO-ENDOCRINOLOGIA\tINSULINA\r\r\n',
#  '2628454 INSULINA ASPARTA BIFÁSICA 30/70 (100UI/ML) 3ML LÁPIZ',
#  '"METFORMINA 850 MG+ VILDAGLIPTINA 50MG. CAJA X 28 COMP. REC. SIMILAR A JALRA M. . .. . . . . . . . . . . . ..(SE ADJUNTAN BASES ADMINISTRATIVAS Y TÉCNICAS ""LEERLAS P/OFERTAR)"',
#  '1092031-2 INSULINA GLARDINA 300U/ML LAPICERA DE 1.5ML O EQUIVALENTE A INS.TOUJEO 300U/ML FLEXPEN 1.5ML.',
#  'HIPOGLUCIN 750 LP  X 60 COMPRIMIDOS O EQUIVALENTE TERAPEUTICO\r\r\n',
#  'M01F0042\tINSULINA CRISTALINA 100UI/ML 10 ML',
#  'CAJAS DE SITAGLIPTINA 50MG/METFORMINA 1000MG; PRESENTACIÓN CAJA DE 28 A 56 COMPRIMIDO',
#  'JERINGA 1 ML',
#  'METFORMINA 1000 MG XR',
#  'INSULINA GLARGINA 300 UI/ML (TOUJEO(R)) CON AGUJAS POR LAPIZ',
#  'APIDRA SOLOSTAR CARTUCHO 3 ML\r\n',
#  'LO QUE SE REQUIERE ES INSULINA ASPARTA BIFASICA 30/70',
#  'SUMINISTRO DE INSULINA ASPARTA 3.5 MG (EQUIVALENTE A 100 U/ML) EQUIVALENTE A NOVORAPID FLEXPEN, CAJA 1, 5 O 10 DISPOSITIVO PRELLENADO X 3 ML',
#  'METFORMINA 850 MG. COMP. (LINEA 97)',
#  'AGUJA 29~30 G  P/INSULINA, DESECHABLE ESTERIL',
#  '262-0212\tINSULINA ASPARTICA 100 UI/ML SOLUCION INYECTABLE ENVASADO EN DISPOSITIVO INYECTOR (TIPO PENFILL) DE 3 ML\tUNIDAD\t                            800',
#  'APIDRA SOLOSTAR',
#  'DAPAGLIFOZINA/METFORMINA XR 10/1000  X 28 COMP SIMILAR A XIGDUO',
#  'METFORMINA 1000 MG CM XR',
#  'SITAGLIPTINA 50MG.+METFORMINA 850MG. COMPRIMIDOS RECUBIERTOS ENVASE CONTENIDO 56 UNIDADES.',
#  'METFORMINA 1000 MG X 30 COMPRIMIDOS DE LIBERACIÓN PROLONGADA, SIMILAR A GLAUPAX XR 1000 MG X 30 COMP.',
#  'INSULINA ISÓFANA HUMANA (NPH); SUSPENSIÓN INYECTABLE 100 (NPH) U.I./ML.; FRASCO AMPOLLA 10 ML.',
#  'LINAGLIPTINA 2,5MG/1000MG METFORMINA X 60 COMPRIMIDOS RECUBIERTOS\r\r\n',
#  'METFORMINA 850 MG (COD. INT 040400170048)',
#  'GLICENEX SR 500 MG X 30 COMP',
#  'METFORMINA 850 MG COMPRIMIDO UNITARIO ENVASE COMERCIAL O CLINICO',
#  'METFORMINA 500 MG LIBERACION PROLONGADA COMPRIMIDO',
#  'METFORMINA 850 MG COMPRIMIDO RECUBIERTO RANURADO ENVASE CONTENIENDO 1000 UNIDADES ENVASADO EN BLISTER',
#  'METFORMINA CLORHIDRATO 500 MG. COMPRIMIDOS DE LIBERACIÓN PROLONGADA.; EQUIVALENTE A HIPOGLUCIN LP 500 30 COMP BEQ\r\r\n',
# ...
#  'METFORMINA COMP.X 850 MG',
#  'METFOMINA 850 MG COMPRIMIDOS',
#  'METFORMINA 850MG COMPRIMIDO RECUBIERTO',
#  '2200067 INSULINA ASPARTO 100 U/ML  3 ML (MEDIA UNIDAD)',
#  'JANUMET 50/1000 XR COMPRIMIDOS',
#  'INSULINA DEGLUDEC 100UI/ML DISPOSITIVO (TIPO LAPIZ) PRE-CARGADO DE 3 ML. DEBE INCLUIR UNA BONIFICACIÓN DE10 AGUJAS 32 GX 4 MM POR LÁPIZ',
#  'METFORMINA 1000MG LP',
#  'METFORMINA 750 MG. XR CAJA 30 COMRIMIDOS DE LIBERACION PROLONGADA',
#  'LINAGLIPTINA 2,5 MG / METFORMINA 1000 MG X 60 COMP RECUBIERTOS, CAJA 60 COMP. RECUBIERTOS',
#  'METFORMINA CLORHIDRATO 500 MG + GLIBENCLAMIDA 5 MG EN COMPRIMIDOS RECUBIERTOS. ENVASE CONTENIENDO 60 COMPRIMIDOS.',
#  'CAJA DE 1 LÁPIZ CONTENIENDO: CADA ML 3000 UNIDADES DE INSULINA GLARGINA (EQUIVALENTES A 10.91 MG). CADA LAPICERA CONTIENE 1.5 ML DE SOLUCIÓN INYECTABLE, EQUIVALENTES A 450 UNIDADES.SIMILAR A TOUJEO',
#  'METFORMINA CLORH. 1000 MG\xa0(EQ. A 780 MG) X 30 TAB DE LIBERACION PROLONGADA POR SISTEMA DE DOBLE MATRIZ DE POLÍMERO HIDROFÍLICO, INSCRIPCIÓN SR1000 EN UNA DE SUS CARAS Y CAJA CON IMPRESIÓN EN BRAILLE,EN BLÍSTER PVDC/ALUMINIO.EXC.: ESTEARATO DE MAGNESIO, CA',
#  'METFORMINA 750 X 30 COMP. LIBERACION PROLONGADA',
#  'JERINGA INSULINA C/AGUJA INTERCAMBIABLE.',
#  'EMPAGLIFOZINA 12.5 MG./ METFORMINA 1000 MG, CAJA 60 COMPRIMIDOS',
#  'GLIFORTEX XR 750 MG X 30 COMP.\r\r\n',
#  'REACTIVO PARA INSULINA BASAL  INCLUYE CONTROLES Y CALIBRADORES COMPATIBLE CON EQUIPO COBAS E 411 (CJ X 100)\r\r\n',
#  'CAJA DE SITAGLIPTINA 50 MG /\r\nMETFORMINA 1000 MG X 28\r\nCOMPRIMIDOS\r\nNOTA: SE SUGIERE FECHA DE\r\nVENCIMIENTO SUPERIOR A 1 AÑO O EN\r\nCASO CONTRARIO CONTAR CON\r\nPOLITICAS DE CANJE',
#  'METFORMINA (CLORHIDRATO) 850 MG SOLIDO ORAL VENC. SUPERIOR 12 MESES COMPRIMIDOS OBLONGOS RANURABLES DOCUMENTACION TECNICA SOLICITADA : CERTIFICADO DE FARMAVIGILANCIA,  CERTIFICADO DE ANALISIS DE  LOTE , BIOEQUIVALENCIA, ESTADO DEL REGISTRO SANITARIO, ENVA',
#  '224-6924 | AGUJA PARA LAPIZ INSULINA',
#  'METFORMINA 850 (30COMP)',
#  'METFORMINA 850 MG..COMPRIMIDOS RECUBIERTOS...(INDICAR FECHA DE VENCIMIENTO Y REGISTRO ISP)..',
#  'METFORMINA 1000/SITAGLIPTINA 50MG X28 **JANUMET**',
#  'GLAFORNIL XR METFORMINA 1000 MG',
#  'METFORMINA 1000 MG RECUBUERTA X 30 COMPRIMIDOS GENERICA\r\r\n',
#  'INSULINA ASPÁRTICA 100 UI/ML ENVASADO EN CARTUCHO DE 3 ML MAS DISPOSITIVO INYECTOR DESECHABLE TIPO LAPIZ.\r\r\n DEBE INCLUIR POR CADA DISPOSITIVO INYECTOR DESECHABLE 10 AGUJAS DE 32G X 4 MM\r\r\n',
#  '(26222003)INSULINA ASPARTO 100 UI/ML DISPOSITIVO (TIPO LAPIZ) PRE-CARGADO DE 3 ML (DEBE INCLUIR UNA BONIFICACION DE 10 AGUJAS 32 G X 4 MM POR LAPIZ)',
#  'HIPOGLUCIN 1000 LP ENVASE X 30 COM. (O EQUIVALENTE)',
#  'SITAGLIPTINA/METFORMINA 50/1000 MG, CAJA DE 56 COMPRIMIDOS.',
#  '12145144000\tMETFORMINA CLORHIDRATO CM RECUBIERTO 850 MG',
#  'METFORMINA 850 MG. COMPRIMIDOS.',
#  'INSULINA GLARGINA 100 UI/ML - TIPO LAPIZ',
#  'INSULINA NPH 100UI/ML, SOLUCIÓN INYECTABLE EN VIAL DE 10 ML, INSULINA HUMANA DE LARGA DURACIÓN',
#  'METFORMINA 850 MG / SITAGLIPTINA 50 MG.',
#  'APIDRA SOLOSTAR 100 U.I',
#  'LINAGLIPTINA 2,5 MG. METFORMINA 1.000 MG.',
#  'INSULINA INTERMEDIA HUMANA, ISOFANA ADN RECOMBINANTE 100 U/ML X 10 ML SC, SIMILAR INSULATARD\tUSO OCASIONAL\tSOL. INY. (FC)\r\r\n',
#  'JARDIANCE DUO 12.5/1000 MG X 60',
#  '262-8434 INSULINA ACCION RAPIDA 100 U/ML VIAL 10 ML (CRISTALINA)',
#  'METFORMINA 1000 MG COMPRIMIDOS LIBERACION PROLONGADA (VENCIMIENTO SUPERIOR A 1 AÑO)',
#  'SAXAGLIPTINA 5 MG + METFORMINA 1000 MG X 28 COMPRIMIDOS DE LIBERACIÓN PROLONGADA, SIMILAR A KOMBIGLYZE XR 5/1000 MG X 28 COMP. DE LIBERACIÓN PROLONGADA',
#  'INSULINA GLARGINA FA 100 U.I./ML LAPIZ 3 ML SOLUCION INYECTABLE',
#  'HOSDIP CM1224. JERINGA DE INSULINA DE 30 UI 0,3 ML CON AGUJA FIJA 31GX 6MM. GRADUACIÓN DE 1/2 EN 1/2 UNIDAD. AGUJA DE ACERO INOXIDABLE, TOTALMENTE SILICONIZADA Y CORTE TRIFACETADO DE LA PUNTA, PLÁSTICO DE POLIPROPILENO TRANSPARENTE CON ESCALA NÍTIDA',
#  'AGUJA DESECHABLE 25G X 5/8 CJ X 100 (INDICAR PRESENTACIÓN Y FECHA DE VENCIMIENTO POSTERIOR A 18 MESES)',
#  'METFORMINA CLORHIDRATO 1000 MG. COMPRIMIDO RECUBIERTO FRACCIONABLE.; EQUIVALENTE A HIPOGLUCIN 1 GR 30 COMP BEQ\r\r\n',
#  'JERINGA INSULINA 1 ML CON AGUJA',
#  'METFORMINA 850MG. COTIZAR POR COMPRIMIDO. VENCIMIENTO IGUAL O SUPERIOR A 12 MESES. INDICAR MONTO MÍNIMO DE FACTURACIÓN Y DESPACHO.',
#  '"METFORMINA 1000 MG + SITAGLIPTINA 50 MG. CAJA X 56 COMP. SIMILAR A JANUMET. . .. . . . . . . . . . . . ..(SE ADJUNTAN BASES ADMINISTRATIVAS Y TÉCNICAS ""LEERLAS P/OFERTAR)"',
#  'DAPAGLIFLOZINA/ METFORMINA 10/1000MG\tXIGDUO XR 10/1000MG\t\tCAJA POR 28 COMPRIMIDOS\r\r\n',
#  'METFORMINA 850MG COMPRIMIDOS',
#  '2 KIT ELECSYS INSULINA CALSET 10 CAL',
#  'METFORMINA/GLIBENCLAMIDA  500/5 COMPRIMIDOS RECUBIERTOS\r\r\n',
#  'INSULINA GLARGINA 100 UI X 10 ML',
#  'ADQUISICION DE MEDICAMENTOS RX PARA FARMACIA COMUNAL.',
#  'METFORMINA GLIBENCLAMIDA 500/2,5 X 30 COMP REC',
#  'METFORMINA COMPRIMIDOS RECUBIERTO, 850MG, 1) PRESENTACIÓN VENTA PÚBLICO MÁS CONVENIENTE DESDE PUNTO DE VISTA PRECIO\r\r\n2) AL MENOS 24 MESES DE EFICACIA\r\r\n3) FABRICADO EN EL EXTRANJERO\r\r\n4) CERTIFICADO CUMPLIMIENTO BUENAS PRACTICAS DE FABRICACIÓN - EMITIDO POR',
#  'INSULINA NPH\t100 UI /ML\tFRASCOS DE 10 ML\r\r\n',
#  'LINAGLIPTINA/METFORMINA 2.5MG/1000MG COMP RECUBIERTO. VENCIMIENTO MAYOR A 12 MESES, NO SE ACEPTAN CARTAS DE CANJE.',
#  '262-0112\tINSULINA DETEMIR 100 UI/MLX 3 ML. \tLAPIZ\t420',
#  'METFORMINA 750 MG',
#  'GLUKAUT 500/5 MG METFORMINA/GLIBENCLAMIDA, CAJA POR 30 COMP',
#  'INSULINA RETARDADA NPH 100 UI/ML (LENTA)',
#  'METFORMINA CLORHIDRATO 850 MG. ENVASADO EN BLISTER DE PVC O SIMILAR Y ALUMINIO IMPRESO DE 60 COMP RECUBIERTOS',
#  'INSULINA NPH FRASCO AMPOLLA 1000 UI\r\r\n',
#  'METFORMINA 500MG/ GLIBENCLAMIDA 5 MG COMP.\r\r\n',
#  'GLIFORTEX XR 750MG',
#  'JANUMET XR 100/1000 MG CAJA X 28 COM. (O EQUIVALENTE)',
#  'SITAGLIPTINA/METFORMINA LIBERACION PROLONGADA 100/1000 MG., CAJA 28 COMPRIMIDOS',
#  'CALSET INSULINA COBAS 411\r\n',
#  'METFORMINA GENÉRICA 850 MG COMPRIMIDO',
#  'SITAGLIPTINA 50 MG/METFORMINA 850 MG X CAJA 56 COMPRIMIDOS',
#  'METFORMINA/ VILDAGLIPTINA 1000/50MG POR 56 COMPRIMIDOS. GALVUS O SIMILAR.',
#  'ENVASE DE 56 COMPRIMIDOS QUE CONTIENE: VILDAGLIPTINA 50 MG; METFORMINA CLORHIDRATO 850 MG, SIMILAR O IGUAL A GALVUS MET 50/850 MG.',
#  '1092018-9 INSUL.LEVEMIR FLEXPEN 100 UI O EQUIVALENTE A INSUL.LEVEMIR FLEXPEN 100 UI',
#  'SITAGLIPTINA DE 50MG MAS METFORMINA DE 1.000MG CAJA 28 COMPRIMIDOS',
#  'METFORMINA 850 MG, CAJA X 60 COMPRIMIDOS (EQUIVALENTE A HIPOGLUCIN).',
#  'TRAYENTA 2.5/850 MG',
#  'METFORMINA 850 MG, COMPRIMIDOS RECUBIERTOS',
#  'JANUMET XR 100/1000MG',
#  'METFORMINA COMPRIMIDO LIBERACIÓN PROLONGADA 500 MG X 60 COMP\r\r\n',
#  'METFORMINA 500MG COMPRIMIDO. FECHA DE VENCIMIENTO SUPERIOR A 1 AÑO DESDE LA FECHA DE ENTREGA. NO SE ACEPTAN CARTAS DE CANJE',
#  'METFORMINA 1.000 MG. LIBERACIÓN PROLONGADA.',
#  'METFORMINA 1GR LIBERACION PROLONGADA',
#  'VIDAGLIPTINA / METFORMINA 50/850 MG',
#  'METFORMINA XR 1000 MG X 30 COMP REC, SIMILAR A GLIFORTEX',
#  'SITAGLIPTINA 50 MG + 1000 MG DE METFORMINA (EN NÚCLEO DEL COMP DE LIB. PROL.) X 56 COMP. REC. BICONVEXOS Y OVALADOS.',
#  'METFORMINA 1000 MG (XR)  COMPRIMIDO DE LIBERACIÓN PROLONGADA',
#  'GLUCOVANCE 500/5MG',
#  'METFORMINA TABLETAS 850 MG',
#  'INSULINA GLARGINA 100 UI/ML X 3 ML SOLUCION INYECTABLE SIMILAR SOLOSTAR',
#  'METFORMINA (CLORHIDRATO)\tCOMPRIMIDO O COMPRIMIDO RECUBIERTO\t850 MG\t7000',
#  'JANUMET 50/500 MG X 56 CM. RECUBIERTO (O EQUIVALENTE)',
#  'INSULINA GLARGINA 3.64 MG, CORRESPONDIENTE A 100 U.I. DE INSULINA HUMANA. PRESENTACIÓN EN FRASCO VIAL; EQUIVALENTE A LANTUS 100 UI/ML FRASCO 10 ML',
#  'INSULINA',
#  'INSULINA GLARGINA 100 UI/ML \tSUGERENCIA, LANTUS \tCAJA CONTENIENDO 1 LAPIZ \r\r\n',
#  'LINAGLIPTINA 2.5MG + METFORMINA 850MG COMPRIMIDOS (SIMILAR GENERICO O BIOEQUIVALENTE) CAJA X30',
#  'SAXAGLIPTINA/METFORMINA 5/1000 MG X 28 COMP., CAJA 28 COMPRIMIDOS',
#  'DAPAGLIFLOZINA 10 MG; METFORMINA 1000 MG. COMPRIMIDOS RECUBIERTOS DE LIBERACION PROLONGADA. ENVASE SELLADO, RESISTENTE E INADULTERADO. SIMILAR A XIGDUO XR',
#  'METFORMINA 850 MG. COMPRIMIDOS RECUBIERTOS.  INDICAR FECHA DE VENCIMIENTO, PLAZOS DE ENTREGA E INDICAR CANTIDADES X ENVASADO',
#  'NEVERA PARA TRASLADO DE INSULINAS PARA VISITA DOMICILIARIA, SE ADJUNTAN ESPECIFICACIONES TECNICAS.',
#  'ITEM N° 62 METFORMINA 850 MG SEGÚN ESPECIFICACIONES TÉCNICAS.',
#  '5\tLAB-0622\tINSULINA\tCAJA\t81',
#  'INSULINA HUMANA  LENTA NPH  FA 1000  , CÓDIGO HOSPITAL 2620039.',
#  'METFORMINA 500 MG. (LP)',
#  'VILDAGLIPTINA 50; METFORMINA 500 MG ENVASE DE 56 COMPRIMIDOS (EQ A JALRA O GALVUS). MAXIMO A PAGAR $ 17.000.',
#  'METFLOMINA XR 1000 MGS //SALUD MENTAL//',
#  'METFORMINA 1000 MG COMPRIMIDOS DE LIBERACIÓN PROLONGADA.  CAJA DE 30 COMPRIMIDOS DE LIBERACION PROLONGADA',
#  'METFORMINA 850 MG BIOEQUIVALENTE (VENCIMIENTO SUPERIOR A 1 AÑO)',
#  'METFORMINA CLORH. 1000 MG\xa0EN COMPRIMIDOS DE LIBERACION PROLONGADA.  ENVASE POR 60 COMPRIMIDOS',
#  'METFOMINA 850 MG COMPRIMIDO\r\r\n',
#  'METFORMINA CLORHIDRATO 1000 MG EN COMPRIMIDOS',
#  'METFORMINA (CLORHIDRATO) 850 MG. COMPRIMIDO O COMPRIMIDO RECUBIERTO.',
#  'INSULINA RÁPIDA, SEGÚN LO REQUERIDO EN BASES ADMINISTRATIVAS, TÉCNICAS Y ANEXOS ADJUNTOS.',
#  '1093063-4 CADA COMPROMIDO DE LIBERACION PROLONGADA CONTIENE \r\r\nMETFORMINA CLORHIDRATO 750 MG.EXCEPIENTES CELULOSA\r\r\nMICROCRISTALINA, HIPROMELOSA, ETILCELULOSA Y ESTEARATO  O EQUIVALENTE A   HIPOGLUCIN LP 750 MG X 60 COMP.',
#  'INSULINA LENTA HUMANA C/ ADN RECOMBINANTE 100 U.I./10 ML. VENCIMIENTO NO INFERIOR A JUNIO 2021, POR LO CUAL EL OFERENTE DEBE CONSIGNAR LA FECHA DE VENCIMIENTO EN SU OFERTA TÉCNICA, ASI COMO LA FORMA FARMACÉUTICA.',
#  'SITAGLIPTINA  50 MG / METFORMINA 850 MG X 28 COMPRIMIDOS \r\nNOTA: SE SUGIERE FECHA DE VENCIMIENTO SUPERIOR A 1 AÑO O EN CASO CONTRARIO CONTAR CON POLITICAS DE CANJE',
#  'METFORMINA 850 MG X30 COMPRIMIDOS RECUBIERTOS EXCLUYENTE',
#  'CAJA DE 28 COMPRIMIDOS RECUBIERTOS DE LIBERACIÓN PROLONGADA CONTIENE: DAPAGLIFLOZINA (COMO PROPANODIOL) 10 MG Y METFORMINA CLORHIDRATO 1000 MG. SIMILAR A XIGDUO 10/1000',
#  'METFORMINA CM 850 MG',
#  'INSULINA GLARGINA HUMANA RECOMBINANTE 100 UI/ML SOLUCIÓN INYECTABLE PARA ADMINISTRACIÓN SUBCUTÁNEA. DISPOSITIVO PRELLENADO DESCARTABLE DE 3 ML.',
#  'KOMBIGLYZE 5/1000 MG X 28 CM. RECUBIERTO (O EQUIVALENTE)',
#  '5274/AI5205 \r\r\nR/INSULINA HUM. INTERMEDIA 100UI/ML///',
#  'SITAGLIPTINA/METFORMINA 50/1000MG X 56 COMPRIMIDOS.',
#  'MEDICAMENTOS CON DESTINO A EMERGENCIA COVID 19, POSTULACION EN VALORES NETOS',
#  'INSULINA DEGLUDEC 3 ML',
#  'EMPAGLIFLOZINA / METFORMINA 12.5/1000 MG COMPRIMIDOS',
#  '262-8434 INSULINA ACCIÓN RÁPIDA 100 U/ML VIAL 10 ML (CRISTALINA)',
#  'INSULINA GLARGINA 100 UI/ML  LAPIZ 3 ML+15 AGUJAS POR LAPIZ + ESTUCHE TERMICO CON GEL',
#  'KOMBIGLYZE XR 2,5/1000 MG X 56 COMP.',
#  'METFORMINA 1.000 MG LIBERACIÓN PROLONGADA COMPRIMIDOS. SEGÚN BASES ADMINISTRATIVAS, ADJUNTAS.',
#  'VILDAGLIPTINA/METFORMINA 50/500 MG X 56 COMPRIMIDOS',
#  'SITAGLIPTINA METFORMINA 50-1000 LIBERACION PROLONGADA \r\r\n\r\r\n\r\r\n',
#  'INSULINA HUMANA CRISTALINA SOLUCION INYECTABLE SUBCUTANEA E INTRAVENOSA ESTERIL, ENVASE RESISTENTE CON SELLO QUE ASEGURE LA INVIOLABILIDAD DEL CONTENIDO FECHA DE VENCIMIENTO SUPERIOR A DOS AÑOS',
#  'METFORMINA CMP. 850 MG. ENVASE 60 COMP.',
#  'GALVUS 850/50 MG (56COMP)',
#  'METFORMINA 850 MG - PRESENTACIÓN: COMPRIMIDO\r\r\n',
#  'CAJAS DE SITAGLIPTINA 50 MG + METFORMINA 500 MG X 28 COMP.',
#  'EMPAGLIFLOZINA/ METFORMINA 12.5/ 850  MG X 60 COMPRIMIDOS SIMILAR A LA JARDIACNE DUO 12.5/850 MG X 60 COMPRIMIDOS',
#  'GALVUS MET 50MG/1000MG X28COMP',
#  'METFORMINA 850 MG (VER BASES ADMINISTRATIVAS Y TÉCNICAS ADJUNTAS)',
#  'GLUKAUT 500/2.5 MG',
#  'METFORMINA COMPRIMIDO RECUBIERTO 850MG',
#  'INSULINA HUMANA SOLUBLE BIOSINTÉTICA 100 U.I PENFILL SIMILAR ACTRAPID PENFILL',
#  'METFORMINA 500 MG CAJA X 30 COMPRIMIDOS DE LIBERACIÓN PROLONGADA',
#  'LINAGLIPTINA 2.5MG/METFORMINA 850 MG X60 **TRAYENTA DUO**',
#  'DAPAGLIFLOZINA 10 MG/ METFORMINA 1000 MG X 28 COMPRIMIDOS SIMILAR A XIGDUO XR 10/1000 MG X 28 COMPRIMIDOS',
#  'GLAUPAX XR 1000 MG X 30 COMP.',
#  'SITAGLIPTINA/ METFORMINA 50 MG/ 1000 MG',
#  'DAPAGLIFLOZINA 5 MG; METFORMINA 1000 MG. COMPRIMIDOS RECUBIERTOS DE LIBERACION PROLONGADA. ENVASE SELLADO, RESISTENTE E INADULTERADO. SIMILAR A XIGDUO XR.',
#  'GLIFORTEX 750MG X 30 COMP O SIMILAR',
#  '0220020012\tMETFORMINA/SITAGLIPTINA 1000/50 MG COMPRIMIDOS DE LIBERACION PROLONGADA',
#  'METFORMINA 1000 MG COMPRIMIDOS DE LIBERACIÓN PROLONGADA ENVASADO EN BLISTER DE PVC Y/O SIMILAR CON ALUMINIO IMPRESO, FÁRMACO DE REFERENCIA O BIOEQUIVALENTE',
#  'SAXAGLIPTINA 2,5 MG / METFORMINA 1000 MG X 28 SIMILAR A KOMBIGLYZE XR',
#  'METFORMINA  850 MG',
#  '40.000 METFORMINA 850 MG COMPRIMIDOS',
#  'METFORMINA COMPRIMIDOS 850 MG',
#  'METFORMINA 500 MG/ GLIBENCLAMIDA 2,5 MG, CAJA X 60 COMPRIMIDOS RECUBIERTOS (EQUIVALENTE A GLUCOVANCE 500/2,5)',
#  'SITAGLIPTINA 50 MG / METFORMINA 850 MG \r\r\n',
#  'CAJA DE 20 COMPRIMIDOS DE JALRA M 50/1000, O SIMILAR COMPOSICIÓN, DE ACUERDO A BASES ADJUNTAS',
#  '"INSULINA ISOFÁNICA 100 UI/ML. FRASCO SUSPENSION X 10 ML. SIMILAR A INSULATARD HM. . . . . . .. . .. .  .. . . . .(SE ADJUNTAN BASES ADMINISTRATIVAS Y TÉCNICAS ""LEERLAS P/OFERTAR"")"',
#  'METFORMINA LIBERACION PROLONGADA 1000 MG, ORIGINAL O BIOEQUIVALENTE.',
#  'METFORMINA 1000 MG COMPRIMIDOS DE LIBERACIÓN PROLONGADA, (CAJA DE 30 COMPRIMIDOS)',
#  'INSULINA LISPRO O ASPARTATO 100UI/ML X 3ML CATRIDGE O CARTUCHO VIDRIO COMPATIBLE CON DISPOSITIVO INYECTOR CON CAPACIDAD DE ADMINSITRAR 0,5',
#  'METFORMINA 1000 MG X 30 O 60 COMPRIMIDOS DE LIBERACIÓN PROLONGADA',
#  'CAJAS DE SITAGLIPTINA + METFORMINA 50/850 MG X 56 COMP.',
#  'TRAYENTA DUO (O SIMILAR) (LINAGLIPTINA 2.5 MG Y CLORHIDRATO DE METFORMINA 500 MG).',
#  'METFORMINA 850 MG UNIDAD 1\r\r\nCOMPRIMIDO',
#  'METFORMINA 750 MG X 30 COMPRIMIDOS LP. BIOEQUIVALENTE',
#  'METFORMINA 750 MG X 30 COMP. DE LIBERACIÓN PROLONGADA',
#  'GLAUPAX XR 500 MG CAJA X 30 COM (O EQUIVALENTE)',
#  'METFORMINA XR 750 MG\tENVASE DE 30 COMPRIMIDOS',
#  'METFORMINA 500 LP X 30 COMPRIMIDOS',
#  'HIPOGLUCIN LP 1000 MG X 30 COMP.LIB.PROL.',
#  'METFORMINA 1000 MG CM LIBERACIÓN MODIFICADA',
#  'SITAGLIPTINA 50 MG + METFORMINA 850 X 56 COMPRIMIDOS, SIMILAR A JANUMET 50/850 MG X 56 COMPRIMIDOS RECUBIERTOS',
#  'KOMBIGLYZE XR 5/1000  CAJA X 28 COM. (O EQUIVALENTE)',
#  'JERINGA INSULINA 1 CC C/ A 27 - 30G * 1/2 - PRESENTACIÓN: CAJA X 100.\r\r\n',
#  'REACTIVO PARA INSULINA PARA EQUIPO MAGLUMI, 4 UNIDADES, VER BASES ADJUNTAS.-',
#  'INSULINA HUMANA MONOCOMPONENTE ISOFANICA NPH ADN RECOMBINANTE SUSPENSION INYECTABLE 100 U.I./ML FAM 10 ML ENVASE INDIVIDUAL CON SELLO QUE ASEGURE INVIOLABILIDAD DEL CONTENIDO',
#  'JERINGA DESECHABLE INSULINA MULTIGRADUADA 1ML/ 100U 27G X 1/2 AGUJA  AGUJA FIJA Y FINA, PRODUCTO NO TOXICO, LIBRE DE PIRÓGENOS. ESTERILIZADA BAJO OXIDO ETILENO, ENVASES INDIVIDUALES CON FECHA DE VENCIMIENTO EN CADA UNIDAD\r\r\n',
#  'METFORMINA 850 MG...COMPRIMIDOS RECUBIERTOS....(INDICAR FECHA DE VENCIMIENTO Y REGISTRO ISP)..',
#  'METFORMINA 500 MG + GLIBENCLAMIDA 5 MG COMP.',
#  'HIPOGLUCIN 1000MG LP',
#  '5551520\tMETFORMINA CLORHIDRATO\t850\tMG\t \t \tCOMPRIMIDO RECUBIERTO',
#  'METFROMINA 850MG',
#  '1400040\tANALOGO DE INSULINA RAPIDA ASPARTA ADN RECOMBINANTE 100 U/ML 5 CARTUCHOS X 3 ML SC, SIMILAR NOVORAPID PENFILL.\t\tSOL. INY. CARTUCHO\r\r\n',
#  'METFORMINA XR 500MG X 30 COMP.',
#  'INSULINA GLARGINA 300 UI/ML. LAPIZ PRELLENADO 1.5ML. SIMILAR A TOUJEO. . . . .. .. .. . .. .. (SE ADJUNTAN BASES ADMINISTRATIVAS Y TÉCNICAS LEERLAS P/OFERTAR)\t\t\t\t\r\r\n',
#  'METFORMINA 850 MG: 12.000 COMPRIMIDOS',
#  'METFORMINA COMPRIMIDOS 850 MG EN BLISTER. VENCIMIENTO MAYOR A 18 MESES DESDE EL ENVIÓ DE LA OC.',
#  'METFORMINA L P 1000 MG',
#  'KOMBIGLYZE SAXAGLIPTINA + METFORMINA 5/1000MG, COMPRIMIDOS RCUBIERTOS DE LIBERACIÓN PROLONGADA, CAJA X 28 COMPRIMIDOS',
#  'GALVUS MET 50/1000 MG\tVILDAGLIPTINA/METFORMINA, CAJA DE 56 COMPRIMIDOS',
#  'METFORMINA 750 MG COMP. LP',
#  'GLIFORTEX XR 500 MG - METFORMINA 500 MG (BIOEQUIVALENTE)',
#  '1092011-4 INSULINA ISOFÁNICA HUMANA RECOMBINANTEA 100UI/ML  \r\r\n10ML FCO AMP. SUSPENSION INYECTABLE, O EQUIVALENTE A INSULINA INSUMAN N 100UI/ML INTERMEDIA',
#  'ÍTEM 4: METFORMINA 1000 MG CM LIBERACIÓN MODIFICADA',
#  ...]

# %%
from nltk.tokenize import WordPunctTokenizer
tokenizer = WordPunctTokenizer()

# %%
CHLDiab1DirtyNameUS = []
for i in CHLDiab1DirtyNameU:
  temp = tokenizer.tokenize(i)
  CHLDiab1DirtyNameUS.append(temp)

CHLDiab1DirtyNameUS2 = []
for i in CHLDiab1DirtyNameUS:
  temp_sub = []
  for j in i:
    if len(j) >= 4 and len(j) <= 20:
      temp_sub.append(j)
  CHLDiab1DirtyNameUS2.append(temp_sub)

# %% [markdown]
# ## clean data base drug names

# %%
import pandas as pd
CleanDataBase = pd.read_excel('CleanDataBase.xlsx')
CatalogName = CleanDataBase['Catalog Name']
CatalogName = list(set(CatalogName))
CatalogName = [x for x in CatalogName if str(x) != 'nan']

CatalogNameCopy = CatalogName.copy()
# uppercase everything
CatalogNameU = []
for i in CatalogNameCopy:
  CatalogNameU.append(i.upper())

# %%
CatalogNameUS = []
for i in CatalogNameU:
  temp = tokenizer.tokenize(i)
  CatalogNameUS.append(temp)

# %%
CatalogNameUS2 = []
for i in CatalogNameUS:
  temp_sub = []
  for j in i:
    if len(j) >= 4 and len(j) <= 20:
      temp_sub.append(j)
  CatalogNameUS2.append(temp_sub)

# %%
CatalogNameUS3 = []
for i in CatalogNameUS2:
  temp_sub = i[0]
  CatalogNameUS3.append(temp_sub)

# %% [markdown]
# ## UDF

# %%
DetermineList_1 = []
for i in CHLDiab1DirtyNameUS2:
  temp = []
  for k in i:
    for j in CatalogNameUS3:
      if k == j:
        temp.append(j)
  DetermineList_1.append(temp)

 # temp_dis = Simhash(CHLDiab1DirtyNameUS2[1]).distance(Simhash(i))
 # DistanceList_1.append(temp_dis)

# %%
temp = []
for k in CHLDiab1DirtyNameUS2[0]:
  for j in CatalogNameUS3:
    if k == j:
      temp.append(j)
temp
# Out:
# []

# %%
for k in CHLDiab1DirtyNameUS2[0]:
  print(k)
# Out:
# INSULINA
# ASPART
# TIPO
# LAPIZ
# DEBE
# INCLUIR
# MEDICAMENTO
# ADMINISTRAR
# DISPOSITIVO
# OTORGUE
# ADMINISTRACIÓN
# DOSIS

# %%
for j in CatalogNameUS3:
  print(j)
# Out:
# ABACAVIR
# ABACAVIR
# ABACAVIR
# ABACAVIR
# ABACAVIR
# ACICLOVIR
# ACICLOVIR
# ACICLOVIR
# ADALIMUMAB
# ADALIMUMAB
# ADALIMUMAB
# ADALIMUMAB
# ADRIAMICIN
# AFATINIB
# AFATINIB
# AFATINIB
# ALBENDAZOLE
# ALOGLIPTIN
# ALOGLIPTIN
# ALOGLIPTIN
# AMINOSIDINE
# AMITRIPTYLINE
# AMITRIPTYLINE
# AMLODIPINE
# AMLODIPINE
# AMLODIPINE
# AMLODIPINE
# AMLODIPINE
# AMLODIPINE
# AMLODIPINE
# AMLODIPINE
# AMLODIPINE
# AMLODIPINE
# AMLODIPINE
# AMLODIPINE
# AMLODIPINE
# AMLODIPINE
# AMLODIPINE
# AMLODIPINE
# AMLODIPINE
# AMLODIPINE
# AMLODIPINE
# AMLODIPINE
# AMLODIPINE
# AMLODIPINE
# AMLODIPINE
# AMLODIPINO
# AMLODIPINO
# AMLODIPINO
# AMLODIPINO
# AMLODIPINO
# AMLODIPINO
# AMLODIPINO
# AMLODIPINO
# AMLODIPINO
# AMLODIPINO
# AMLODIPINO
# AMLODIPINO
# AMLODIPINO
# AMLODIPINO
# AMLODIPINO
# AMLODIPINO
# AMLODIPINO
# AMLODIPINO
# AMLODIPINO
# AMLODIPINO
# AMOXICILLIN
# AMOXICILLIN
# AMPHOTERICIN
# AMPHOTERICIN
# AMPHOTERICIN
# ASPARAGINASE
# ASPARAGINASE
# ASPARAGINASE
# ATAZANAVIR
# ATAZANAVIR
# ATAZANAVIR
# ATAZANAVIR
# ATENOLOL
# ATORVASTATIN
# ATORVASTATIN
# ATORVASTATIN
# ATORVASTATIN
# AZATHIOPRINE
# AZITHROMYCIN
# AZITHROMYCIN
# BECLOMETASONE
# BEDAQUILINE
# BEVACIZUMAB
# BIPERIDEN
# BISOPROLOL
# BISOPROLOL
# BISOPROLOL
# BISOPROLOL
# BISOPROLOL
# BISOPROLOL
# BISOPROLOL
# BLEOMYCIN
# BLEOMYCIN
# CALCIUM
# CANAGLIFOZINE
# CANAGLIFOZINE
# CANAGLIFOZINE
# CANDESARTAN
# CANDESARTAN
# CANDESARTAN
# CANDESARTAN
# CANDESARTAN
# CAPECITABINE
# CAPECITABINE
# CAPTOPRIL
# CAPTOPRIL
# CARBAMAZEPINE
# CARBAMAZEPINE
# CARBAMAZEPINE
# CARBOPLATIN
# CARBOPLATIN
# CARBOPLATIN
# CARVEDILOL
# CARVEDILOL
# CARVEDILOL
# CARVEDILOL
# CARVEDILOL
# CHLORTHALIDONE
# CHLORTHALIDONE
# CHLORTHALIDONE
# CHLORTHALIDONE
# CHLORTHALIDONE
# CHLORTHALIDONE
# CHLORTHALIDONE
# CISPLATIN
# CISPLATIN
# CISPLATIN
# CLINDAMYCIN
# CLOPIDOGREL
# COAGULATION
# CYCLOPHOSPHAMIDE
# CYCLOPHOSPHAMIDE
# CYCLOPHOSPHAMIDE
# CYCLOPHOSPHAMIDE
# CYCLOSPORINE
# CYCLOSPORINE
# CYCLOSPORINE
# CYCLOSPORINE
# CYCLOSPORINE
# CYTARABINE
# CYTARABINE
# DACARBAZINE
# DACLATASVIR
# DACTINOMICNA
# DAPAGLIFLOZIN
# DAPAGLIFLOZIN
# DAPAGLIFLOZIN
# DAPAGLIFOZIN
# DARUNAVIR
# DARUNAVIR
# DARUNAVIR
# DARUNAVIR
# DARUNAVIR
# DARUNAVIR
# DASATINIB
# DASATINIB
# DASATINIB
# DASATINIB
# DASATINIB
# DAUNORUBICIN
# DELAMANID
# DEXAMETHASONE
# DEXAMETHASONE
# DEXTROMETORFANO
# DIGOXIN
# DIGOXIN
# DOCETAXEL
# DOCETAXEL
# DOCETAXEL
# DOLUTEGRAVIR
# DOXORUBICIN
# DOXORUBICIN
# DOXORUBICIN
# DOXORUBICIN
# DOXORUBICIN
# DOXYCYCLINE
# EFAVIRENZ
# EFAVIRENZ
# EFAVIRENZ
# EFAVIRENZ
# EMPAGLIFLOZIN
# EMPAGLIFLOZIN
# EMPAGLIFOZIN
# EMPAGLIFOZIN
# EMPAGLIFOZIN
# EMPAGLIFOZIN
# EMTRICITABINE
# EMTRICITABINE
# EMTRICITABINE
# ENALAPRIL
# ENALAPRIL
# ENALAPRIL
# ENTECAVIR
# ENTECAVIR
# ERLOTINIB
# ERLOTINIB
# ERLOTINIB
# ETANERCEPT
# ETANERCEPT
# ETOPOSIDE
# ETRAVIRINE
# ETRAVIRINE
# FENTANYL
# FLUCONAZOLE
# FLUCONAZOLE
# FLUCONAZOLE
# FLUCONAZOLE
# FLUDROCORTISONE
# FLUOROURACIL
# GLIBENCLAMIDE
# GLIBENCLAMIDE
# GLIBENCLAMIDE
# GLIBENCLAMIDE
# GLIBENCLAMIDE
# GLICAZIDE
# GLICAZIDE
# GLICAZIDE
# GLIMEPIRIDE
# GLIMEPIRIDE
# GLIMEPIRIDE
# GLIMEPIRIDE
# HALOPERIDOL
# HYDRALAZINE
# HYDRALAZINE
# HYDROCHLOROTHIAZIDE
# HYDROCHLOROTHIAZIDE
# HYDROCHLOROTHIAZIDE
# HYDROCHLOROTHIAZIDE
# HYDROCHLOROTHIAZIDE
# HYDROCHLOROTHIAZIDE
# HYDROCORTISONE
# HYDROXYUREA
# IFOSFAMIDE
# IFOSFAMIDE
# IFOSFAMIDE
# IMATINIB
# IMATINIB
# IMIPENEM
# INFLIXIMAB
# INSULIN
# INSULIN
# INSULIN
# INSULIN
# INSULIN
# INSULIN
# INSULIN
# INSULIN
# INSULIN
# INSULIN
# INSULIN
# INSULIN
# INSULIN
# INSULIN
# INSULIN
# INSULIN
# INSULIN
# INSULIN
# INSULIN
# INSULIN
# INSULIN
# INSULIN
# INTERMEDIATE
# IRBESARTAN
# IRBESARTAN
# IRBESARTAN
# IRBESARTAN
# IRBESARTAN
# IRBESARTAN
# ITRACONAZOLE
# LAMIVUDINE
# LAMIVUDINE
# LAMIVUDINE
# LAMIVUDINE
# LAMIVUDINE
# LEVOTHYROXINE
# LEVOTHYROXINE
# LEVOTHYROXINE
# LEVOTHYROXINE
# LEVOTHYROXINE
# LEVOTHYROXINE
# LEVOTHYROXINE
# LEVOTHYROXINE
# LEVOTHYROXINE
# LEVOTHYROXINE
# LEVOTHYROXINE
# LEVOTHYROXINE
# LEVOTHYROXINE
# LEVOTHYROXINE
# LEVOTHYROXINE
# LINAGLIPTIN
# LINAGLIPTIN
# LINAGLIPTIN
# LINEZOLID
# LISINOPRIL
# LISINOPRIL
# LISINOPRIL
# LISINOPRIL
# LOPINAVIR
# LOPINAVIR
# LOPINAVIR
# LOPINAVIR
# LOPINAVIR
# LOSARTAN
# LOSARTAN
# LOSARTAN
# LOSARTAN
# LOSARTAN
# LOSARTAN
# MEGLUMINE
# MERCAPTOPURINE
# MERCAPTOPURINE
# MEROPENEM
# MEROPENEM
# MESNA
# METFORMIN
# METFORMIN
# METFORMIN
# METFORMIN
# METFORMIN
# METFORMIN
# METFORMIN
# METFORMIN
# METFORMIN
# METHOTREXATE
# METHOTREXATE
# METHOTREXATE
# METHOTREXATE
# METHOTREXATE
# METHOTREXATE
# METHOTREXATE
# METHYLDOPA
# METHYLDOPA
# METOPROLOL
# METOPROLOL
# METOPROLOL
# METOPROLOL
# METOTREXATE
# MIDAZOLAM
# MIDAZOLAM
# MIDAZOLAM
# MILTEFOSINE
# MILTEFOSINE
# MISOPROSTOL
# MITOXANTRONA
# MORPHINE
# MORPHINE
# MOXIFLOXACIN
# MYCOPHENOLATE
# MYCOPHENOLATE
# NEVIRAPINE
# NEVIRAPINE
# NIFEDIPINE
# NIFEDIPINE
# NIFEDIPINE
# NIFEDIPINE
# NILOTINIB
# NIMODIPINE
# NIVOLUMAB
# OLMESARTAN
# OLMESARTAN
# OMEPRAZOLE
# PACLITAXEL
# PENTAMIDINE
# PERTUZUMAB
# PHENOBARBITAL
# PHENOBARBITAL
# PHENOBARBITAL
# PHOSPHOMYCIN
# PRIMAQUINE
# PROPOFOL
# PROPOFOL
# PUSHY
# PYRAZINAMIDE
# RALTEGRAVIR
# RALTEGRAVIR
# RANITIDINE
# RECOMBINANT
# RIFAMPICIN
# RIFAMPICIN
# RIFAMPICIN
# RIFAPENTINE
# RITONAVIR
# RITUXIMAB
# RITUXIMAB
# RITUXIMAB
# ROSUVASTATIN
# ROSUVASTATIN
# ROSUVASTATIN
# SAXAGLIPTIN
# SAXAGLIPTIN
# SAXAGLIPTIN
# SIMVASTATIN
# SIMVASTATIN
# SITAGLIPTIN
# SITAGLIPTIN
# SITAGLIPTIN
# SITAGLIPTIN
# SITAGLIPTIN
# SOFOSBUVIR
# SOFOSBUVIR
# STREPTOKINASE
# SULFADIAZINE
# SURFACTANT
# TACROLIMUS
# TACROLIMUS
# TACROLIMUS
# TACROLIMUS
# TACROLIMUS
# TACROLIMUS
# TACROLIMUS
# TAMOXIFEN
# TELMISARTAN
# TELMISARTAN
# TELMISARTAN
# TELMISARTAN
# TELMISARTAN
# TELMISARTAN
# TENOFOVIR
# TENOFOVIR
# TENOFOVIR
# TENOFOVIR
# TENOFOVIR
# TENOFOVIR
# TOCILIZUMAB
# TOCILIZUMAB
# TOCILIZUMAB
# TOCILIZUMAB
# TOCILIZUMAB
# TRASTUZUMAB
# TRASTUZUMAB
# TRASTUZUMAB
# TRASTUZUMAB
# TRASTUZUMAB
# VALGANCICLOVIR
# VALGANCICLOVIR
# VALPROIC
# VALSARTAN
# VALSARTAN
# VALSARTAN
# VALSARTAN
# VALSARTAN
# VALSARTAN
# VILDAGLIPTIN
# VILDAGLIPTIN
# VILDAGLIPTIN
# VILDAGLIPTIN
# VINCRISTINE
# VORICONAZOLE
# VORICONAZOLE
# WARFARIN
# WARFARIN
# WARFARIN
# ZIDOVUDINE
# ZIDOVUDINE
# ZIDOVUDINE
# ZIDOVUDINE

# %%
CHLDiab1DirtyNameUS2
# Out:
# [['INSULINA',
#   'ASPART',
#   'TIPO',
#   'LAPIZ',
#   'DEBE',
#   'INCLUIR',
#   'MEDICAMENTO',
#   'ADMINISTRAR',
#   'DISPOSITIVO',
#   'OTORGUE',
#   'ADMINISTRACIÓN',
#   'DOSIS'],
#  ['INUSLINA',
#   'ULTRA',
#   'RÁPIDA',
#   'ASPARTICA',
#   'LISPRO',
#   'GLULISINA',
#   'CARTUCHO',
#   '1000'],
#  ['ELECSYS',
#   'INSULINA',
#   'TEST',
#   'CÓDIGO',
#   'HOSPITAL',
#   'LAB09442',
#   'SEGÚN',
#   'BASES',
#   'TÉCNICAS',
#   'ARTÍCULO'],
#  ['REQUIERE', 'METFORMINA'],
#  ['INSULINA', 'GLARGINA'],
#  ['GLAFORNIL', 'COMPRIMIDOS'],
#  ['TRESIBA', 'FLEXTOUCH'],
#  ['METFORMINA', 'RECUBIERTO', '100003255'],
#  ['METFORMINA',
#   'CLORHIDRATO',
#   '1000',
#   'CAJA',
#   'COMPRIMIDOS',
#   'LIBERACIÓN',
#   'PROLONGADA'],
#  ['METFORMINA'],
#  ['METFORMINA',
#   '1000',
#   'COMPRIMIDOS',
#   'LIBERACIÓN',
#   'PROLONGADA',
#   'ENVASE',
#   'COMPRIMIDOS'],
#  ['ENVASE',
#   'COMPRIMIDOS',
#   'CONTIENE',
#   'VILDAGLIPTINA',
#   'METFORMINA',
#   'CLORHIDRATO',
#   '1000',
#   'SIMILAR',
#   'IGUAL',
#   'GALVUS',
#   '1000'],
#  ['SITAGLIPTINA',
#   'METFORMINA',
#   '1000',
#   'COMPRIMIDOS',
#   'LIBERACIÓN',
#   'PROLONGADA',
#   'SIMILAR',
#   'JANUMET',
#   '1000',
#   'COMP'],
#  ['KOMBIGLYZE',
#   'SAXAGLIPTINA',
#   'METFORMINA',
#   '1000MG',
#   'COMPRIMIDOS',
#   'RCUBIERTOS',
#   'LIBERACIÓN',
#   'PROLONGADA',
#   'CAJA',
#   'COMPRIMIDOS'],
#  ['SITAGLIPINA',
#   'METFORMINA',
#   'COMPRIMIDOS',
#   'SIMILAR',
#   'JANUMET',
#   'COMPRIMIDOS'],
#  ['CAJA',
#   'SITAGLIPTINA',
#   'METFORMINA',
#   '1000',
#   'COMPRIMIDOS',
#   'NOTA',
#   'SUGIERE',
#   'FECHA',
#   'VENCIMIENTO',
#   'SUPERIOR',
#   'CASO',
#   'CONTRARIO',
#   'CONTAR',
#   'POLITICAS',
#   'CANJE'],
#  ['5175',
#   'INSULINA',
#   'HUMANA',
#   'GLARGINA',
#   'RECOMBINANTE',
#   'LAPIZ',
#   'PRECARGADO',
#   '100UI'],
#  ['METFORMINA', 'COMPRIMIDOS'],
#  ['JERINGAS', 'INSULINA', 'DESECHABLES'],
#  ['VILDAGLIPTINA', 'METFORMINA', '1000', 'COMPRIMIDOS'],
#  ['CAJAS', 'SITAGLIPTINA', '50MG', 'METFORMINA', '850MG', 'COMP'],
#  ['METFORMINA', 'GLIBENCLAMIDA', 'COMPRIMIDO'],
#  ['INSULINA',
#   'DEGLUDEC',
#   '100UI',
#   'SOLUCIÓN',
#   'INYECTABLE',
#   'SIMILAR',
#   'TRESIBA',
#   'ADJUNTAN',
#   'BASES',
#   'ADMINISTRATIVAS',
#   'TÉCNICAS',
#   'LEERLAS',
#   'OFERTAR'],
#  ['EMPAGLIFOZINA', 'METFORMINA', 'CAJA', 'COMPRIMIDOS'],
#  ['METFORMINA',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   'LIBERACIÓN',
#   'PROLONGADA',
#   '750MG',
#   'PRESENTACIÓN',
#   'VENTA',
#   'PÚBLICO',
#   'CONVENIENTE',
#   'DESDE',
#   'PUNTO',
#   'VISTA',
#   'PRECIO',
#   'MENOS',
#   'MESES',
#   'EFICACIA',
#   'FABRICADO',
#   'CHILE',
#   'CERTIFICADO',
#   'CUMPLIMIENTO',
#   'BUENAS',
#   'PRACTICAS',
#   'FABRICACIÓN'],
#  ['VILDAGLIPTINA', 'METFORMINA', 'CAJA', 'COMPRIMIDOS'],
#  ['INSULINA', 'ULTRALENTA', 'DETEMIR', 'LAPIZ', 'DESECHABLE', '2620021'],
#  ['METFORMINA', 'ENVASE', 'COMPRIMIDOS'],
#  ['GLIBENCLAMIDA', 'METFORMINA', 'COMP'],
#  ['XIGDUO', '1000', 'CAJA', 'EQUIVALENTE'],
#  ['APIDRA', 'SOLOSTAR'],
#  ['METFORMINA', '500MG', 'GLIBENCLAMIDA'],
#  ['METFORMINA',
#   'CLORH',
#   'PROLONGADA',
#   'SISTEMA',
#   'DOBLE',
#   'MATRIZ',
#   'POLÍMERO',
#   'HIDROFÍLICO',
#   'INSCRIPCIÓN',
#   'SR750',
#   'CARAS',
#   'CAJA',
#   'IMPRESIÓN',
#   'BRAILLE',
#   'BLÍSTER',
#   'PVDC',
#   'ALUMINIO',
#   'ESTEARATO',
#   'MAGNESIO',
#   'CARBOXIMETILCELULOSA'],
#  ['METFORMINA',
#   'CLORH',
#   '1000',
#   'COMPRIMIDOS',
#   'LIBERACION',
#   'PROLONGADA',
#   'ENVASE',
#   'COMPRIMIDOS'],
#  ['METFORMINA',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   'LIBERACIÓN',
#   'PROLONGADA',
#   '750MG',
#   'PRESENTACIÓN',
#   'VENTA',
#   'PÚBLICO',
#   'CONVENIENTE',
#   'DESDE',
#   'PUNTO',
#   'VISTA',
#   'PRECIO',
#   'MENOS',
#   'MESES',
#   'EFICACIA',
#   'FABRICADO',
#   'CHILE',
#   'CERTIFICADO',
#   'CUMPLIMIENTO',
#   'BUENAS',
#   'PRACTICAS',
#   'FABRICACIÓN'],
#  ['VILDAGLIPTINA', 'METFORMINA', 'CAJA', 'COMPRIMIDOS'],
#  ['METFORMINA'],
#  ['SITAGLIPTINA',
#   'METFORMINA',
#   '1000',
#   'NÚCLEO',
#   'METFORMINA',
#   'LIBERACIÓN',
#   'PROLONGADA',
#   'CAPA',
#   'LIBERACIÓN',
#   'INMEDIATA',
#   'SITAGLIPTINA',
#   'SIMILAR',
#   'JANUMET',
#   '1000',
#   'COMPRIMIDOS',
#   'RECUBIERTOS'],
#  ['SITAGLIPTINA',
#   '50MG',
#   'METFORMINA',
#   '850MG',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   'ENVASE',
#   'CONTENIDO',
#   'UNIDADES'],
#  ['METFORMINA', 'GLIBENCLAMIDA', 'COMPR'],
#  ['INSULINA', 'RETARDADA', 'HUMANA', '10ML', '1000'],
#  ['METFORMINA'],
#  ['INSULATARD', 'SIMILAR'],
#  ['EMPAGLIFLOZINA',
#   'CLORH',
#   'METFORMINA',
#   '1000',
#   'ENVASES',
#   'CONTENIENDO',
#   'COMPRIMIDOS',
#   'RECUBIERTOS'],
#  ['SITAGLIPTINA',
#   'METFORMINA',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   'PRESENTACIÓN',
#   'VENTA',
#   'PÚBLICO',
#   'CONVENIENTE',
#   'DESDE',
#   'PUNTO',
#   'VISTA',
#   'PRECIO',
#   'MENOS',
#   'MESES',
#   'EFICACIA',
#   'FABRICADO',
#   'CHILE',
#   'CERTIFICADO',
#   'CUMPLIMIENTO',
#   'BUENAS',
#   'PRACTICAS',
#   'FABRICA'],
#  ['SITAGLIPTINA',
#   'METFORMINA',
#   'SITAGLIPTINA',
#   '1000',
#   'METFORMINA',
#   'COMPRIMIDOS',
#   'RECUBIERTOS'],
#  ['SITAGLIPTINA',
#   'METFORMINA',
#   'CLORHIDRATO',
#   'CAJA',
#   'COMPRIMIDOS',
#   'RECUBIERTOS'],
#  ['METFORMINA',
#   '850MG',
#   'VIDAGLIPTINA',
#   '50MG',
#   'CAJA',
#   'COMP',
#   'SIMILAR',
#   'JALRA',
#   'ADJUNTAN',
#   'BASES',
#   'ADMINISTRATIVAS',
#   'TECNICAS',
#   'LEERLAS',
#   'OFERTAR',
#   '"")"'],
#  ['CTTO',
#   'SUMINISTRO',
#   'MEDICAMENTOS',
#   'SEGÚN',
#   'FORMULARIO',
#   'DETALLE',
#   'OFERTA',
#   'ECONÓMICA',
#   'MEDICAMENTOS',
#   'BASES',
#   'ADMINISTRATIVAS',
#   'TÉCNICAS',
#   'ADJUNTAS',
#   'INGRESAR',
#   'PORTAL',
#   'VALOR',
#   'EXPRESADO',
#   'PESOS',
#   'CHILENOS',
#   'ANEXOS'],
#  ['LINAGLIPTINA', 'METFORMINA', '1000MG'],
#  ['INSULINA', 'ULTRA', 'RAPIDA', '100UI'],
#  ['METFORMINA', '1000', 'COMPRIMIDOS', 'BIOEQUIVALENTE'],
#  ['METFORMINA', 'CLORHIDRATO', '1000', 'LIBERACION', 'PROLONGADA'],
#  ['METFORMINA', 'COMP', 'LIBERACION', 'PROLONGADA'],
#  ['JANUMET', 'COMPRIMIDO', '1000MG'],
#  ['VILDAGLIPTINA',
#   'METFORMINA',
#   '1000',
#   'COMPRIMIDOS',
#   'SIMILAR',
#   'GALVUS',
#   '1000',
#   'COMPRIMIDOS'],
#  ['8434', 'INSULINA', 'ACCION', 'RAPIDA', 'VIAL', 'CRISTALINA'],
#  ['INSULINA', 'ULTRAPIDA', 'LISPRO', 'CARTUCHO', '2620034'],
#  ['INSULINA', 'ISOFANA', 'SOLUCION', 'INYECTABLE'],
#  ['1000', 'COMP'],
#  ['GLIFORTEX', '750MG', 'COMP', 'SIMILAR'],
#  ['SITAGLIPTINA',
#   'METFORMINA',
#   '1000',
#   'COMPRIMIDOS',
#   'SIMILAR',
#   'JANUMET',
#   '1000',
#   'COMP'],
#  ['METFORMINA', 'COMPRIMIDO', 'RECUBIERTO'],
#  ['40400170048', 'METFORMINA'],
#  ['INSULINA',
#   'DEGLUDEX',
#   'SOLUCIÓN',
#   'INYECTABLE',
#   'LÁPIZ',
#   'DESCARTABLE',
#   'UNIDAD',
#   'LÁPIZ'],
#  ['METFORMINA', '750MG', 'COMPRIMIDO', 'LIBERACIÓN', 'PROLONGADA'],
#  ['METFORMINA',
#   'CONVENIO',
#   'FOFAR',
#   'CAJA',
#   'COMPRIMIDOS',
#   'LIBERACIÓN',
#   'PROLONGADA',
#   'SEGÚN',
#   'BASES',
#   'ADMINISTRATIVAS',
#   'ADJUNTAS'],
#  ['METFORMINA',
#   'VILDAGLIPTINA',
#   'COMPRIMIDOS',
#   'ENVASE',
#   'SELLADO',
#   'RESISTENTE',
#   'INADULTERADO',
#   'SIMILAR',
#   'GALVUS'],
#  ['METFORMINA', 'LIBERACIÓN', 'PROLONGADA', '1000'],
#  ['DIAMICRON'],
#  ['METFORMINA',
#   'COMPRIMIDOS',
#   'LIBERACIÓN',
#   'PROLONGADA',
#   'SIMILAR',
#   'HIPOGLUCIN',
#   'COMP'],
#  ['METFORMINA', '750MG', 'LIBERACION', 'PROLONGADA'],
#  ['METFORMINA', 'GLIBENCLAMIDA', 'CAJA', 'COMPRIMIDOS'],
#  ['XIGDUO', '1000', 'COMP', 'SIMILAR'],
#  ['CAJA',
#   'COMPRIMIDO',
#   'RECUBIERTO',
#   'CONTIENE',
#   'EMPAGLIFLOZINA',
#   'CLORHIDRATO',
#   'METFORMINA',
#   'SIMILAR',
#   'JARDIANCE'],
#  ['METFORMINA',
#   'CLORHIDRATO',
#   '1000',
#   'COMPRIMIDOS',
#   'LIBERACIÓN',
#   'PROLONGADA',
#   'EQUIVALENTE',
#   'GLICENEX',
#   '1000',
#   'COMP'],
#  ['INSULINA',
#   'ULTRA',
#   'RÁPIDA',
#   'ASPARTICA',
#   'LISPRO',
#   'GLULISINA',
#   'CARTUCHO',
#   '1000'],
#  ['INSULINA', 'CURVA', 'MUESTRAS'],
#  ['METFORMINA'],
#  ['METFORMINA',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   'LIBERACIÓN',
#   'PROLONGADA',
#   '500MG',
#   'PRESENTACIÓN',
#   'VENTA',
#   'PÚBLICO',
#   'CONVENIENTE',
#   'DESDE',
#   'PUNTO',
#   'VISTA',
#   'PRECIO',
#   'MENOS',
#   'MESES',
#   'EFICACIA',
#   'CERTIFICADO',
#   'ACREDITE',
#   'FABRICADO',
#   'PAÍSES',
#   'AGENCIAS',
#   'ALTA'],
#  ['METFORMINA',
#   'CAJA',
#   'COMPRIMIDOS',
#   'LIBERACIÓN',
#   'PROLONGADA',
#   'EQUIVALENTE',
#   'GLAFORNIL'],
#  ['METFORMINA', 'LIBERACIÓN', 'PROLONGADA'],
#  ['METFORMINA', '1000MG', 'PROLONG', 'COMPRIMIDOS'],
#  ['EMPAGLIFLOZINA',
#   'METFORMINA',
#   '850MG',
#   'COMPRIMIDOS',
#   'SEGÚN',
#   'EXIGIDO',
#   'BASES',
#   'ADMINISTRATIVAS',
#   'TÉCNICAS'],
#  ['TRAYENTA', '1000', 'COMPRIMIDOS'],
#  ['0113', 'INSULINA', 'GLULISINA', 'LAPIZ'],
#  ['SITAGLIPTINA',
#   '50MG',
#   'METFORMINA',
#   '1000',
#   'COMPRIMIDOS',
#   'LIBERACIÓN',
#   'PROLONGADA'],
#  ['SITAGLIPTINA',
#   'METFORMINA',
#   '1000',
#   'CAJA',
#   'COMPRIMIDOS',
#   'LIBERACION',
#   'PROLONGADA',
#   'JANUMET',
#   '1000'],
#  ['VILDAGLIPTINA',
#   'METFORMINA',
#   '1000MG',
#   'COMPRIMIDO',
#   'FECHA',
#   'VENCIMIENTO',
#   'MAYOR',
#   'DESDE',
#   'RECEPCIÓN',
#   'ACEPTAN',
#   'CARTAS',
#   'CANJE'],
#  ['INSULINA', 'LANTUS', 'SOLOSTAR', '100UI'],
#  ['METFORMINA',
#   'SITAGLIPTINA',
#   'CAJA',
#   'COMP',
#   'SIMILAR',
#   'JANUMET',
#   '.....(',
#   'INDICAR',
#   'FECHA',
#   'VENCIMIENTO',
#   'REGISTRO'],
#  ['INSULINA', 'INSULATARD', 'HUMANA'],
#  ['REQUIERE',
#   'METFORMINA',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   'BLISTER',
#   'ENVASE',
#   'RESISTENTE',
#   'SELLO',
#   'ASEGURE',
#   'INVIOLABILIDAD',
#   'COTENIDO',
#   'MEDICAMENTO',
#   'SOLICITADO',
#   'DEBE',
#   'TENER',
#   'FECHA',
#   'VENCIMIENTO',
#   'SUPERIOR'],
#  ['ENVASE',
#   'COMPRIMIDOS',
#   'CONTIENE',
#   'VILDAGLIPTINA',
#   'METFORMINA',
#   'CLORHIDRATO',
#   'SIMILAR',
#   'IGUAL',
#   'GALVUS'],
#  ['INSULINA', 'DEGLUDEC', 'DISP', '100004348'],
#  ['VILDAGLIPTINA', 'METFORMINA', 'GALVUS'],
#  ['METFOTMINA', 'LIBERACION', 'PROLONGADA', 'COMPRIMIDOS'],
#  ['JERINGAS', 'INSULINA', 'FIJA'],
#  ['SITAGLIPINA', 'METFORMINA', 'CLORHIDRATO', 'COMP', 'JANUMET'],
#  ['JERINGAS',
#   'INSULINA',
#   'AGUJA',
#   'COTIZAR',
#   'UNIDAD',
#   'VENCIMIENTO',
#   'MÍNIMO',
#   'MESES'],
#  ['METFORMINA',
#   '1000MG',
#   'ASOCIADO',
#   'SITAGLIPTINA',
#   '50MG',
#   'SEGÚN',
#   'EXIGIDO',
#   'BASES',
#   'ADMINISTRATIVAS',
#   'TÉCNICAS',
#   'ANEXOS',
#   'ADJUNTOS'],
#  ['VILDAGLIPTINA', 'CLORHIDRATO', 'METFORMINA', 'SIMILAR', 'JALRA'],
#  ['0242', 'JERINGA', 'INSULINA', 'INDIVIDUAL'],
#  ['METFORMINA', 'CLORHIDRATO', 'COMPRIMIDO', 'RECUBIERTO'],
#  ['METFORMINA',
#   'COMPRIMIDOS',
#   'LIBERACION',
#   'PROLONGADA',
#   'ENVASADO',
#   'BLISTER',
#   'SIMILAR',
#   'ALUMINO',
#   'IMPRESO',
#   'ENVASE',
#   'CONTIENE',
#   'COMPRIMIDOS'],
#  ['LINAGLIPTINA', 'METFORMINA', '1000', 'TABLETAS', 'SIMILAR', 'TRAYENTA'],
#  ['METFORMINA', '1000MG', 'LIBERACION', 'PROLONGADA'],
#  ['SITAGLIPTINA',
#   'METFORMINA',
#   'CLORHIDRATO',
#   '1000',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   'LIBERACIÓN',
#   'PROLONGADA'],
#  ['GLIBENCLAMIDA', 'METFORMINA'],
#  ['INSULINA', 'FRASCO', 'AMPOLLA'],
#  ['METFORMINA',
#   'GLIBENCLAMIDA',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   'EQUIVALENTE',
#   'GLUCOVANCE',
#   '500MG',
#   'HIPOGLUCIN'],
#  ['GLIFORTEX'],
#  ['JANUMET', '1000', 'COMPRIMIDOS'],
#  ['0084',
#   'INSULINA',
#   'GLULISINA',
#   'CARTRIDGE',
#   'DISPOSITIVO',
#   'PRELLENADO',
#   'DESECHABLE',
#   'PARA',
#   'DISPENSACIÓN'],
#  ['FLEETGLICOL', 'POLVO', 'PARA', 'SOLUCIÓN', 'ORAL', 'SOBRES'],
#  ['GLAUPAX', 'CAJA', 'EQUIVALENTE'],
#  ['SITAGLIPTINA', 'METFORMINA', 'COMPRIMIDOS'],
#  ['METFORMINA', '850MG', 'CARDIOVASCULAR'],
#  ['LEVENIR', 'FLEX', 'PENCIL'],
#  ['XIGDUO', '1000', 'DAPAGLIFLOZINA', 'METFORMINA', '1000'],
#  ['METFORMINA', 'CLORHIDRATO', 'COMPRIMIDO', 'RECUBIERTO'],
#  ['INSULINA',
#   'DEGLUDEC',
#   'SIMILAR',
#   'TRESIBA',
#   'CAJA',
#   'DISPOSITIVO',
#   'PRELLENADO',
#   'SUBCUTANEO'],
#  ['METFORMINA', '1000', 'SITAGLIPTINA', '50MG', 'JANUMET'],
#  ['EMPAGLIFLOZINA',
#   '1000MG',
#   'CLORHIDRATO',
#   'METFORMINA',
#   'COMPRIMIDOS',
#   'RECUBIERTOS'],
#  ['EMPAGLIFOZINA',
#   'METFORMINA',
#   'CLORHIDRATO',
#   '1000',
#   'CAJA',
#   'COMPRIMIDOS',
#   'RECUBIERTOS'],
#  ['INSULINA', 'FRASCO', 'AMPOLLA'],
#  ['METFORMINA', 'CLORHIDRATO', 'COMPRIMIDO', 'FOFAR'],
#  ['6545', 'METFORMINA', 'COMPRIMIDOS'],
#  ['SAXAGLIPTINA',
#   'METFORMINA',
#   'SAXAGLIPTINA',
#   '1000',
#   'METFORMINA',
#   'COMPRIMIDOSS',
#   'LIBERACION',
#   'EXTENDIDA'],
#  ['1092023',
#   'INSULINA',
#   'ASPARTATO',
#   'RECOMBINANTE',
#   '100UI',
#   'LAPIZ',
#   'VIGENCIA',
#   'SUPERIOR',
#   'EQUIVALENTE',
#   'NOVORAPID',
#   'FLEXPEN'],
#  ['SITAGLIPTINA',
#   'METFORMINA',
#   '1000',
#   'ENVASE',
#   'COMPRIMIDOS',
#   'JANUMET',
#   'MAXIMO',
#   'PAGAR'],
#  ['GALVUS', 'SIMILAR', 'VIDAGLIPTINA', 'METFORMINA', 'COMPRIMIDOS'],
#  ['METFORMINA', '500MG', 'COMP'],
#  ['INSULINA', 'GLARGINA', 'RECOMB', 'LAPIZ'],
#  ['SITAGLIPTINA', 'METFORMINA', '1000'],
#  ['XIGDUO', '1000MG', 'COMPRIMIDO'],
#  ['GLIBENCLAMIDA', 'METFORMINA', 'CLORHIDRATO', 'COMPRIMIDO'],
#  ['GLAFORNIL', '1000'],
#  ['METFORMINA', 'COMPRIMIDOS', 'RECUBIERTOS', 'SIMILAR', 'GLAFORNIL'],
#  ['METFORMINA', '1000MG', 'LIBERACION', 'PROLONGADA'],
#  ['INSULINA', 'ASPARTA', 'BIFÁSICA', 'LÁPICES'],
#  ['GLIFORTEX', '1000', 'COMP'],
#  ['METFORMINA', 'CLORHIDRATO', 'COMPRIMIDOS', 'RECUBIERTOS'],
#  ['KOMBIGLYZE', '1000'],
#  ['0096', 'INSULINA', 'ANÁLOGA', 'ASPÁRTICA'],
#  ['1093059',
#   'CADA',
#   'COMPRIMIDO',
#   'CONTIENE',
#   'PRINCIPIOS',
#   'ACTIVOS',
#   'SITAGLIPTINA',
#   '50MG',
#   'METFORMINA',
#   '1000MG',
#   'PARA',
#   'ADMINISTRACION',
#   'ORAL',
#   'FORMA',
#   'FARMACEUTICA',
#   'COMPRIMIDOS',
#   'RECUBRIMIENTO',
#   'EQUIVALENTE',
#   'JANUMET',
#   '1000',
#   'COMP'],
#  ['METFORMINA', '850MG', 'COMPRIMIDO', 'RECUBIERTO'],
#  ['VILDAGLIPTINA', 'CLORHIDRATO', 'METFORMINA'],
#  ['FIJA'],
#  ['INSULINA',
#   'DEGLODEC',
#   'SOLUCION',
#   'INYECTABLE',
#   'DISPOSITIVO',
#   'PRELLENADO',
#   'IGUAL',
#   'SUPERIOR',
#   'TRESIBA',
#   'NOTA',
#   'SUGIERE',
#   'FECHA',
#   'VENCIMIENTO',
#   'SUPERIOR',
#   'CASO',
#   'CONTRARIO',
#   'CONTAR',
#   'POLITICAS',
#   'CANJE'],
#  ['GLIBENCLAMIDA', 'METFORMINA', 'COMPRIMIDO'],
#  ['METFORMINA', '040400170048'],
#  ['1092030',
#   'INSULINA',
#   'DEGLUDEC',
#   'RECOMBINANTE',
#   'FLEXPEN',
#   'EQUIVALENTE',
#   'TRESIBA',
#   'PLEXPEN'],
#  ['1092019',
#   'INSULINA',
#   'GLARGINA',
#   '100UI',
#   'LAPICERA',
#   'LLENADA',
#   'EQUIVALENTE',
#   'LANTUS',
#   '100UI',
#   'LAPIZ'],
#  ['METFORMINA'],
#  ['METFORMINA',
#   'LINAGLIPTINA',
#   'ENVASE',
#   'COMPRIMIDOS',
#   'FECHA',
#   'VENCIMIENTO',
#   'MENOR',
#   'MESES'],
#  ['GLIBENCLAMIDA', 'METFORMINA', '500MG'],
#  ['METFORMINA',
#   'CLORHIDRATO',
#   'ENVASADO',
#   'BLISTER',
#   'SIMILAR',
#   'ALUMINIO',
#   'IMPRESO',
#   'COMP',
#   'LIBERACIÓN',
#   'PROLONGADA'],
#  ['METFORMINA', 'COMP'],
#  ['SAXAGLIPTINA',
#   'METFORMINA',
#   '1000',
#   'SIMILAR',
#   'KOMBIGLYZE',
#   '1000',
#   'COMPRIMIDOS'],
#  ['METFORMINA', 'CLORHIDRATO', 'COMPRIMIDOS', 'RECUBIERTO'],
#  ['1092019',
#   'LANTUS',
#   '100UI',
#   'LAPIZ',
#   'INSULINA',
#   'GLARGINA',
#   '100UI',
#   'LAPICERA',
#   'LLENADA'],
#  ['METFORMINA',
#   '500MG',
#   'COMPRIMIDOS',
#   'FECHA',
#   'VENCIMIENTO',
#   'MAYOR',
#   'DESDE',
#   'FECHA',
#   'RECEPCIÓN',
#   'ACEPTAN',
#   'CARTAS',
#   'CANJE'],
#  ['METFORMINA', 'VILDAGLIPTINA', 'COMP'],
#  ['METFORMINA', '1000', 'LIBERACION', 'PROLONGADA', 'COMP'],
#  ['METFORMINA',
#   'COMPRIMIDOS',
#   '1000MG',
#   'LIBERACION',
#   'PROLONGADA',
#   'ENVASE',
#   'BLISTER',
#   'ASEGURE',
#   'INVIOLABILIDAD',
#   'FECHA',
#   'VENCIMIENTO',
#   'SUPERIOR',
#   'AÑOS'],
#  ['0017',
#   'INSULINA',
#   'RETARDADA',
#   'SOLUCION',
#   'INYECTABLE',
#   'FRASCO',
#   'AMPOLLA'],
#  ['GLAFORNIL', '1000', 'METFORMINA', 'CAJA', 'COMPRIMIDOS'],
#  ['METFORMINA', 'COMPRIMIDO'],
#  ['METFORMINA',
#   '1000',
#   'CAJA',
#   'COMPRIMIDOS',
#   'LIBERACIÓN',
#   'PROLONGADA',
#   'EQUIVALENTE',
#   'GLIFORTEX',
#   '1000'],
#  ['SUMINISTRO',
#   'VILDAGLIPTINA',
#   'METFORMINA',
#   'CLORHIDRATO',
#   'EQUIVALENTE',
#   'GALVUS',
#   'CAJA',
#   'COMPRIMIDOS',
#   'RECUBIERTOS'],
#  ['INSULINA', 'GLARGINA', 'LAPIZ', 'TOUJEO'],
#  ['INSULINA', 'CRISTALINA'],
#  ['METFORMINA'],
#  ['REQUIERE', 'METFORMINA', '1000', 'LIBERACIÓN', 'PROLONGADA'],
#  ['VILDAGLIPTINA', 'METFORMINA', '1000', 'CAJA', 'COMPRIMIDOS'],
#  ['METFORMINA', '1000', 'SEGUN', 'ESPECIFICACIONES', 'TECNICAS'],
#  ['1300105', 'METFORMINA', 'ACCIÓN', 'SOSTENIDA', 'OCASIONAL'],
#  ['VILDAGLIPTINA',
#   'METFORMINA',
#   'COMP',
#   'RECUBIERTO',
#   'VENCIMIENTO',
#   'MAYOR',
#   'ACEPTAN',
#   'CARTAS',
#   'CANJE'],
#  ['METFORMINA', 'COMPRIMIDOS', 'VENCIMIENTO', 'MÍNIMO', '2023'],
#  ['METFORMINA', 'MGRS', 'COMPRIMIDOS'],
#  ['METFORMINA',
#   '850MG',
#   'COMPRIMIDOS',
#   'FECHA',
#   'VENCIMIENTO',
#   'MAYOR',
#   'DESDE',
#   'FECHA',
#   'RECEPCIÓN',
#   'ACEPTAN',
#   'CARTAS',
#   'CANJE'],
#  ['LINAGLIPTINA', 'METFORMINA', 'COMPRIMIDOS', 'SIMILAR', 'TRAYENTA'],
#  ['METFORMINA',
#   'VILDAGLIPTINA',
#   '50MG',
#   'CAJA',
#   'COMP',
#   'SIMILAR',
#   'JALRA',
#   '.....(',
#   'INDICAR',
#   'FECHA',
#   'VENCIMIENTO',
#   'REGISTRO'],
#  ['LINEA', 'METFORMINA', 'COMPRIMIDO'],
#  ['METFORMINA', 'SITAGLIPTINA', 'COMPRIMIDOS', 'JANUMET', 'SIMILAR'],
#  ['GLIFORTEX', '1000', 'METFORMINA', 'CAJA', 'COMPR'],
#  ['MAPEO', 'TERMICO', 'INVIERNO', 'DROGUERIA', 'SERVICIO', 'SALUD', 'IQUIQUE'],
#  ['INSULINA', 'ASPARTATO', 'CARTRIDGE', 'PENFIL'],
#  ['METFORMINA', 'COMP'],
#  ['METFORMINA',
#   'VILDAGLIPTINA',
#   '50MG',
#   'CAJA',
#   'COMP',
#   'SIMILAR',
#   'JALRA',
#   'ADJUNTAN',
#   'BASES',
#   'ADMINISTRATIVAS',
#   'TÉCNICAS',
#   'LEERLAS',
#   'OFERTAR'],
#  ['METFORMINA', '1000MG', 'COMP', 'PROLONGADA', 'CAJA', 'COMP'],
#  ['METFORMINA', 'COMPRIMIDOS', 'RECUBIERTOS'],
#  ['METFORMINA', '1000MG', 'LIBERACION', 'PROLONGADA'],
#  ['CURVA', 'INSULINA'],
#  ['INSULINA', 'GLULISINA'],
#  ['DAPAGLIFLOZINA',
#   'COMO',
#   'PROPANODIOL',
#   'METFORMINA',
#   'CLORHIDRATO',
#   '1000',
#   'COMP'],
#  ['VILDAGLIPTINA', 'METFORMINA', 'COMPRIMIDOS'],
#  ['CAJAS', '1000', 'COMPRIMIDOS', 'METFORMINA', '850MG'],
#  ['METFORMINA',
#   '1000',
#   'COMPRIMIDOS',
#   'LIBERACION',
#   'PROLONGADA',
#   'PRESENTACION'],
#  ['DAPAGLIFLOZINA',
#   'COMO',
#   'PROPANODIOL',
#   'METFORMINA',
#   'CLORHIDRATO',
#   '1000',
#   'ENVASE',
#   'CONTENIENDO',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   'LIBERACIÓN',
#   'PROLONGADA'],
#  ['METFORMINA',
#   '1000MG',
#   'LIBERACION',
#   'PROLONGADA',
#   'COTIZAR',
#   'COMPRIMIDO',
#   'VENCIMIENTO',
#   'IGUAL',
#   'SUPERIOR',
#   'MESES',
#   'INDICAR',
#   'MONTO',
#   'MÍNIMO',
#   'FACTURACIÓN',
#   'DESPACHO',
#   'LINEA',
#   'COTIZAR',
#   'SOLO',
#   'STOCK'],
#  ['METFORMINA',
#   'COMP',
#   'GLAFORNIL',
#   'GLICENEX',
#   'GLIDANIL',
#   'GLIFORTEX',
#   'GLUCOPAGE',
#   'HIPOGLUCIN',
#   'METFORMINA'],
#  ['METFORMINA',
#   'COMPRIMIDOS',
#   'LIBERACION',
#   'PROLONGADA',
#   'SIMILAR',
#   'GLAUPAX',
#   'COMP'],
#  ['40400170196',
#   'INSULINA',
#   'GLARGINA',
#   'LÁPIZ',
#   'LAPICERA',
#   'PRELLENADA',
#   'SOLUCIÓN',
#   'INYECTABLE',
#   'OFERENTES',
#   'DEBERÁN',
#   'CONSIDERAR',
#   'ENTREGA',
#   'AGUJAS',
#   'CADA',
#   'LÁPIZ'],
#  ['METFORMINA',
#   'COMPRIMIDO',
#   '850MG',
#   'BLISTER',
#   'ALUMINIO',
#   'IMPRESO',
#   'ENVASE',
#   'RESISTENTE',
#   'SELLO',
#   'ASEGURE',
#   'INVIOLABILIDAD',
#   'CONTENIDO',
#   'FECHA',
#   'VENCIMIENTO',
#   'SUPERIOR',
#   'AÑOS'],
#  ['METFORMINA', 'COMPRIMIDO', '750MG', 'LIBERACIÓN', 'PROLONGADA'],
#  ['2244074',
#   'AGUJA',
#   'HIPODERMICA',
#   'DESC',
#   'ENTREGA',
#   'INMEDATA',
#   'DIAS',
#   'HABILES'],
#  ['VILDAGLIPTINA', 'METFORMINA', '1000', 'CAJA', 'COMPRIMIDOS'],
#  ['COMPRESAS',
#   'FRIO',
#   'CALIENTE',
#   'PARA',
#   'INSULINA',
#   'PARA',
#   'PACIENTES',
#   'APROXIMADAMENTE'],
#  ['METFORMINA', 'COTIZAR', 'COMPRIMIDOS', 'VENCIMIENTOS', 'MÍNIMO', 'MESES'],
#  ['VILDAGLIPTINA',
#   'METFORMINA',
#   '850MG',
#   'COMPRIMIDOS',
#   'ENVASADAS',
#   'BLISTER',
#   'SIMILAR',
#   'ALUMINIO',
#   'IMPRESO',
#   'ENVASE',
#   'CONTENIDO',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   'CERTIFICACION',
#   'PLANTA',
#   'PRODUCTORA',
#   'TIPO',
#   'GALVUS'],
#  ['METFORMINA', 'COMPRIMIDO', 'UNITARIO', 'ENVASE', 'COMERCIAL', 'CLINICO'],
#  ['METFORMINA', 'COMPRIMIDOS', 'LIBERACIÓN', 'PROLONGADA'],
#  ['GLULISINA', '100UI', 'LAPIZ', '100006440'],
#  ['METFORMINA', 'ENVASE', 'CLÍNICO', 'COMPRIMIDOS'],
#  ['DAPAGLIFLOZINA',
#   'COMO',
#   'PROPANODIOL',
#   'METFORMINA',
#   'CLORHIDRATO',
#   '1000',
#   'COMPRIMIDOS',
#   'LIBERACION',
#   'PROLONGADA',
#   'SIMILAR',
#   'XIGDUO',
#   '1000',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   'LIBERACIÓN',
#   'PROLONGADA'],
#  ['GLAFORNIL', 'CAJA', 'EQUIVALENTE'],
#  ['LINAGLIPTINA', 'METFORMINA', '1000', 'COMPRIMIDOS'],
#  ['METFORMINA', '500MG', 'GLIBENCLAMIDA', 'COMP'],
#  ['2620056', 'INSULINA', 'DEGLUDEC', '100UI', 'LAPIZ'],
#  ['CAJAS', '1000', 'COMPRIMIDOS', 'METFORMINA', '850MG'],
#  ['INSULINA',
#   'DETEMIR',
#   'RECOMBINANTE',
#   'CARTUCHO',
#   'PRESENTACIÓN',
#   'VENTA',
#   'PÚBLICO',
#   'CONVENIENTE',
#   'DESDE',
#   'PUNTO',
#   'VISTA',
#   'PRECIO',
#   'MENOS',
#   'MESES',
#   'EFICACIA',
#   'CERTIFICADO',
#   'ACREDITE',
#   'FABRICADO',
#   'PAÍSES',
#   'AGENCIAS',
#   'ALTA',
#   'VIGILANCIA',
#   'SANIT'],
#  ['GLIBENCLAM', 'METFOR', '100000717'],
#  ['INSULINA',
#   'ASPARTA',
#   'RECOMBINANTE',
#   '100U',
#   'FRASCO',
#   'AMPOLLA',
#   'FRASCO',
#   'AMPOLLA'],
#  ['METFORMINA', '750XR', 'COMP'],
#  ['METFORMINA', '1000', 'LIBERACION', 'PROLONGADA'],
#  ['METFORMINA', '1000', 'ENVASE', 'COMPRIMIDOS'],
#  ['METFORMINA', '500MG', 'GLIBENCLAMIDA', 'COMPRIMIDOS', 'RECUBIERTOS'],
#  ['SITAGLIPINA',
#   'COMO',
#   'FOSFATO',
#   'MONOHIDRATADO',
#   'METFORMINA',
#   'CLORHIDRATO',
#   '1000',
#   'COMPRIMIDOS',
#   'SIMILAR',
#   'JANUMET',
#   '1000',
#   'COMPRIMIDOS'],
#  ['METFORMINA',
#   'COMPRIMIDO',
#   'RECUBIERTO',
#   'PREFERENCIA',
#   'FORMATO',
#   'OVALADO'],
#  ['DAPAGLIFOZINA',
#   'METFORMINA',
#   'CLORHIDRATO',
#   '1000',
#   'SIMILAR',
#   '1000',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   'LIBERACIÓN',
#   'PROLONGADA'],
#  ['METFORMINA', '1000', 'COMPRIMIDO', 'ACCIÓN', 'PROLONGADA'],
#  ['METFORMINA',
#   '1000',
#   'ENVASE',
#   'COMPRIMIDOS',
#   'LIBERACIÓN',
#   'PROLONGADA',
#   'FECHA',
#   'VENCIMIENTO',
#   'MENOR',
#   'MESES'],
#  ['INSULINA', 'LISPRO', 'SIMILAR', 'HUMALOG', 'KWIKPEN'],
#  ['FA03', '0006', 'INSULINA', 'CRISTALINA', 'RÁPIDA'],
#  ['METFORMINA',
#   '1000',
#   'SITAGLIPTINA',
#   'CAJA',
#   'COMPRIMIDOS',
#   'LIBERACION',
#   'PROLONGADA',
#   'SIMILAR',
#   'JUNAMET',
#   '.....(',
#   'INDICAR',
#   'FECHA',
#   'VENCIMIENTO',
#   'REGISTRO'],
#  ['METFORMINA', 'CLORHIDRATO', 'COMP', 'PROLONGADA'],
#  ['METFORMINA',
#   'COMPRIMIDOS',
#   'BIOEQUIVALENTE',
#   'COMPRIMIDOS',
#   'CAJAS',
#   '1000'],
#  ['GLUCOVANCE'],
#  ['METFORMINA', 'VENCIMIENTO', 'SUPERIOR', 'MESES'],
#  ['VILDAGLIPTINA', 'METFORMINA', '1000'],
#  ['INSULINA', 'CRISTALINA', 'ACCIÓN', 'RÁPIDA'],
#  ['EMPAGLIFOZINA',
#   'METFORMINA',
#   'CAJA',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   'JARDIANCE',
#   'SIMILAR'],
#  ['METFORMINA', 'CLORHIDRATO', 'GLIBENCLAMIDA', 'COMP'],
#  ['INSULINA', 'ASPARTA', 'INYECTABLE'],
#  ['2020',
#   '1999',
#   'ITEM',
#   'DESCRIPCIÓN',
#   'ESTANDAR',
#   'INSULINA',
#   'LISPRO',
#   'CATÁLOGO',
#   'REFERENCIA',
#   '1342321',
#   'UNIDAD',
#   'MEDIDA',
#   'VIAL',
#   'TEMPERATURA',
#   'VENCIMIENTO',
#   'LOTE',
#   'R016UO',
#   'LOTE',
#   'VIGENTE',
#   'SECCION',
#   'PRUEBAS',
#   'BIOLOGICAS'],
#  ['SITAGLIPTINA',
#   'METFORMINA',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   'ENVASE',
#   'COMERCIAL',
#   'CONTENIENDO',
#   'COMPRIMIDOS',
#   'RECUBIERTOS'],
#  ['INSULINA', 'GLARGINA', '300UL', 'AMPOLLA'],
#  ['INSULINA',
#   'DEGLUDEC',
#   '100UI',
#   'SOLUCIÓN',
#   'INYECTABLE',
#   'DISPOSITIVO',
#   'PRELLENADO'],
#  ['LINAGLIPTINA',
#   'METFORMINA',
#   '1000MG',
#   'TRAYENTA',
#   'COMPRIMIDO',
#   'CAJA',
#   'AUMENTARÁ',
#   'CANTIDAD',
#   'SEGÚN',
#   'NECESIDAD',
#   'FARMACIA',
#   'POPULAR'],
#  ['METFORMINA', 'COMP'],
#  ['METFORMINA',
#   '1000',
#   'COMPRIMIDOS',
#   'LIBERACIÓN',
#   'PROLONGADA',
#   'MEDICAMENTO',
#   'DEBE',
#   'TENER',
#   'VENCIMIENTO',
#   'MAYOR',
#   'MESES'],
#  ['1092012',
#   'INSULINA',
#   'HUMANA',
#   'RECOMBINANTE',
#   '100UI',
#   '10ML',
#   'SUPENSION',
#   'INYECTABLE',
#   'EQUIVALENTE',
#   'INSULINA',
#   'ACTRAPID',
#   '100UI',
#   'AMPOLLA'],
#  ['METFORMINA', '1000', 'COMPRIMIDO'],
#  ['SITAGLIPTINA',
#   'METFORMINA',
#   'COMPRIMIDOS',
#   'NOTA',
#   'SUGIERE',
#   'FECHA',
#   'VENCIMIENTO',
#   'SUPERIOR',
#   'CASO',
#   'CONTRARIO',
#   'CONTAR',
#   'POLITICAS',
#   'CANJE'],
#  ['JERINGAS', 'INSULINA'],
#  ['METFORMINA', 'CLORHIDRATO', '1000'],
#  ['METFORMINA',
#   '1000',
#   'PRESENTAR',
#   'FECHA',
#   'VENCIMIENTO',
#   'REVISAR',
#   'BASES',
#   'ADJUNTAS'],
#  ['METFORMINA', '1000', 'COMP'],
#  ['METFORMINA',
#   'CLORHIDRATO',
#   'ENVASADO',
#   'BLISTER',
#   'SIMILAR',
#   'ALUMINIO',
#   'IMPRESO',
#   'COMP',
#   'RECUBIERTOS'],
#  ['GLAFORNIL', '1000MG', 'COMP', 'SIMILAR'],
#  ['HIPOGLUCIN', 'METFORMINA', 'GLIBENCLAMIDA', 'CAJA', 'COMPRIMIDOS'],
#  ['EMPAGLIFLOZINA', 'CLORHIDRATO', 'METFORMINA', 'SIMILAR', 'JARDIANCE'],
#  ['METFORMINA', 'COMPRIMIDO', 'LIBERACION', 'PROLONGADA'],
#  ['INSULINA', 'CRISTALINA'],
#  ['METFORMINA', 'COMPRIMIDOS', 'OBLONGOS', 'RANURADOS'],
#  ['METFORMINA',
#   '1000',
#   'COMPRIMIDOS',
#   'LIBERACIÓN',
#   'PROLONGADA',
#   'BLÍSTER',
#   'IMPRESO',
#   'ALUMINIO',
#   'LÁMINA',
#   'PVDC',
#   'INCOLORO',
#   'EXCIPIENTES',
#   'HIPROMELOSA',
#   'LACTOSA',
#   'MONOHIDRATO',
#   'CELULOSA',
#   'MICROCRISTALINA',
#   'MAGNESIO',
#   'ESTEARATO',
#   'DESEABLE',
#   'ENVASE',
#   'CLÍNICO'],
#  ['JERINGA', 'INSULINA'],
#  ['INSULINA', 'GLARGINA', 'LAPIZ'],
#  ['LINAGLIPTINA',
#   'CLORHIDRATO',
#   'METFORMINA',
#   '1000',
#   'ENVASADO',
#   'BLISTER',
#   'SIMILAR',
#   'ALUMINIO',
#   'IMPRESO',
#   'COMP',
#   'RECUBIERTOS'],
#  ['METFORMINA', 'COMPRIMIDOS', 'CAJA'],
#  ['METFORMINA', '1000MG', 'LIBERACIÓN', 'PROLONGADA'],
#  ['SITAGLIPTINA', 'METFORMINA', '1000', 'CAJA', 'COMPRIMIDOS'],
#  ['METFORMINA',
#   '850MG',
#   'COTIZAR',
#   'COMPRIMIDO',
#   'VENCIMIENTO',
#   'IGUAL',
#   'SUPERIOR',
#   'MESES',
#   'INDICAR',
#   'MONTO',
#   'MÍNIMO',
#   'FACTURACIÓN',
#   'DESPACHO'],
#  ['METFORMINA', 'COMPRIMIDOS'],
#  ['GALVUS', 'COMP'],
#  ['INSULINA', 'DEGLUDEC', 'SIMILAR', 'TRESIBA', 'FLEXTOUCH'],
#  ['METFORMINA',
#   'CLORHIDRATO',
#   '1000MG',
#   'COMPRIMIDO',
#   'LIBERACIÓN',
#   'PROLONGADA'],
#  ['LINAGLIPTINA',
#   'METFORMINA',
#   '1000',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   'ENVASE',
#   'COMERCIAL',
#   'CONTENIENDO',
#   'COMPRIMIDOS',
#   'RECUBIERTOS'],
#  ['GLAUPAX', '1000'],
#  ['LINAGLIPTINA', 'METFORMINA', '1000', 'COMP', 'SIMILAR', 'TRAYENTA', '1000'],
#  ['SITAGLIPTINA', '50MG', 'METFORMINA', '1000', 'COMPRIMIDOS', 'RECUBIERTOS'],
#  ['0068',
#   'INSULINA',
#   'ASPARTO',
#   '100UI',
#   'MLX3',
#   'DEBE',
#   'CONSIDERAR',
#   'BONIFICACION',
#   'AGUJAS',
#   'LAPIZ',
#   'LAPIZ',
#   'DESECHABLE',
#   '2560'],
#  ['GLUKAUT'],
#  ['SITAGLIPTINA', 'METFORMINA', 'COMP', 'RECUBIERTOS', 'CAJA', 'COMPRIMIDOS'],
#  ['FA03', '0005', 'INSULINA', 'ASPARTATO', 'LAPIZ', 'ULTRA', 'RAPIDA'],
#  ['INSULINA',
#   'HUMANA',
#   'RECOMBINANTE',
#   '100UI',
#   'SOLUCION',
#   'INYECTABLE',
#   'VIAL',
#   'INSULINA',
#   'HUMANAN',
#   'ACCIÓN',
#   'RÁPIDA'],
#  ['INSULINA',
#   'ULTRALENTA',
#   'DEGLUDEC',
#   '100UI',
#   'LAPIZ',
#   'DESECHABLE',
#   '2620067'],
#  ['METFORMINA',
#   'COMPRIMIDO',
#   'LIBERACION',
#   'PROLONGADA',
#   'ENVASADO',
#   'BLISTER'],
#  ['SUMINISTRO', 'METFORMINA', 'COMPRIMIDOS'],
#  ['METFORMINA',
#   'CAJA',
#   'COMP',
#   'PROL',
#   'SIMILAR',
#   'GLICENEX',
#   'ADJUNTAN',
#   'BASES',
#   'ADMINISTRATIVAS',
#   'TECNICAS',
#   'LEERLAS',
#   'PARA',
#   'OFERTAR',
#   '"")"'],
#  ['FAAA10013', 'INSULINA', 'ASPART', 'RAPIDA', '100UI', 'CART'],
#  ['METFORMINA', 'GLAFORNIL', 'MERCK'],
#  ['METFORMINA',
#   'GLIBENCLAMIDA',
#   'COMPRIMIDOS',
#   'REECUBIERTOS',
#   'PRESENTACIÓN',
#   'VENTA',
#   'PÚBLICO',
#   'CONVENIENTE',
#   'DESDE',
#   'PUNTO',
#   'VISTA',
#   'PRECIO',
#   'MENOS',
#   'MESES',
#   'EFICACIA',
#   'FABRICADO',
#   'CHILE',
#   'CERTIFICADO',
#   'CUMPLIMIENTO',
#   'BUENAS',
#   'PRACTICAS',
#   'FABRIC'],
#  ['METFORMINA', '1000', 'SITAFLIPTINA', '50MG', 'SOCIAL'],
#  ['CAJAS', 'JERINGAS', 'DESECHABLES', 'CAJAS', 'UNIDADES'],
#  ['JERINGA',
#   'DESECHABLE',
#   'PARA',
#   'INSULINA',
#   'AGUJA',
#   'FIJA',
#   '100UI',
#   'AGUJA'],
#  ['INSULINA', 'GLULISINA', 'LÁPIZ', 'DESECHABLE'],
#  ['INSULINA', 'INYECTABLE'],
#  ['GLIFORTEX'],
#  ['METFORMINA', '1000', 'COMP'],
#  ['METFORMINA',
#   'SITAGLIPTINA',
#   'ENVASE',
#   'COMPRIMIDOS',
#   'FECHA',
#   'VENCIMIENTO',
#   'MENOR',
#   'MESES'],
#  ['LINAGLIPTINA', 'METFORMINA', 'COMP'],
#  ['METFORMINA',
#   '1000',
#   'GLIBENCLAMIDA',
#   'CAJA',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   'EQUIVALENTE',
#   'GLICENEXDUO'],
#  ['METFORM', 'SAXAGLIPTIN', '1000', '100004977'],
#  ['METFORMINA', 'CLORHIDRATO', 'COMPRIMIDO'],
#  ['INSULINA', 'LENTA'],
#  ['JERINGA',
#   'DESECHABLE',
#   'INSULINA',
#   'JERINGA',
#   'INSULINA',
#   'TIPO',
#   'NIPRO',
#   'AGUJA',
#   'CONO',
#   'ACOPLAMIENTO',
#   'CONECTOR',
#   'LUER',
#   'SLIP',
#   'POSEE',
#   'GRADUACIÓN',
#   'FÁCILMENTE',
#   'IDENTIFICABLE',
#   'PARA',
#   'RÁPIDA',
#   'PRECISA',
#   'MEDICIÓN',
#   'VOLUMEN',
#   'ESTERILIZADO',
#   'ÓXIDO',
#   'ETIL'],
#  ['METFORMINA', '1000', 'COMPRIMIDOS', 'LIBERACIÓN', 'PROLONGADA'],
#  ['JANUMET', '1000', 'CAJA', 'EQUIVALENTE'],
#  ['METFORMINA',
#   'COMPRIMIDO',
#   'RECUBIERTO',
#   'RANURADO',
#   'BIOEQUIVALENTE',
#   'ENVASE',
#   'CLÍNICO',
#   'DESPACHO',
#   'PARCIALIZADO'],
#  ['GLICENEX', 'METFORMINA', 'COMPRIMIDOS'],
#  ['METFORMINA', 'COMPRIMIDOS'],
#  ['GLAFORNIL', '1000', 'CAJA', 'COMP'],
#  ['METFORMINA', 'COMP'],
#  ['JERINGAS'],
#  ['1092018',
#   'INSUL',
#   'LEVEMIR',
#   'FLEXPEN',
#   'EQUIVALENTE',
#   'INSUL',
#   'LEVEMIR',
#   'FLEXPEN'],
#  ['METFORMINA',
#   'VILDAGLIPTINA',
#   'CAJA',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   'SIMILAR',
#   'JALRA',
#   '.....(',
#   'INDICAR',
#   'FECHA',
#   'VENCIMIENTO',
#   'REGISTRO'],
#  ['METFORMINA', 'GLIBENCLAMIDA', 'ENVASES', 'CLÍNICOS', 'COMPRIMIDOS'],
#  ['LINAGLIPTINA', 'METFORMINA', '1000'],
#  ['INSULINA', 'ANALOGA', 'ACCIÓN', 'ULTRARAPIDA'],
#  ['METFORMINA',
#   'SITAGLIPTINA',
#   'CAJA',
#   'COMPRIMIDOS',
#   'SIMILAR',
#   'JANUMET',
#   '.....(',
#   'INDICAR',
#   'FECHA',
#   'VENCIMIENTO',
#   'REGISTRO'],
#  ['JERINGA',
#   'DESECHABLE',
#   'PARA',
#   'INSULINA',
#   'AGUJA',
#   'FIJA',
#   '100UI',
#   'AGUJA',
#   'UNIDAD'],
#  ['INSULINA',
#   'DEGLUDEC',
#   'SOLUCION',
#   'INYECTABLE',
#   'ENVASE',
#   'DISPOSITIVO',
#   'PRELLENADO',
#   'SIMILAR',
#   'TRESIBA',
#   'FLEXTOUCH'],
#  ['METFORMINA',
#   'CLORHIDRATO',
#   '1000',
#   'COMPRIMIDOS',
#   'LIBERACION',
#   'PROLONGADA'],
#  ['METFORMINA', '500MG', 'GLIBENCLAMIDA', 'COMPRIMIDOS', 'RECUBIERTOS'],
#  ['METFORMINA', '1000', 'LIBERACION', 'PROLONGADA'],
#  ['EMPAGLIFLOZINA', 'METFORMINA', '850MG', 'JARDIANCE'],
#  ['METFORMINA',
#   'CLORHIDRATO',
#   'COMPRIMIDO',
#   'RECUBIERTO',
#   'EQUIVALENTE',
#   'GLAFORNIL'],
#  ['INSULINA', 'ASPARTATO', 'BIFASICA', '40400170058'],
#  ['VILDAGLIPTINA', '50MG', 'METFORMINA', '850MG', 'CAJA', 'COMP'],
#  ['METFORMINA', 'COMPRIMIDOS', 'RECUBIERTOS'],
#  ['0031',
#   'INSULINA',
#   'GLARGINA',
#   'MLX1ML',
#   'DEBE',
#   'CONSIDERAR',
#   'BONIFICACIÓN',
#   'AGUJAS',
#   'LÁPIZ'],
#  ['INSULINA', 'GLARGINA', 'SOLUCION', 'INYECTABLE', 'SIMILAR', 'SOLOSTAR'],
#  ['INSULINA', 'CARTUCHO', '100UI', 'CÓDIGO', 'HOSPITAL', '2620029'],
#  ['SITAGLIPTINA', 'METFORMINA', 'SIMILAR', 'JANUMET'],
#  ['2145142',
#   'METFORMINA',
#   '850MG',
#   'COMPRIMIDO',
#   'ORAL',
#   'LIBERACION',
#   'CONVENCIONAL'],
#  ['KOMBIGLYZE', '1000', 'RECUBIERTO', 'EQUIVALENTE'],
#  ['TRAYENTA', 'CAJA', 'EQUIVALENTE'],
#  ['METFORMINA', 'COMPRIMIDOS'],
#  ['METFORMINA', 'GLIBENCLAMIDA', 'COMPRIMIDO', 'CÁPSULA'],
#  ['EMPAGLIFLOZINA',
#   'METFORMINA',
#   '1000',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   'ENVASE',
#   'SELLADO',
#   'RESISTENTE',
#   'INADULTERADO',
#   'SIMILAR',
#   'JARDIANCE'],
#  ['2200046',
#   'INSULINA',
#   'ASPARTICA',
#   'SOLUCION',
#   'INYECTABLE',
#   'DISPOSITIVO',
#   'TIPO',
#   'FLEXPEN',
#   'AGUJAS',
#   'COMPATIBLES',
#   'PARA',
#   'DISPOSITIVO',
#   'TIPO',
#   'FLEX'],
#  ['REQUIERE', 'DAPAGLIFLOZINA', 'METFORMINA', '1000', 'COMP'],
#  ['SITAGLIPTINA',
#   'METFORMINA',
#   'COMPRIMIDOS',
#   'NOTA',
#   'SUGIERE',
#   'FECHA',
#   'VENCIMIENTO',
#   'SUPERIOR',
#   'CASO',
#   'CONTRARIO',
#   'CONTAR',
#   'POLITICAS',
#   'CANJE'],
#  ['JANUMET', '1000'],
#  ['METFORMINA', '1000', 'COMP'],
#  ['METFORMINA',
#   'LIBERACIÓN',
#   'PROLONGADA',
#   '1000',
#   'COMPRIMIDO',
#   'REGISTRO',
#   'SANITARIO',
#   'VIGENTE',
#   'VENCIMIENTO',
#   'SUPERIOR',
#   'IGUAL',
#   '2023'],
#  ['METFORMINA', '1000', 'CAJA', 'COMPRIMIDOS', 'LIBERACIÓN', 'PROLONGADA'],
#  ['AGUJAS', 'INSULINA', 'ULTRAFINE'],
#  ['METFORMINA',
#   'CLORHIDRATO',
#   'COMPRIMIDOS',
#   'LIBERACION',
#   'PROLONGADA',
#   'ENVASADOS',
#   'BLISTER',
#   'SIMILAR',
#   'ALUMINIO',
#   'IMPRESO',
#   'ENVASE',
#   'COMPRIMIDOS',
#   'LIBERACIÓN',
#   'PROLONGADA',
#   'CERTIFICACIÓN',
#   'PLANTA',
#   'PRODUCTORA'],
#  ['JANUMET', 'RECUBIERTO', 'EQUIVALENTE'],
#  ['DAPAGLIFOZINA', 'METFORMINA', '1000', 'COMP', 'SIMILAR', 'XIGDUO', '1000'],
#  ['INSULINA', 'DEGLUDEC'],
#  ['SITAGLIPTINA',
#   'METFORMINA',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   '1000',
#   'PRESENTACIÓN',
#   'VENTA',
#   'PÚBLICO',
#   'CONVENIENTE',
#   'DESDE',
#   'PUNTO',
#   'VISTA',
#   'PRECIO',
#   'MENOS',
#   'MESES',
#   'EFICACIA',
#   'CERTIFICADO',
#   'ACREDITE',
#   'FABRICADO',
#   'PAÍSES',
#   'AGENCIAS',
#   'ALTA'],
#  ['EMPAGLIFLOZINA',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   '1000',
#   'PRESENTACIÓN',
#   'VENTA',
#   'PÚBLICO',
#   'CONVENIENTE',
#   'DESDE',
#   'PUNTO',
#   'VISTA',
#   'PRECIO',
#   'MENOS',
#   'MESES',
#   'EFICACIA',
#   'CERTIFICADO',
#   'ACREDITE',
#   'FABRICADO',
#   'PAÍSES',
#   'AGENCIAS',
#   'ALTA',
#   'VIGILANC'],
#  ['INSULINA',
#   'RÁPIDA',
#   'LÁPIZ',
#   'SEGÚN',
#   'REQUERIDO',
#   'BASES',
#   'ADMINISTRATIVAS',
#   'TÉCNICAS',
#   'ANEXOS',
#   'ADJUNTOS'],
#  ['INSULINA',
#   'HUMANA',
#   'ADNR',
#   'PRODUCIDA',
#   'TECNOLOGÍA',
#   'RECOMBINANTE',
#   'SACCHAROMYCES',
#   'CEREVISIAE',
#   'CADA',
#   'CONTIENE',
#   'INSULINA',
#   'HUMANA',
#   'UNIDAD',
#   'INTERNACIONAL',
#   'CORRESPONDE',
#   'INSULINA',
#   'HUMANA',
#   'ANHIDRA',
#   'EQUIVALENTE',
#   'INSULATARD'],
#  ['SITAGLIPTINA',
#   'METFORMINA',
#   'CLORHIDRATO',
#   '1000',
#   'CAJA',
#   'COMPRIMIDOS',
#   'RECUBIERTOS'],
#  ['VILDAGLIPTINA', 'CLORHIDRATO', 'METFORMINA'],
#  ['METFORMINA', 'COMPRIMIDO', '1000MG', 'LIBERACIÓN', 'PROLONGADA'],
#  ['METFORMINA',
#   'COMP',
#   'PROLONG',
#   'CAJA',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   'SIMILAR',
#   'GLICENEX',
#   '1000'],
#  ['0114',
#   'INSULINA',
#   'DEGLUDEC',
#   'DEBE',
#   'CONSIDERAR',
#   'BONIFICACION',
#   'AGUJAS',
#   'LAPIZ',
#   'LAPIZ',
#   'DESECHABLE',
#   '5600'],
#  ['INSULINA',
#   'GLARGINA',
#   'SUGERENCIA',
#   'LANTUS',
#   'CAJA',
#   'CONTENIENDO',
#   'LAPIZ'],
#  ['METFORMINA', 'COMPRIMIDO', 'BIOEQUIVALENTE'],
#  ['METFORMINA', '1000', 'LIBERACIÓN', 'PROLONGADA', 'COMPRIMIDO'],
#  ['JERINGA',
#   'DESECHABLE',
#   'PARA',
#   'INSULINA',
#   'AGUJA',
#   'FIJA',
#   '50UI',
#   'AGUJA'],
#  ['EMPAGLIFOZINA', 'METFORMINA', '1000MG', '60COMP'],
#  ['METFORMINA'],
#  ['SITAGLIPINA',
#   'METFORMINA',
#   'CLORHIDRATO',
#   '1000',
#   'COMPRIMIDOS',
#   'JANUMET',
#   '1000'],
#  ['INSULINA', 'RETARD', '100UI', 'INDICAR', 'VALOR', 'UNITARIO', 'NETO'],
#  ['INSULINA', 'ASPARTATO', 'CARTRIDGE'],
#  ['METFORMINA', '1000', 'SITAGLIPTINA', 'COMPRIMIDO'],
#  ['JERINGA', 'INSULINA', 'PRESENTACIÓN', 'CAJA'],
#  ['METFORMINA', 'COMPRIMIDOS', 'ENVASE', 'CLINICO'],
#  ['LISTADO', 'FÁRMACOS', 'DETALLADOS', 'BASES', 'LICITACIÓN', 'ADJUNTAS'],
#  ['GALVUS'],
#  ['INSULINA', 'DEGLUDEC', 'INYECTABLE', 'SIMILAR', 'TRESIBA', 'FLEXOUCH'],
#  ['SAXAGLIPTINA',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   '1000',
#   'PRESENTACIÓN',
#   'VENTA',
#   'PÚBLICO',
#   'CONVENIENTE',
#   'DESDE',
#   'PUNTO',
#   'VISTA',
#   'PRECIO',
#   'MENOS',
#   'MESES',
#   'EFICACIA',
#   'FABRICADO',
#   'CHILE',
#   'CERTIFICADO',
#   'CUMPLIMIENTO',
#   'BUENAS',
#   'PRACTICAS',
#   'FABRICACIÓN',
#   'EMITIDO'],
#  ['CAJA',
#   'COMPRIMIDO',
#   'CONTIENE',
#   'METFORMINA',
#   'CLORHIDRATO',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   'SIMILAR',
#   'GLIDANIL'],
#  ['METFORMINA', 'CAJA', 'COMP'],
#  ['METFORMINA',
#   'LIBERACIÓN',
#   'PROLONGADA',
#   'COMPRIMIDOS',
#   'SEGÚN',
#   'BASES',
#   'ADMINISTRATIVAS',
#   'ADJUNTAS'],
#  ['METFORMINA', 'COMP', 'SIMILAR', 'GLIFORTEX'],
#  ['INSULINA',
#   'ULTRALENTA',
#   'GLARGINA',
#   'LÁPIZ',
#   'DESECHABLE',
#   'JERINGA',
#   'PRELLENADA',
#   '2620928'],
#  ['METFORMINA', 'COMPRIMIDOS', 'RECUBIERTOS'],
#  ['METFORMINA',
#   '1000',
#   'COMP',
#   'PROLONGADA',
#   'GLAUPAX',
#   'GLIFORTX',
#   'GLIMEFOR',
#   'HIPOGLUCIN',
#   'TAVIST'],
#  ['METFORMINA', '1000', 'LINEA'],
#  ['INSULINA', 'HUMANA', '1000', 'INYECTABLE'],
#  ['METFORMINA',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   'ENVASE',
#   'SELLADO',
#   'RESISTENTE',
#   'INADULTERADO'],
#  ['ZGEN',
#   '100003873',
#   'METFORMINA',
#   '1000MG',
#   'COMPRIMIDO',
#   'LIBERACIÓN',
#   'PROLONGADA'],
#  ['METFORMINA', '850MG', 'COMPRIMIDO'],
#  ['METFORMINA'],
#  ['METFORMINA', '1000', 'RECUBUERTA', 'COMPRIMIDOS', 'GENERICA'],
#  ['SAXAGLIPTINA',
#   'METFORMINA',
#   '1000',
#   'CAJA',
#   'BLISTERS',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   'LIBERACION',
#   'PROLONGADA'],
#  ['METFORMINA', 'COMP', '850MG'],
#  ['6773', 'INSULINA'],
#  ['VILDAGLIPTINA', 'METFORMINA', '850MG', 'GALVUS'],
#  ['5277', 'AI5208', 'INSULINA', 'GLARG', 'LAPIZ', 'ML100', ')///'],
#  ['METFORMINA', 'COMPRIMIDOS', 'RECUBIERTOS', '...(', 'INDICAR', 'REGISTRO'],
#  ['0190030013', 'INSULINA', 'DETEMIR'],
#  ['SITAGLIPTINA', 'METFORMINA', 'SIMILAR', 'JANUMET'],
#  ['METFORMINA', 'PROLONGADA', 'COMPRIMIDO', 'RECUBIERTO', 'RANURADO'],
#  ['GLAFORNIL', 'METFORMINA', 'REFERENTE', 'TERAPÉUTICO'],
#  ['METFORMINA', 'COMPRIMIDOS', '1000', 'LIBERACION', 'PROLONGADA'],
#  ['0004', 'INSULINA', 'LENTA'],
#  ['METFORMINA', 'COMP', 'LINEA'],
#  ['FA03', '0008', 'INSULINA', 'LENTA'],
#  ['SITAGLIPTINA', 'METFORMINA', 'COMP', 'SIMILAR', 'JANUMET'],
#  ['METFORMINA',
#   'CLORHIDRATO',
#   '1000',
#   'ENVASADO',
#   'BLISTER',
#   'SIMILAR',
#   'ALUMINIO',
#   'IMPRESO',
#   'COMP',
#   'LIBERACIÓN',
#   'PROLONGADA'],
#  ['EMPAGLIFOZINA', 'METFORMINA', 'COMP'],
#  ['INSULINA', 'TRESIBA', 'EQUIVALENTE', 'TERAPEUTICO'],
#  ['3002161364', 'INSULINA', 'ASPARTICA', 'SOLUCIÓN', 'INYECTABLE'],
#  ['CAJAS', '1000', 'COMPRIMIDOS', 'METFORMINA'],
#  ['INSUL', 'DETEMIR', 'INYECT', '100005501'],
#  ['INSULINA', 'DEGLUDEC', 'TRESIBA', 'INYECTABLE'],
#  ['INSULINEMIA'],
#  ['INSULINA', 'GLARGINA', 'PLUMA', 'SIMILAR', 'LANTUS', 'SOLOSTAR'],
#  ['EMPAGLIFOZINA', 'METFORMINA', '1000MG', 'COMP'],
#  ['0345', 'METFORMINA', 'COMPRIMIDO'],
#  ['VILDAGLIPTINA', 'METFORMINA', 'COMP'],
#  ['ENVASE',
#   'COMPRIMIDOS',
#   'CONTIENE',
#   'CLORHIDRATO',
#   'METFORMINA',
#   'SIMILAR',
#   'IGUAL',
#   'GLAFORNIL'],
#  ['METFORMINA', 'CLORHIDRATO', 'COMPRIMIDO'],
#  ['VILDAGLIPTINA', 'METFORMINA', '1000', 'COMPRIMIDOS'],
#  ['GLIBENCLAMIDA', 'METFORMINA', 'COMP'],
#  ['METFORMINA',
#   'GLIBENCLAMIDA',
#   'COMPRIMIDOS',
#   'ENVASE',
#   'SELLADO',
#   'RESISTENTE',
#   'INADULTERADO'],
#  ['INSULINA', 'HUMANA'],
#  ['DAPAGLIFOZINA',
#   'METFORMINA',
#   '1000',
#   'CAJA',
#   'COMPRIMIDOS',
#   'LIBERACION',
#   'PROLONGADA'],
#  ['VILDAGLIPTINA', 'METFORMINA', '1000', 'COMPRIMIDOS', 'RECUBIERTOS'],
#  ['1092020',
#   'INSULINA',
#   'ULTRA',
#   'RAPIDA',
#   'INSULINA',
#   'ULTRARAPIDA',
#   'LISPRO',
#   'LAPIZ',
#   'EQUIVALENTE',
#   'HUMALOG',
#   'KWIKPEN'],
#  ['METFORMINA', '1000XR'],
#  ['GLIFORTEX', 'CAJA', 'COMP'],
#  ['METFORMINA', 'CLORHIDRATO', '850MG'],
#  ['JARDIANCE'],
#  ['INSULINA', 'ELECSYS'],
#  ['INSULINA', 'ASPARTA', 'RECOMBINANTE'],
#  ['LINAGLIPTINA', 'METFORMINA', '1000', 'COMP'],
#  ['INSULINA', 'DEGLUDEC'],
#  ['GLICENEX', 'CAJA', 'EQUIVALENTE'],
#  ['VILDAGLIPTINA',
#   'METFORMINA',
#   '1000',
#   'COMPRIMIDOS',
#   'SIMILAR',
#   'GALVUS',
#   '1000',
#   'COMP'],
#  ['METFORMINA',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   'ADJUNTAN',
#   'BASES',
#   'ADMINISTRATIVAS',
#   'TECNICAS',
#   'LEERLAS',
#   'OFERTAR'],
#  ['EMPAGLIFLOZINA', '1000', 'COMPRIMIDO', 'RECUBIERTO'],
#  ['METFORMINA', 'VILDAGLIPTINA', '50MG', 'COMPRIMIDOS', 'GALVUS', 'SIMILAR'],
#  ['INSULINA', 'GLARGINA', 'RECOMB', 'LAPIZ', '100004060'],
#  ['3002161382', 'INSULINA', 'GLARGINA', 'SOLUCIÓN', 'INYECTABLE'],
#  ['GLAFORNIL', 'CAJA', 'COMP'],
#  ['METFORMINA', 'COMP', 'ENVASE', 'CLINICO'],
#  ['METFORMINA',
#   'GLIBENCLAMIDA',
#   'COMPRIMIDOS',
#   'REECUBIERTOS',
#   'PRESENTACIÓN',
#   'VENTA',
#   'PÚBLICO',
#   'CONVENIENTE',
#   'DESDE',
#   'PUNTO',
#   'VISTA',
#   'PRECIO',
#   'MENOS',
#   'MESES',
#   'EFICACIA',
#   'CERTIFICADO',
#   'ACREDITE',
#   'FABRICADO',
#   'PAÍSES',
#   'AGENCIAS',
#   'ALTA'],
#  ['SUMINISTRO',
#   'METFORMINA',
#   'CLORHIDRATO',
#   'CAJA',
#   'COMPRIMIDOS',
#   'LIBERACION',
#   'PROLONGADA'],
#  ['METFORMINA', '1000'],
#  ['METFORMINA',
#   'CLORHIDRATO',
#   '1000',
#   'COMPRIMIDOS',
#   'LIBERACION',
#   'PROLONGADA',
#   'ENVASADOS',
#   'BLISTER',
#   'SIMILAR',
#   'ALUMINIO',
#   'IMPRESO',
#   'ENVASE',
#   'COMPRIMIDOS',
#   'LIBERACIÓN',
#   'PROLONGADA',
#   'DESPACHO',
#   'PARCIALIZADO'],
#  ['METFORMINA', 'COMPRIMIDO', 'CAPSULA'],
#  ['METFORMINA', '1000', 'COMP'],
#  ['INSULINA', '100UI'],
#  ['GLIBENCLAMIDA', 'METFORMINA', '1000MG', 'COMPRIMIDOS', 'RECUBIERTOS'],
#  ['INSULINA', 'ASPARTA', 'LAPIZ', 'SIMILAR', 'NOVORAPID', 'FLEXPEN'],
#  ['JERINGAS', 'CAJAS', '100UI'],
#  ['LINAGLIPTINA',
#   'METFORMINA',
#   'COMPRIMIDOS',
#   'CAJA',
#   'COMPRIMIDOS',
#   'RECUBIERTOS'],
#  ['INSULINA', 'GLARGINA', 'LAPIZ'],
#  ['JANUMET', '1000MG'],
#  ['METFORMINA', 'COMPRIMIDOS', 'RECUBIERTOS'],
#  ['EMPAGLIFOZINA', 'METFORMINA', 'CAJA', 'COMPRIMIDOS'],
#  ['M01F0043', 'INSULINA', 'LENTA', '100UI'],
#  ['METFORMINA', 'CAJA', 'COMPRIMIDOS'],
#  ['INSULINA',
#   'ULTRARAPIDA',
#   'ASPARTATO',
#   'CART',
#   'VIDR',
#   'AGUJAS',
#   'LÁPIZ',
#   'APLICADOR'],
#  ['CAJAS',
#   'COMPRIMIDOS',
#   'METFORMINA',
#   'VILDAGLIPTINA',
#   'SUGIERE',
#   'GALVUS',
#   'SIMILAR',
#   'COMPOSICIÓN'],
#  ['METFORMINA', 'COMP'],
#  ['METFORMINA',
#   'CLORHIDRATO',
#   'CAJA',
#   'COMPRIMIDOS',
#   'LIBERACIÓN',
#   'PROLONGADA',
#   'SIMILAR',
#   'GLICENEX',
#   'COMP'],
#  ['LINAGLIPTINA', 'METFORMINA', 'CAJA', 'TABLETAS'],
#  ['CAJA',
#   'COMPRIMIDO',
#   'RECUBIERTO',
#   'CONTIENE',
#   'LINAGLIPTINA',
#   'METFORMINA',
#   'CLORHIDRATO',
#   '1000',
#   'SIMILAR',
#   'TRAYENTA',
#   '1000'],
#  ['JANUMET', '1000', 'SITAGLIPTINA', 'METFORMINA'],
#  ['EMPAGLIFOZINA', 'METFORMINA', '1000', 'COMP'],
#  ['METFORNINA', 'SEGUN', 'BASES'],
#  ['GALVUS', '1000', '56COMP'],
#  ['METFORMINA', 'CLORHIDRATO'],
#  ['METFORMINA', 'ENVASE', 'COMPRIMIDOS', 'MAXIMO', 'PAGAR'],
#  ['INSULINA', 'RETARDADA', 'HUMANA', '100UI'],
#  ['METFORMINA',
#   'COMPRIMIDO',
#   'RECUBIERTO',
#   'ENVASADO',
#   'BLISTER',
#   'ENVASERESISTENTE',
#   'SELLO',
#   'ASEGURE',
#   'INVIOLABILIDAD',
#   'CONTENIDO'],
#  ['METFORMINA', 'BIOEQUIVALENTE', 'VENCIMIENTO', 'SUPERIOR'],
#  ['TRAYENTA', 'ENVASE', 'COMPRMIDOS'],
#  ['SITAGLIPTINA',
#   '1000',
#   'METFORMINA',
#   'CLORHIDRATO',
#   'LIBERACIÓN',
#   'PROLONGADA',
#   'COMPRIMIDOS',
#   'REFERENCIA',
#   'JANUMET'],
#  ['GLIFORTEX', '1000MG', 'COMP', 'SIMILAR'],
#  ['GALVUS', 'COMP'],
#  ['METFORMINA',
#   'CLORHIDRATO',
#   '1000',
#   'COMPRIMIDOS',
#   'LIBERACIÓN',
#   'PROLONGADA',
#   'EQUIVALENTE',
#   'HIPOGLUCIN',
#   'COMP'],
#  ['METFORMINA', '1000', 'CAJA', 'COMPRIMIDOS', 'LIBERACIÓN', 'PROLONGADA'],
#  ['INSULINA', 'CRISTALINA', 'RÁPIDA', 'AMPOLLA', '10ML'],
#  ['METFORMINA',
#   'CLORHIDRATO',
#   'BIOEQUIVALENTE',
#   'COMPRIMIDO',
#   'REGISTRO',
#   'SANITARIO',
#   'VIGENTE',
#   'VENCIMIENTO',
#   'SUPERIOR',
#   'MESES'],
#  ['JANUMET',
#   'METFORMINA',
#   '850MG',
#   'SITAGLIPTINA',
#   '50MG',
#   'COMP',
#   'RECUB',
#   'CAJA'],
#  ['CAJA',
#   'COMPRIMIDOS',
#   'TRAYENTA',
#   'SIMILAR',
#   'COMPOSICIÓN',
#   'ACUERDO',
#   'BASES',
#   'ADJUNTAS'],
#  ['DAPAGLIFOZINA', 'METFORMINA', '1000', 'COMP', 'SIMILAR', 'XIGDUO'],
#  ['INSULINA', 'LENTA'],
#  ['METFORMINA', '1000'],
#  ['METFORMINA', '1000MG', 'SITAGLIPTINA', '50MG'],
#  ['METFORMINA', 'ENVASE', 'CLINICO'],
#  ['METFORMINA',
#   '1000',
#   'COMPRIMIDOS',
#   'LIBERACIÓN',
#   'PROLONGADA',
#   'SIMILAR',
#   'GLAUPAX',
#   '1000',
#   'COMP'],
#  ['SUMINISTRO',
#   'LINAGLIPTINA',
#   'CLORHIDRATO',
#   'METFORMINA',
#   '1000',
#   'CAJA',
#   'COMPRIMIDOS',
#   'RECUBIERTOS'],
#  ['METFORMINA'],
#  ['JARDIANCE', '1000MG'],
#  ['SITAGLIPTINA', 'METFORMINA', '1000', 'CAJA', 'COMPRIMIDOS', 'JANUMET'],
#  ['VILDAGLIPTINA', 'METFORMINA', 'COMP', 'SIMILAR', 'GALVUS'],
#  ['CAJA',
#   'COMPRIMIDOS',
#   'CONTIENEN',
#   'SITAGLIPTINA',
#   'MONOHIDRATO',
#   'EQUIVALENTE',
#   'SITAGLIPTINA',
#   'COMO',
#   'BASE',
#   'LIBRE',
#   '1000',
#   'METFORMINA',
#   'CLORHIDRATO',
#   'LIBERACIÓN',
#   'PROLONGADA',
#   '1000',
#   'SIMILAR',
#   'JANUMET',
#   '1000'],
#  ['METFORMINA',
#   '1000',
#   'LIBERACION',
#   'PROPONGADA',
#   'COMPRIMIDOS',
#   'LIBERACION',
#   'PROLONGADA'],
#  ['METFORMINA', 'COMPRIMIDOS'],
#  ['ELECSYS', 'INSULINA'],
#  ['1092011',
#   'INSULINA',
#   'HUMANA',
#   '100UI',
#   'FRASCO',
#   'AMPOLLA',
#   'CONTIENE',
#   '10ML',
#   'EQUIVALENTE',
#   'INSULINA',
#   'INSULATARD',
#   '100UI'],
#  ['SUMINISTRO',
#   'DAPAGLIFLOZINA',
#   'PROPANODIOL',
#   'METFORMINA',
#   'CLORHIDRATO',
#   '1000',
#   'CAJA',
#   'COMPRIMIDOS',
#   'LIBERACION',
#   'PROLONGADA'],
#  ['SITAGLIPTINA', 'METFORMINA', '1000', 'COMP', 'SIMILAR', 'JANUMET'],
#  ['JERINGAS'],
#  ['CALIBRADOR',
#   'INSULINA',
#   'PARA',
#   'MINDRAY',
#   'CL1000I',
#   'CALIBRADOR',
#   'INSULINA',
#   'PARA',
#   'EQUIPO',
#   'MINDRAY',
#   'CL1000I',
#   'CAJA'],
#  ['METFORMINA', '1000', 'COMPRIMIDOS', 'LIBERACIÓN', 'PROLONGADA'],
#  ['HIPOGLUCIN'],
#  ['METFORMINA', 'CLOHIDRATO', 'COMP', 'RECUBIERTOS'],
#  ['METFORMINA', '1000', 'LIBERACION', 'PROLONGADA'],
#  ['METFORMINA', '1000'],
#  ['INSULINA', 'GLARGINA', 'SIMILAR', 'LANTUS'],
#  ['INSULINA',
#   'HUMANA',
#   'ISÓFANA',
#   'RECOMBINANTE',
#   'SUSPENSIÓN',
#   'INYECTABLE',
#   'VIAL',
#   'ENVASADO',
#   'VIAL',
#   'VIDRIO',
#   'ADMINISTRACIÓN',
#   'SUBCUTÁNEA',
#   'ENVASE',
#   'RESISTENTE',
#   'SELLO',
#   'ASEGURE',
#   'INVIOLABILIDAD',
#   'CONTENIDO'],
#  ['INSULINA',
#   'CRISTALINA',
#   'HUMAN',
#   '100UI',
#   'FRASCO',
#   'AMPOLLA',
#   '10ML',
#   'ADJUNTAN',
#   'ESPECIFICACIONES'],
#  ['METFORMINA', '1000', 'COMPRIMIDOS', 'LIBERACION', 'PROLONGADA'],
#  ['INSULINA',
#   'ASPARTATO',
#   'RECOMBINANTE',
#   'SOLUCIÓN',
#   'INYECTABLE',
#   'LÁPIZ',
#   'DESCARTABLE',
#   'UNIDAD',
#   'LÁPIZ'],
#  ['INSULINA',
#   'GLARGINA',
#   'SOLUCIÓN',
#   'INYECTABLE',
#   'CONTENIENDO',
#   '6378',
#   'EQUIVALENTES',
#   'INSULINA',
#   'RECOMBINANTE',
#   'HUMANA',
#   'ENVASE',
#   'CONTENIENDO',
#   'LAPIZ',
#   'APLICADOS',
#   'DESECHABLE',
#   'EQUIVALENTE',
#   'LANTUS'],
#  ['METFORMINA', 'LIBERACION', 'PROLONGADA'],
#  ['INSULINA', 'GLARGINA', 'TOUGEO', '300U', 'LAPIZ'],
#  ['REQUIERE', 'METFORMINA', '750XL', 'COMP'],
#  ['TRAYENTA', '1000', 'ENVASE', 'COMPRMIDOS'],
#  ['SITAGLIPTINA', 'METFORMINA', '1000'],
#  ['JANUMET', '1000MG'],
#  ['METFORMINA',
#   'COMPRIMIDOS',
#   'RECUBIERTO',
#   '850MG',
#   'PRESENTACIÓN',
#   'VENTA',
#   'PÚBLICO',
#   'CONVENIENTE',
#   'DESDE',
#   'PUNTO',
#   'VISTA',
#   'PRECIO',
#   'MENOS',
#   'MESES',
#   'EFICACIA',
#   'FABRICADO',
#   'EXTRANJERO',
#   'CERTIFICADO',
#   'CUMPLIMIENTO',
#   'BUENAS',
#   'PRACTICAS',
#   'FABRICACIÓN',
#   'EMITIDO'],
#  ['METFORMINA',
#   'CLORHIDRATO',
#   'ENVASADO',
#   'BLISTER',
#   'SIMILAR',
#   'ALUMINIO',
#   'IMPRESO',
#   'COMP',
#   'LIBERACIÓN',
#   'PROLONGADA'],
#  ['METFORMINA', 'GLIBENCLAMIDA', 'CARDIOVASCULAR'],
#  ['INSULINA', 'HUMANA', 'ISOFANA', 'INYECTABLE'],
#  ['SITAGLIPTINA', 'METFORMINA', 'LIBERACION', 'PROLONGADA', 'COMPRIMIDOS'],
#  ['METFORMINA', 'COMPRIMIDOS', 'ENVASE', 'CLINICO'],
#  ['CADA',
#   'LAPICERA',
#   'CONTIENE',
#   'SOLUCIÓN',
#   'INYECTABLE',
#   'EQUIVALENTES',
#   'UNIDADESDE',
#   'INSULINA',
#   'GLARGINA',
#   'SIMILAR',
#   'TOUJEO'],
#  ['METFORMINA'],
#  ['INSULINA',
#   'DEGLUDEC',
#   'RECOMBINANTE',
#   'DISPOSITIVO',
#   'DESECHABLE',
#   'EQUIVALENTE',
#   'TRESIBA',
#   'FLEX',
#   'TOUCH',
#   'LÁPIZ'],
#  ['METFORMINA',
#   'CLORHIDRATO',
#   'GLIBENCLAMIDA',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   'ENVASE',
#   'CONTENIENDO',
#   'COMPRIMIDOS'],
#  ['HIPOGLUCIN', 'COMPRIMIDOS', 'EQUIVALENTE', 'TERAPEUTICO'],
#  ['3020110', 'CAJA', 'JERINGAS', 'INSULINA', 'DESECHABLES'],
#  ['0212',
#   'INSULINA',
#   'ASPARTICA',
#   'SOLUCION',
#   'INYECTABLE',
#   'ENVASADO',
#   'DISPOSITIVO',
#   'INYECTOR',
#   'TIPO',
#   'PENFILL',
#   'UNIDAD'],
#  ['AMARYL', '1000MG'],
#  ['30000', 'METFORMINA', 'FOFAR'],
#  ['COMPRIMIDOS', 'METFORMINA', '1000', 'LIBERACIÓN', 'PROLONGADA'],
#  ['METFORMINA',
#   '1000',
#   'INDICAR',
#   'FORMA',
#   'CLARA',
#   'VENCIMIENTO',
#   'LABORATORIO',
#   'PLAZO',
#   'ENTREGA',
#   'MONTO',
#   'MINIMO',
#   'DESPACHO',
#   'ESPECIFICACIONES',
#   'PROVEEDOR'],
#  ['ENVASE',
#   'COMPRIMIDOS',
#   'CONTIENE',
#   'METFORMINA',
#   'CLORHIDRATO',
#   'SIMILAR',
#   'IGUAL',
#   'GLAFORNIL'],
#  ['METFORMINA', '1000MG', 'COMP'],
#  ['CAJA',
#   'COMPRIMIDO',
#   'RECUBIERTO',
#   'CONTIENE',
#   'EMPAGLIFLOZINA',
#   'CLORHIDRATO',
#   'METFORMINA',
#   '1000',
#   'SIMILAR',
#   'JARDIANCE',
#   '1000'],
#  ['METFORMINA', 'COMPRIMIDOS'],
#  ['INSULINA', 'GLARGINA', 'LAPIZ', 'SIMILAR', 'LANTUZ', 'SOLOSTAR'],
#  ['0079', 'JERINGA', 'DESECHABLE', 'INSULINA', 'AGUJA', 'LIBRE', 'LATEX'],
#  ['VILDAGLIPTINA',
#   'METFORMINA',
#   '850MG',
#   'COMPRIMIDO',
#   'FECHA',
#   'VENCIMIENTO',
#   'MAYOR',
#   'DESDE',
#   'RECEPCIÓN',
#   'ACEPTAN',
#   'CARTAS',
#   'CANJE'],
#  ['DAPAGLIFLOZINA',
#   'COMO',
#   'PROPANODIOL',
#   'METFORMINA',
#   'CLORHIDRATO',
#   '1000',
#   'COMP',
#   'XIGDUO',
#   '1000'],
#  ['CAJAS',
#   'VILDAGLIPTINA',
#   '50MG',
#   'METFORMINA',
#   '1000MG',
#   'PRESENTACIÓN',
#   'CAJA',
#   'COMPRIMIDOS'],
#  ['INSULINA', 'ASPARTA', 'INYECTABLE', 'LAPIZ', 'PRELLENADO'],
#  ['INSULINA',
#   'HUMANA',
#   'RAPIDA',
#   'EQUIVALENTE',
#   'CADA',
#   'SOLUCION',
#   'INYECTABLE',
#   'CONTIENE',
#   'INSULINA'],
#  ['FAAA10009', 'INSULINA', 'DETEMIR', 'MULTIDOSIS'],
#  ['SITAGLIPTINA', 'METFORMINA'],
#  ['GLAFORNIL', 'LIBERACION', 'PROLONGADA', 'EQUIVALENTE'],
#  ['METFORMINA', 'CAJA', 'COMPRIMIDOS'],
#  ['LINAGLIOPTINA',
#   'METFORMINA',
#   '1000',
#   'SIMILAR',
#   'TRAYENTA',
#   '1000',
#   'CAJA',
#   'COMPRIMIDOS'],
#  ['XIGDUO', '1000', 'COMPRIMIDOS'],
#  ['METFORMINA',
#   'COMPRIMIDO',
#   'LIBERACION',
#   'PROLONGADA',
#   'ENVASADO',
#   'BLISTER'],
#  ['LINAGLIPTINA', 'METFORMINA', 'SIMILAR', 'TRAYENTA'],
#  ['METFORMINA', 'VILDAGLIPTINA', 'COMPRIMIDO', 'CAPSULA'],
#  ['4000', 'COMPRIMIDO', 'METFORMINA', '1000'],
#  ['ELECSYS', 'INSULINA', 'CALSET'],
#  ['TRAYENTA', 'CAJA', 'EQUIVALENTE'],
#  ['LINAGLIPTINA', 'METFORMINA', '1000', 'COMP', 'SIMILAR', 'TRAYENTA'],
#  ['METFORMINA', 'COMPRIMIDOS'],
# ...
#   'RÁPIDA'],
#  ['REQUIERE', 'METFORMINA', '1000', 'VILDAGLIPTINA', 'COMP'],
#  ['INSULINA'],
#  ['HIPOGLUCIN', 'CAJA', 'COMP'],
#  ['GALVUS', '1000', 'CAJA', 'EQUIVALENTE'],
#  ['METFORMINA', 'GLIBENCLAMIDA'],
#  ['METFORMINA',
#   'SAXAGLIPTINA',
#   'COMPRIMIDOS',
#   'COLOR',
#   'ROSADO',
#   'BICONVEXOS',
#   'FORMA',
#   'CAPSULA',
#   'MARCA',
#   'IMPRESA',
#   'LADO',
#   'CADA',
#   'CAJA',
#   'CONTIENE',
#   'COMPRIMIDOS',
#   'METFORMINA',
#   '1000',
#   'SAXAGLIPTINA',
#   'KOMBIGLYZE',
#   'SIMILAR'],
#  ['INSULINA', '100UI'],
#  ['METFORMINA', 'GLIBENCLAMIDA', 'COMPRIMIDO'],
#  ['METFORMINA', 'COMPRIMIDOS'],
#  ['EMPAGLIOFOZINA', 'METFORMINA', 'CAJA', 'COMPRIMIDOS'],
#  ['METFORMINA'],
#  ['METFORMINA',
#   'CLORHIDRATO',
#   '1000',
#   'BIOEQUIVALENTE',
#   'COMP',
#   'VENCIMIENTO',
#   'SUPERIOR',
#   'AÑOS'],
#  ['METFORMINA',
#   'CLORHIDRATO',
#   'ENVASADO',
#   'BLISTER',
#   'SIMILAR',
#   'ALUMINIO',
#   'IMPRESO',
#   'COMP',
#   'LIBERACION',
#   'PROLONGADA'],
#  ['GLAUPAX', 'CAJA', 'EQUIVALENTE'],
#  ['INSULINA', 'SOLUCION', 'INYECTABLE'],
#  ['JANUMET', 'ENVASE', 'COMPRIMIDOS'],
#  ['METFORMINA', '1000', 'LIBERACIÓN', 'PROLONGADA'],
#  ['METFORMINA', 'GLIBENCLAMIDA', 'COMPRIMIDOS', 'RECUBIERTOS'],
#  ['METFORMINA', 'COMPRIMIDOS', 'RECUBIERTOS'],
#  ['INSULINA',
#   'LENTA',
#   'SEGÚN',
#   'REQUERIDO',
#   'BASES',
#   'ADMINISTRATIVAS',
#   'TÉCNICAS',
#   'ANEXOS',
#   'ADJUNTOS'],
#  ['CLONAZEPAM', 'COMPRIMIDOS'],
#  ['METFORMINA', 'COMP'],
#  ['DAPAGLIFOZINA', 'METFORMINA', '1000', 'COMP', 'SIMILAR', 'XIGDUO', '1000'],
#  ['INSULINA', 'CRISTALINA'],
#  ['GLIFORTEX', '850MG', 'COMPRIMIDOS', 'BOTICA', 'COMUNAL'],
#  ['REQUIERE', 'ADQUIRIR', 'MERTFORMINA', 'CLORHIDRATO', '1000'],
#  ['METFORMINA',
#   '1000MG',
#   'COMPRIMIDOS',
#   'LIBERACIÓN',
#   'PROLONGADA',
#   'SIMILAR',
#   'GLAFORNIL'],
#  ['METFORMINA',
#   'CLORHIDRATO',
#   'COMPRIMIDO',
#   'RECUBIERTO',
#   'ENVASADO',
#   'BLISTER',
#   'ENVASE',
#   'RESISTENTE',
#   'SELLO',
#   'ASEGURE',
#   'INVIOLABILIDAD',
#   'CONTENIDO'],
#  ['CAJA',
#   'COMPRIMIDO',
#   'CONTIENE',
#   'VILDAGLIPTINA',
#   'METFORMINA',
#   'CLORHIDRATO',
#   '1000',
#   'SIMILAR',
#   'GALVUS',
#   '1000'],
#  ['1629804',
#   'INSULINA',
#   'GLARGINA',
#   'ACCION',
#   'PROLONGADA',
#   'FRASCO',
#   'SOLUCIÓN',
#   'INYECTABLE'],
#  ['SITAGLIPTINA', 'METFORMINA', '1000', 'COMPRIMIDOS'],
#  ['2200068', 'INSULINA', 'CATRIDGE'],
#  ['VILDAGLIPTINA', 'METFORMINA', 'COMP', 'SIMILAR', 'GALVUS'],
#  ['LINAGLIPTINA',
#   'METFORMINA',
#   '000MG',
#   'COMP',
#   'RECUBIERTO',
#   'SIMILAR',
#   'TRAYENTA'],
#  ['METFORMINA', 'SITAGLIPTINA', 'COMPRIMIDOS', 'JANUMET', 'SIMILAR'],
#  ['INSULINA',
#   'DEGLUDEC',
#   'SOLUCIÓN',
#   'INYECTABLE',
#   'DISPOSITIVO',
#   'PARA',
#   'INYECCIÓN',
#   'PRELLENADO',
#   'TIPO',
#   'LÁPIZ',
#   'DESCARTABLE',
#   'AGUJAS',
#   'DONACIÓN',
#   'VENCIMIENTO',
#   'MAYOR',
#   'MESES',
#   'DESDE',
#   'ENVÍO',
#   'ORDEN'],
#  ['INSULINA', 'GLARGINA', 'SOLUCION', 'INYECTABLE', 'SOLOSTAR', 'PENFIL'],
#  ['INSULINA',
#   'GLARGINA',
#   'LÁPIZ',
#   '100UI',
#   'LANTUS',
#   'AGUJAS',
#   'COMPATIBLE',
#   'AGUJAS',
#   'LAPIZ',
#   'ENTREGA',
#   'FORMA',
#   'PARCIALIZADA',
#   'SEGÚN',
#   'ACUERDO'],
#  ['JERINGA', 'INSULINA', 'AGUJA', '28GX11'],
#  ['METFORMINA', 'COMPRIMIDOS'],
#  ['METFORMINA', 'SITAGLIPTINA', '500MG', 'COMPRIMIDOS', 'JANUMET', 'SIMILAR'],
#  ['VILDAGLIPTINA',
#   'METFORMINA',
#   'CLORH',
#   '1000',
#   'ENVASE',
#   'CONTENIENDO',
#   'COMPRIMIDOS'],
#  ['INSULINA', 'CALSET', 'CAJA'],
#  ['ELECSYS', 'CALSET', 'INSULINA', 'CÓDIGO', 'HOSPITAL', 'LAB09443'],
#  ['JERINGA',
#   'PARA',
#   'INSULINA',
#   'AGUJA',
#   'FIJA',
#   'MMLARGO',
#   'TOPE',
#   'GOMA',
#   'GRADUACION',
#   'VISIBLE',
#   'EMBOLO',
#   'LUBRICACION',
#   'LIBRE',
#   'LATEX',
#   'DESECHABLE',
#   'ENVASE',
#   'INDIVIDUAL'],
#  ['MEDICAMENTOS',
#   'SEGUN',
#   'FORMULARIO',
#   'PRESENTACION',
#   'OFERTA',
#   'ECONOMICA',
#   'ADJUNTO'],
#  ['METFORMINA', '1000'],
#  ['METFORMINA',
#   'CLORHIDRATO',
#   '850MG',
#   'CAJA',
#   'COMPRIMIDOS',
#   'BIOEQUIVALENTE',
#   'EXCIPIENTES',
#   'POVIDONA',
#   'CROSPOVIDONA',
#   'CELULOSA',
#   'MICROCRISTALINA',
#   'ACIDO',
#   'ESTEÁRICO',
#   'PRODUCTO',
#   'ELABORADO',
#   'CHILE'],
#  ['METFORMINA', '1000', 'LIBERACIÓN', 'PROLONGADA', 'COMPRIMIDO'],
#  ['0116', 'INSULINA', 'ASPARTA', 'RECOMBINANTE', '100UI', 'FRASCO', 'AMPOLLA'],
#  ['SITAGLIPTINA', 'METFORMINA', 'COMP', 'SIMILAR', 'JANUMET'],
#  ['SITAGLIPTINA',
#   'METFORMINA',
#   '1000',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   'CAJA',
#   'COMPRIMIDOS'],
#  ['INSULINA',
#   'RETARDADA',
#   'MLSOLUCION',
#   'INYECTABLE',
#   'VENCIMIENTO',
#   'MAYOR',
#   'MESES',
#   'DESDE',
#   'ENVIÓ'],
#  ['METFORMINA', 'CAJA', 'COMPRIMIDOS', 'RECUBIERTOS'],
#  ['1400020',
#   'ANALOGO',
#   'INSULINA',
#   'LENTA',
#   'GLARGINA',
#   'RECOMBINANTE',
#   'LAPIZ',
#   'SIMILAR',
#   'TOUJEO',
#   'OCASIONAL',
#   'LAPIZ'],
#  ['SITAGLIPTINA',
#   'METFORMINA',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   'ENVASE',
#   'COMERCIAL',
#   'CONTENIENDO',
#   'COMPRIMIDOS',
#   'RECUBIERTOS'],
#  ['METFORMINA', 'COMPRIMIDOS', 'BLÍSTER', 'VCTO', 'SUPERIOR'],
#  ['GALVUS', 'CAJA', 'EQUIVALENTE'],
#  ['SITAGLIPTINA', 'METFORMINA', '1000', 'COMPRIMIDOS'],
#  ['2200043',
#   'INSULINA',
#   'DEGLUDEC',
#   'ULTRALENTA',
#   '100UI',
#   'SOLUCION',
#   'INYECTABLE',
#   'LAPIZ',
#   'PRELLENADO'],
#  ['SUMINISTRO',
#   'VILDAGLIPTINA',
#   'METFORMINA',
#   'CLORHIDRATO',
#   '1000',
#   'CAJA',
#   'COMPRIMIDOS'],
#  ['BOLSA',
#   'TÉRMICA',
#   'TRANSPORTE',
#   'PARA',
#   'INSULINA',
#   '19X25CMS',
#   'APROX',
#   'COTIZAR',
#   'UNIDAD',
#   'INDICAR',
#   'VENCIMIENTO',
#   'MONTO',
#   'MÍNIMO',
#   'FACTURACIÓN',
#   'DESPACHO',
#   'LINEA'],
#  ['METFORMINA', 'LIBERACIÓN', 'PROLONGADA'],
#  ['2140163', 'METFORMINA', 'CLORHIDRATO', 'COMPRIMIDO'],
#  ['METFORMINA'],
#  ['AMARYL', '1000MG'],
#  ['METFORMINA', 'CMPRIMIDO'],
#  ['METFORMINA',
#   '1000',
#   'COMPRIMIDOS',
#   'LIBERACIÓN',
#   'PROLONGADA',
#   'SIMILAR',
#   'GLAUPAX',
#   '1000',
#   'COMP'],
#  ['LINAGLIPTINA', 'METFORMINA', 'COMPRIMIDO', 'CAPSULA'],
#  ['8455', 'LANTUS', 'INSULINA', 'GLARGINA'],
#  ['LINAGLIPTINA', 'METFORMINA'],
#  ['METFORMINA',
#   'SITAGLIPTINA',
#   'METFORMINA',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   '1000',
#   'PRESENTACIÓN',
#   'VENTA',
#   'PÚBLICO',
#   'CONVENIENTE',
#   'DESDE',
#   'PUNTO',
#   'VISTA',
#   'PRECIO',
#   'MENOS',
#   'MESES',
#   'EFICACIA',
#   'FABRICADO',
#   'EXTRANJERO',
#   'CERTIFICADO',
#   'CUMPLIMIENTO',
#   'BUENAS'],
#  ['METFORMINA', '500MG', 'GLIBENCLAMIDA', '5MGX30'],
#  ['METFORMINA', 'REVISAR', 'BASES', 'ADJUNTAS'],
#  ['INSULINA',
#   'HUMANA',
#   'BIFASICA',
#   'INSULINA',
#   'REGULAR',
#   'INSULINA',
#   'PROPORCION',
#   'FRASCO',
#   'AMPOLLA'],
#  ['SUMINISTRO', 'METFORMINA', 'COMPRIMIDOS', 'PROLONGADA'],
#  ['EMPAGLIFOZINA', 'METFORMINA', '1000MG', 'CAJA', 'COMP'],
#  ['INSULINA', 'GLULISINA', 'LAPIZ', 'AGUJAS', 'LAPIZ', 'ESTUCHE', 'TERMICO'],
#  ['METFORMINA',
#   'GLIBENCLAMIDA',
#   'COMPRIMIDOS',
#   'EQUIVALENTE',
#   'HIPOGLUCIN',
#   'COMP'],
#  ['METFORMINA', 'COMPRIMIDO', 'LIBERACIÓN', 'CONVENCIONAL'],
#  ['METFORMINA',
#   'GLIBENCLAMIDA',
#   'COMPRMIDOS',
#   'RECUBIERTOS',
#   'ENVASE',
#   'SELLADO',
#   'RESISTENTE',
#   'INADULTERADO',
#   'SIMILAR',
#   'GLUCOVANCE'],
#  ['METFORMINA', 'CLORHIDRATO', 'COMPRIMIDO'],
#  ['METFORMINA', '500MG', 'COMPRIMIDO', 'LIBERACIÓN', 'PROLONGADA'],
#  ['INSULINA', 'DETEMIR', 'INYECTABLE', 'CARTUCHO'],
#  ['EMPAGLIFOZINA',
#   'METFORMINA',
#   'CAJA',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   'JARDIANCE',
#   'SIMILAR'],
#  ['METFORMINA', 'VENCIMIENTO', 'SUPERIOR', 'MESES'],
#  ['METFORMINA',
#   'COMPRIMIDO',
#   'COMPRIMIDO',
#   'RECUBIERTO',
#   'ENVASADO',
#   'ENBLISTER'],
#  ['VILDAGLIPTINA', 'METFORMINA', '1000', 'CAJA', 'COMPRIMIDOS'],
#  ['GALVUS', '1000', 'VILDAGLIPTINA', 'METFORMINA', 'CAJA', 'COMPRIMIDOS'],
#  ['0073', 'METFORMINA', 'CLORHIDRATO', 'COMPRIMIDO', 'RANURADO', 'ORAL'],
#  ['METFORMINA', 'CAJA', 'COMPRIMIDOS'],
#  ['INSULINA', 'GLANGINA', 'RECOMB', 'LAPIZ'],
#  ['METFORMINA', 'GLIBENCLAMIDA'],
#  ['INSULINA', 'PARA', 'COBAS'],
#  ['LINAGLIPTINA',
#   'METFORMINA',
#   'COMPRIMIDOS',
#   'NOTA',
#   'SUGIERE',
#   'FECHA',
#   'VENCIMIENTO',
#   'SUPERIOR',
#   'CASO',
#   'CONTRARIO',
#   'CONTAR',
#   'POLITICAS',
#   'CANJE'],
#  ['FAAA10004', 'INSULINA', 'GLARGINA'],
#  ['VILDAGLIPTINA',
#   '50MG',
#   'METFORMINA',
#   '500MG',
#   'SEGÚN',
#   'SOLICITADO',
#   'BASES',
#   'ADMINISTRATIVAS',
#   'TÉCNICAS',
#   'ANEXOS',
#   'ADJUNTOS'],
#  ['GLIFORTEX'],
#  ['SITAGLIPTINA',
#   'METFORMINA',
#   'CLORHIDRATO',
#   '1000',
#   'COMPRIMIDOS',
#   'LIBERACION',
#   'PROLONGADA',
#   'ENVASADOS',
#   'BLISTER',
#   'SIMILAR',
#   'ALUMINIO',
#   'IMPRESO',
#   'ENVASE',
#   'COMPRIMIDOS',
#   'TIPO',
#   'JANUMET',
#   '1000MG'],
#  ['METFORMINA', '850MG', 'COMPRIMIDOS', 'SIMILAR', 'GLAFORNIL'],
#  ['METFORMINA',
#   'CLORHIDRATO',
#   '850MG',
#   'CAJA',
#   'COMPRIMIDOS',
#   'BIOEQUIVALENTE',
#   'EXCIPIENTES',
#   'POVIDONA',
#   'CROSPOVIDONA',
#   'CELULOSA',
#   'MICROCRISTALINA',
#   'ACIDO',
#   'ESTEÁRICO',
#   'PRODUCTO',
#   'ELABORADO',
#   'CHILE'],
#  ['GLICENEX'],
#  ['INSULINA',
#   'HUMANA',
#   'CRISTALINA',
#   'FRASCO',
#   'AMPOLLA',
#   'SOLUCIÓN',
#   'INYECTABLE',
#   'VENCIMIENTO',
#   'MAYOR',
#   'MESES',
#   'DESDE',
#   'ENVÍO'],
#  ['LINAGLIPTINA',
#   'COMPRIMIDOS',
#   '1000',
#   'PRESENTACIÓN',
#   'VENTA',
#   'PÚBLICO',
#   'CONVENIENTE',
#   'DESDE',
#   'PUNTO',
#   'VISTA',
#   'PRECIO',
#   'MENOS',
#   'MESES',
#   'EFICACIA',
#   'FABRICADO',
#   'EXTRANJERO',
#   'CERTIFICADO',
#   'CUMPLIMIENTO',
#   'BUENAS',
#   'PRACTICAS',
#   'FABRICACIÓN',
#   'EMITIDO'],
#  ['METFORMINA', 'CAJA', 'COMNPRIMIDOS', 'GLICENEX', 'SIMILAR'],
#  ['METFORMINA'],
#  ['JERINGA',
#   'HIPODERMICA',
#   'INSULINA',
#   'AGUJA',
#   'FIJA',
#   'PROTECTOR',
#   'AGUJA',
#   'POLIPROPILENO',
#   'TRANSPARENTE',
#   'LIBRE',
#   'LATEX',
#   'ESCALA',
#   'NUMERICA',
#   'NITIDA',
#   'INDELEBLE',
#   'GRADUACION',
#   'UNIDADES',
#   '4517'],
#  ['METFORMINA',
#   'COMPRIMIDO',
#   'RECUBIERTO',
#   'PREFERENCIA',
#   'FORMATO',
#   'OVALADO',
#   'VENCIMIENTO',
#   'SUPERIOR'],
#  ['CAJAS', 'SITAGLIPTINA', 'METFORMINA', 'COMP'],
#  ['26222003',
#   'INSULINA',
#   'ASPARTO',
#   'DISPOSITIVO',
#   'TIPO',
#   'LAPIZ',
#   'CARGADO',
#   'DEBE',
#   'INCLUIR',
#   'BONIFICACION',
#   'AGUJAS',
#   'LAPIZ'],
#  ['TRAYENTA', 'CAJA', 'EQUIVALENTE'],
#  ['LINAGLIPTINA', 'METFORMINA', '1000', 'CAJA', 'COMPRIMIDOS'],
#  ['DAPAGLIFLOZINA',
#   'METFORMINA',
#   '1000',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   'ENVASE',
#   'COMERCIAL',
#   'CONTENIENDO',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   'LIBERACION',
#   'PROLONGADA'],
#  ['JERINGA', 'INSULINA'],
#  ['CAJAS', 'DAPAGLIFLOZINA', '10MG', 'METFORMINA', '1000MG', 'COMP'],
#  ['8434', 'INSULINA', 'ACCIÓN', 'RÁPIDA', 'VIAL', 'CRISTALINA'],
#  ['GLAFORNIL', 'CAJA', 'EQUIVALENTE'],
#  ['CANAGLIFLOZINA', 'METFORMINA', '1000'],
#  ['2140163', 'METFORMINA', 'CLORHIDRATO', 'COMPRIMIDO'],
#  ['METFORMINA',
#   'ENVASE',
#   'COMPRIMIDOS',
#   'LIBERACIÓN',
#   'PROLONGADA',
#   'FECHA',
#   'VENCIMIENTO',
#   'MENOR',
#   'MESES'],
#  ['LINAGLIPTINA',
#   'METFORMINA',
#   '1000',
#   'CAPSULAS',
#   'SIMILAR',
#   'TRAYENTA',
#   '1000',
#   'CAPSULAS'],
#  ['METFORMINA', '1000', 'CAJA', 'EQUIVALENTE'],
#  ['JARDIANCE', 'CAJA', 'EQUIVALENTE'],
#  ['METFORMINA', 'COMPRIMIDO'],
#  ['SITAGLIPTINA',
#   '50MG',
#   'METFORMINA',
#   '1000MG',
#   'LIBERACIÓN',
#   'PROLONGADA',
#   'CAJA',
#   'COMPRIMIDOS'],
#  ['JANUMET', 'RECUBIERTO', 'EQUIVALENTE'],
#  ['INSULINA', 'ASPARTA', 'BIFÁSICA', 'LÁPICES', 'CAJA', 'LÁPICES'],
#  ['METFORMINA', 'VILDAGLIPTINA', '50MG', 'COMPRIMIDOS', 'GALVUS', 'SIMILAR'],
#  ['2628455',
#   'INSULINA',
#   'GLARGINA',
#   'ACCION',
#   'PROLONGADA',
#   '300UI',
#   'LAPIZ',
#   'SOLUCIÓN',
#   'INYECTABLE'],
#  ['METFORMINA', 'COMP', 'BIOEQUIVALENTE'],
#  ['INSULINA', 'DETEMIR', 'CARTRIDGE'],
#  ['SITAGLIPTINA',
#   'METFORMINA',
#   '1000',
#   'COMPRIMIDOS',
#   'SIMILAR',
#   'JANUMET',
#   '1000',
#   'COMPRIMIDOS',
#   'RECUBIERTOS'],
#  ['SITAGLIPTINA',
#   'METFORMINA',
#   '1000',
#   'COMPRIMIDOS',
#   'LIBERACIÓN',
#   'PROLONGADA',
#   'SIMILAR',
#   'JANUMET',
#   '1000',
#   'COMP'],
#  ['REQUIERE',
#   'ADQUISICIÓN',
#   'METFORMINA',
#   '1000',
#   'COMPRIMIDOS',
#   'LIBERACIÓN',
#   'PROLONGADA',
#   'PARA',
#   'ABASTECER',
#   'DROGUERÍA',
#   'COMUNAL'],
#  ['METFORMINA', '750XR', '30COMP'],
#  ['METFORMINA', 'COMPRIMIDOS', 'LIBERACION', 'PROLONGADA'],
#  ['SAXAGLIPTINA',
#   'METFORMINA',
#   '1000',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   'LIBERACIÓN',
#   'EXTENDIDA'],
#  ['GLIFORTEX', 'COMPRIMIDO'],
#  ['METFORMINA', 'LIBERACIÓN', 'PROLONGADA', '1000MG'],
#  ['INSULINA',
#   'HUMANA',
#   'GLARGINA',
#   'RECOMBINANTE',
#   'FRASCO',
#   'AMPOLLA',
#   'PRESENTACIÓN',
#   'VENTA',
#   'PÚBLICO',
#   'CONVENIENTE',
#   'DESDE',
#   'PUNTO',
#   'VISTA',
#   'PRECIO',
#   'MENOS',
#   'MESES',
#   'EFICACIA',
#   'FABRICADO',
#   'EXTRANJERO',
#   'CERTIFICADO',
#   'CUMPLIMIENTO',
#   'BUENAS'],
#  ['0070', 'METFORMINA', 'CLORHIDRATO'],
#  ['AGUJA', 'DESECHABLE', 'PENFILL', '2240024'],
#  ['LINAGLIPTINA', 'METFORMINA', 'CAPSULAS', 'SIMILAR', 'TRAYENTA', 'CAPSULAS'],
#  ['METFORMINA',
#   'LIBERACION',
#   'PROLONGADA',
#   '750MG',
#   'COMPRIMIDOS',
#   'BOTICA',
#   'COMUNAL'],
#  ['INSULINA',
#   'LAPIZ',
#   'HIPOGLICEMIANTE',
#   'INSULINA',
#   'HUMANA',
#   'ACCIÓN',
#   'PROLONGADA',
#   'FORMATO',
#   'LÁPIZ',
#   '300UI',
#   'CUTÁNEA',
#   'EQUIVALENTE',
#   'PENFILL',
#   'INSULATARD'],
#  ['LINAGLIPTINA',
#   'METFORMINA',
#   '1000MG',
#   'COMPRIMIDO',
#   'RECUBIERTO',
#   'FECHA',
#   'VENCIMIENTO',
#   'SUPERIOR',
#   'DESDE',
#   'FECHA',
#   'ENTREGA',
#   'ACEPTAN',
#   'CARTAS',
#   'CANJE'],
#  ['ENVASE',
#   'COMPRIMIDOS',
#   'CONTIENE',
#   'METFORMINA',
#   'CLORHIDRATO',
#   'SIMILAR',
#   'IGUAL',
#   'GLAFORNIL'],
#  ['JANUMET', 'XR100', 'COMP'],
#  ['SITAGLIPTINA',
#   'METFORMINA',
#   '1000',
#   'CAJA',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   'NÚCLEO',
#   'LIBERACIÓN',
#   'PROLONGADA',
#   'METFORMINA',
#   'CAPA',
#   'ACCIÓN',
#   'RÁPIDA',
#   'SITAGLIPTINA',
#   'EQUIVALENTE',
#   'JANUMET',
#   '1000'],
#  ['ALFA', 'INSULINE', 'GROWTH', 'FACTOR'],
#  ['METFORMINA', '1000', 'COMPRIMIDOS', 'LIBERACIÓN', 'PROLONGADA'],
#  ['INSULINA', 'LENTA', 'SUSPENSIÓN', 'INYECTABLE', 'FRASCO', 'AMPOLLA'],
#  ['JANUMET', '1000', 'CAJA', 'EQUIVALENTE'],
#  ['METFORMINA', 'VENCIMIENTO', 'SUPERIOR'],
#  ['VILDAGLIPTINA',
#   'CLORHIDRATO',
#   'METFORMINA',
#   'CAJA',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   'EQUIVALENTE',
#   'JALRA'],
#  ['SITAGLIPTINA',
#   'METFORMINA',
#   'LIBERACION',
#   'PROLONGADA',
#   '1000',
#   'CAJA',
#   'COMPRIMIDOS',
#   'LIBERACION',
#   'PROLONGADA'],
#  ['METFORMINA'],
#  ['METFORMINA',
#   'LIBERACION',
#   'PROLONGADA',
#   '500MG',
#   'COMPRIMIDOS',
#   'BOTICA',
#   'COMUNAL'],
#  ['9350001', 'PUERTO', 'INYECCION', 'INSULINA', 'PORT', 'ADVANCE'],
#  ['LINAGLIPTINA',
#   'METFORMINA',
#   '1000',
#   'CAJA',
#   'COMP',
#   'SIMILAR',
#   'TRAYENTA',
#   'ADJUNTAN',
#   'BASES',
#   'ADMINISTRATIVAS',
#   'TÉCNICAS',
#   'LEERLAS',
#   'OFERTAR'],
#  ['LINAGLIPTINA', 'METFORMINA', 'CAJA', 'COMPRIMIDOS'],
#  ['METFORMINA', '500MG', 'GLIBENCLAMIDA'],
#  ['METFORMINA', '1000'],
#  ['METFORMINA', 'SITAGLIPTINA', '1000', 'COMPRIMIDOS', 'JANUMET', 'SIMILAR'],
#  ['METFORMINA', 'SITAGLIPTINA', 'COMPRIMIDOS', 'JANUMET', 'SIMILAR'],
#  ['JERINGA', 'DESECHABLE', '27GX1'],
#  ['SUMINISTRO',
#   'SITAGLIPTINA',
#   'METFORMINA',
#   'CLORHIDRATO',
#   '1000',
#   'EQUIVALENTE',
#   'JANUMET',
#   '1000',
#   'CAJA',
#   'COMPRIMIDOS',
#   'LIBERACION',
#   'PROLONGADA'],
#  ['NOVOMIX', 'RECOMBINANTE', 'FLEXPEN'],
#  ['SOBRE', 'TERMICO', 'PARA', 'INSULINA'],
#  ['LINAGLIPTINA', 'METFORMINA', 'CLORHIDRATO', 'COMP', 'SIMILAR', 'TRAYENTA'],
#  ['INSULINA', 'TRESIBA', 'LÁPIZ'],
#  ['SAXAGLIPTINA',
#   'METFORMINA',
#   'CLORHIDRATO',
#   '1000',
#   'COMPRIMIDOS',
#   'RECUBIERTOS',
#   'MARCA',
#   '1000',
#   'IMPRESA',
#   'LADO'],
#  ['INSUL', 'ASPARTICA', '100U', 'LAPIZ', 'AGUJ', '100005592'],
#  ['METFORMINA',
#   'COMPRIMIDOS',
#   '500MG',
#   'PRESENTACIÓN',
#   'VENTA',
#   'PÚBLICO',
#   'CONVENIENTE',
#   'DESDE',
#   'PUNTO',
#   'VISTA',
#   'PRECIO',
#   'MENOS',
#   'MESES',
#   'EFICACIA',
#   'FABRICADO',
#   'CHILE',
#   'CERTIFICADO',
#   'CUMPLIMIENTO',
#   'BUENAS',
#   'PRACTICAS',
#   'FABRICACIÓN',
#   'EMITIDO'],
#  ['3002168452', 'INSULINA', 'DEGLUDEC', 'INYECTABLE'],
#  ['KOMBIGLIZE', '1000', 'COMP'],
#  ['SITAGLIPINA',
#   'METFORMINA',
#   'CLORHIDRATO',
#   '1000',
#   'COMP',
#   'JANUMET',
#   '1000'],
#  ['GLAFORNIL', 'METFORMINA', 'REFERENTE', 'TERAPÉUTICO'],
#  ['REQUIERE', 'ADQUIRIR', 'METFORMINA', '1000'],
#  ['0070',
#   'INSULINA',
#   'ASPARTO',
#   'RECOMBINANTE',
#   'CARTRIDGE',
#   'DISPOSITIVO',
#   'PRELLENADO',
#   'DESECHABLE',
#   'PARA',
#   'DISPENSACIÓN'],
#  ['INSULINA', 'HUMANA', 'MONOCOMPONENTE', 'ISOFANICA', 'RECOMBINANTE', 'SUSP'],
#  ['LINAGLIPTINA',
#   'METFORMINA',
#   '1000',
#   'ENVASE',
#   'COMPRIMIDOS',
#   'TRAYENTA',
#   'MAXIMO',
#   'PAGAR'],
#  ['EMPAGLIFLOZINA',
#   'CLORHIDRATO',
#   'METFORMINA',
#   'COMP',
#   'SIMILAR',
#   'JARDIANCE'],
#  ...]

# %% [markdown]
# ## SimHash

# %%
import jieba
# !pip install simhash
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: simhash in /usr/local/lib/python3.7/dist-packages (2.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from simhash) (1.21.6)

# %%
from simhash import Simhash

# %%
CHLDiab1DirtyNameUS2[0]
# Out:
# ['INSULINA',
#  'ASPART',
#  'TIPO',
#  'LAPIZ',
#  'DEBE',
#  'INCLUIR',
#  'MEDICAMENTO',
#  'ADMINISTRAR',
#  'DISPOSITIVO',
#  'OTORGUE',
#  'ADMINISTRACIÓN',
#  'DOSIS']

# %%
print(Simhash(CHLDiab1DirtyNameUS2[0]).distance(Simhash(CatalogNameUS2[0])))
# Out:
# 35

# %%
DistanceList_1 = []
for i in CatalogNameUS2:
  temp_dis = Simhash(CHLDiab1DirtyNameUS2[1]).distance(Simhash(i))
  DistanceList_1.append(temp_dis)

# %%
min(DistanceList_1)
# Out:
# 19

# %%
val, idx = min((val, idx) for (idx, val) in enumerate(DistanceList_1))

# %%
print(val, idx)
# Out:
# 19 84

# %%
CatalogNameUS[84]
#print([' '.join(row) for row in CatalogNameUS[257]])
# Out:
# ['TACROLIMUS', '3', 'MG', ',', 'CAPSULE', ',', 'TBD']

# %%
CHLDiab1DirtyNameUS2[1]
# Out:
# ['INUSLINA',
#  'ULTRA',
#  'RÁPIDA',
#  'ASPARTICA',
#  'LISPRO',
#  'GLULISINA',
#  'CARTUCHO',
#  '1000']

# %%
DistanceList_0

def find(lst, a, b):
    result = []
    for i, x in enumerate(lst):
        if x<a or x>b:
            result.append(i)
    return result
